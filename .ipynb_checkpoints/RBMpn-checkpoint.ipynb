# %%
import numpy as np
import itertools
import time

# %%
class RBM:
    def __init__(self, v_dim, h_dim, lr=5e-4, gibbs_num=1):
        self.v_dim = v_dim
        self.h_dim = h_dim
        self.lr = lr
        self.v_bias = np.random.normal(-0.1, 0.1, size = (1,self.v_dim))
        self.h_bias = np.random.normal(-0.1, 0.1, size =(1,self.h_dim))
        self.W = np.random.normal(size = (self.v_dim, self.h_dim))
        self.gibbs_num = gibbs_num
        self.v_w, self.v_v, self.v_h = 0, 0, 0
        self.momentum = 0.9

    
    # when a input vector V is recieved, p(h=1|v) can be computed
    # using the activition probability, the states of hidden layer could be sampled
    def sample_h(self, v_input):
        var = -(np.dot(v_input, self.W) + self.h_bias)
        p_h_v = 1/(1 + np.exp(var))
        #p_h_v = np.tanh(var)
        state_h = self.state_sample(p_h_v)

        return state_h, p_h_v
    
    # in constract, once the states of hidden layer are obtained, p(v=1|h) can be computed
    # with probability, the states of visible layer could be sampled 
    def sample_v(self, h):
        var = -(np.dot(h, self.W.T) + self.v_bias)
        p_v_h = 1/(1 + np.exp(var))
        #p_v_h = np.tanh(var)
        state_v = self.state_sample(p_v_h)
        
        return state_v, p_v_h

    def state_sample(self, p):
        state = []
        uni = np.random.uniform(0,1, size=p[0].shape[0])
        for i in range(len(p)):
            condition = np.less(p[i], uni)
            state_node = np.where(condition, 0, 1)
            state.append(state_node)
        return np.array(state).reshape(p.shape[0], p.shape[1])

    # taking use of the visible layer state V(i) and probability p(v|h), k'th V state could be computed 
    # and its corresponding p(h(k)|V).
    def gibbs_sampling(self, v):
        i = 0 
        k = self.gibbs_num
        v_0 = v

        _, p_h0_v = self.sample_h(v_0)

        while bool(i < k):
            state_h, _ = self.sample_h(v)
            state_v, _ = self.sample_v(state_h)
            i += 1

        else: 
            v_k = state_v

            _, p_hk_v = self.sample_h(v_k)
        
        return v_0, v_k, p_h0_v, p_hk_v
        

    # with the refered formulas, the gradient of each parameter(W, b-->h, a-->v) could be computed
    def gradient_compute(self, v_0, v_k, p_h0_v, p_hk_v):
        dw = np.dot(v_0.T, p_h0_v) - np.dot(v_k.T, p_hk_v)
        dh_bias = np.sum(p_h0_v - p_hk_v)
        dv_bias = np.sum(v_0 - v_k)
        
        
        self.v_w = self.momentum * self.v_w + (1 - self.momentum) * dw
        self.v_h = self.momentum * self.v_h + (1 - self.momentum) * dh_bias
        self.v_v = self.momentum * self.v_v + (1 - self.momentum) * dv_bias 

        self.W += self.lr * self.v_w
        self.v_bias += self.lr * self.v_v
        self.h_bias += self.lr * self.v_h 
    # set the number of iteration and go over all the training data (binary vectors) for one epoch.

# %%
def compute_px_with_Z(train_data, W, v_bias, h_bias): 
    probability = []
    for l in range(len(train_data)):
        train_data_one_piece = train_data[l]
        product_value = 1
        exp_av = np.exp(np.dot(v_bias, train_data_one_piece))
        for i in range(h_bias.shape[1]):
            product_value = product_value * (np.exp(np.dot(W.T[i], train_data_one_piece) + h_bias.T[i]) + 1)
        px_with_Z = exp_av * product_value
        probability.append(px_with_Z[0])
    return probability


def compute_Z(v_dim, W, v_bias, h_bias):
    def dic_build(dic_candidate, dim):
        i= 0
        for item in itertools.product('01',repeat=dim):
            if i not in dic_candidate:
                dic_candidate[i] = item
            i += 1
        return dic_candidate
        
    dic_v = {}  
    dic_v = dic_build(dic_v, v_dim)

    Z = 0
    for l in range(len(dic_v)):
        train_data_one = np.array(dic_v[l]).astype(int)
        for i in range(len(train_data_one)):
            if train_data_one[i] == 0:
                train_data_one[i] = -1
        exp_av = np.exp(np.dot(v_bias, train_data_one))
        product = 1
        for j in range(h_bias.shape[1]):
            product = product * (np.exp(np.dot(train_data_one.T, W.T[j]) + h_bias.T[j]) + 1)
        total = exp_av * product

        Z += total
    return Z

# %%
train_data = np.loadtxt(r'3x3pn.txt')

visible_node_num = train_data.shape[1]
hidden_node_num = 20
lr = 5e-4
gibbs_num = 1

epochs = 10000
batch_size = 1

# %%
rbm = RBM(visible_node_num, hidden_node_num, lr, gibbs_num)

# %%
KL_list = []
log_LKH_list = []

for epoch in range(epochs):
    epoch_start_time = time.time()
    for index in range(0, train_data.shape[0]-batch_size, batch_size):
        v0 = train_data[index: index + batch_size]
        vk = train_data[index: index + batch_size]
        _, p_h0_v = rbm.sample_h(v0)
        v0, vk, p_h0_v, p_hk_v = rbm.gibbs_sampling(v0)
        rbm.gradient_compute(v0, vk, p_h0_v, p_hk_v)
    

    Z = compute_Z(train_data.shape[1], rbm.W, rbm.v_bias, rbm.h_bias) 
    probability_list = compute_px_with_Z(train_data, rbm.W, rbm.v_bias, rbm.h_bias)

    logLKH = 0
    KL = 0
    
    
    for i in range(len(probability_list)):
        px_with_Z = probability_list[i]
        N = len(probability_list)
        log_lkh = np.log(px_with_Z) - np.log(Z) 
        logLKH += log_lkh

        kl = -np.log(N)/N - np.log(px_with_Z)/N + np.log(Z)/N
        KL += kl
    KL /= N
    logLKH /= N
    KL_list.append(KL)
    log_LKH_list.append(logLKH)

    probability_list = [probability_list[i]/Z for i in range(len(probability_list))]
    x = np.sum(probability_list)
    
    epoch_end_time = time.time()
    
    results = 'epoch:{} ==>  KL = {}, logLKH = {}, prob_sum = {:.4f}, time = {:.2f}s'.format(epoch+1, KL, logLKH, x, epoch_end_time-epoch_start_time)
    f=open("a.txt","a")
    f.write(results + '\n')
    f.close()

    #if(epoch % 10 == 0):
    print(results)
# Out:
# epoch:1 ==>  KL = [0.94287523], logLKH = [-15.83931052], prob_sum = 0.0000, time = 0.08s
# epoch:2 ==>  KL = [0.93381123], logLKH = [-15.71241452], prob_sum = 0.0000, time = 0.05s
# epoch:3 ==>  KL = [0.92435463], logLKH = [-15.58002215], prob_sum = 0.0000, time = 0.04s
# epoch:4 ==>  KL = [0.91459014], logLKH = [-15.44331928], prob_sum = 0.0000, time = 0.04s
# epoch:5 ==>  KL = [0.90707265], logLKH = [-15.33807442], prob_sum = 0.0000, time = 0.04s
# epoch:6 ==>  KL = [0.90032503], logLKH = [-15.24360772], prob_sum = 0.0000, time = 0.05s
# epoch:7 ==>  KL = [0.89308096], logLKH = [-15.14219072], prob_sum = 0.0001, time = 0.05s
# epoch:8 ==>  KL = [0.88354585], logLKH = [-15.00869925], prob_sum = 0.0001, time = 0.05s
# epoch:9 ==>  KL = [0.8772311], logLKH = [-14.9202928], prob_sum = 0.0001, time = 0.05s
# epoch:10 ==>  KL = [0.87058806], logLKH = [-14.82729023], prob_sum = 0.0001, time = 0.04s
# epoch:11 ==>  KL = [0.86577287], logLKH = [-14.75987744], prob_sum = 0.0002, time = 0.05s
# epoch:12 ==>  KL = [0.86251118], logLKH = [-14.71421389], prob_sum = 0.0002, time = 0.05s
# epoch:13 ==>  KL = [0.85707185], logLKH = [-14.63806325], prob_sum = 0.0003, time = 0.05s
# epoch:14 ==>  KL = [0.85049046], logLKH = [-14.54592373], prob_sum = 0.0004, time = 0.04s
# epoch:15 ==>  KL = [0.84743067], logLKH = [-14.50308675], prob_sum = 0.0006, time = 0.05s
# epoch:16 ==>  KL = [0.84250599], logLKH = [-14.43414119], prob_sum = 0.0009, time = 0.05s
# epoch:17 ==>  KL = [0.84078767], logLKH = [-14.41008464], prob_sum = 0.0013, time = 0.05s
# epoch:18 ==>  KL = [0.83635961], logLKH = [-14.34809186], prob_sum = 0.0018, time = 0.05s
# epoch:19 ==>  KL = [0.83226117], logLKH = [-14.29071373], prob_sum = 0.0027, time = 0.05s
# epoch:20 ==>  KL = [0.83067439], logLKH = [-14.26849873], prob_sum = 0.0039, time = 0.05s
# epoch:21 ==>  KL = [0.83057466], logLKH = [-14.26710261], prob_sum = 0.0053, time = 0.05s
# epoch:22 ==>  KL = [0.82908534], logLKH = [-14.24625213], prob_sum = 0.0070, time = 0.05s
# epoch:23 ==>  KL = [0.83053735], logLKH = [-14.26658027], prob_sum = 0.0090, time = 0.05s
# epoch:24 ==>  KL = [0.83286498], logLKH = [-14.29916711], prob_sum = 0.0113, time = 0.05s
# epoch:25 ==>  KL = [0.83639956], logLKH = [-14.34865121], prob_sum = 0.0136, time = 0.05s
# epoch:26 ==>  KL = [0.84089688], logLKH = [-14.41161366], prob_sum = 0.0163, time = 0.05s
# epoch:27 ==>  KL = [0.84833206], logLKH = [-14.51570618], prob_sum = 0.0206, time = 0.05s
# epoch:28 ==>  KL = [0.85841129], logLKH = [-14.65681544], prob_sum = 0.0259, time = 0.05s
# epoch:29 ==>  KL = [0.86929501], logLKH = [-14.80918745], prob_sum = 0.0319, time = 0.05s
# epoch:30 ==>  KL = [0.8812657], logLKH = [-14.97677715], prob_sum = 0.0385, time = 0.05s
# epoch:31 ==>  KL = [0.89459192], logLKH = [-15.16334419], prob_sum = 0.0462, time = 0.05s
# epoch:32 ==>  KL = [0.9088999], logLKH = [-15.36365596], prob_sum = 0.0538, time = 0.05s
# epoch:33 ==>  KL = [0.91898834], logLKH = [-15.50489404], prob_sum = 0.0596, time = 0.05s
# epoch:34 ==>  KL = [0.93167021], logLKH = [-15.68244033], prob_sum = 0.0673, time = 0.05s
# epoch:35 ==>  KL = [0.9480737], logLKH = [-15.91208915], prob_sum = 0.0768, time = 0.05s
# epoch:36 ==>  KL = [0.96229667], logLKH = [-16.11121075], prob_sum = 0.0845, time = 0.05s
# epoch:37 ==>  KL = [0.98056954], logLKH = [-16.36703087], prob_sum = 0.0936, time = 0.05s
# epoch:38 ==>  KL = [0.99684088], logLKH = [-16.59482968], prob_sum = 0.1025, time = 0.05s
# epoch:39 ==>  KL = [1.01057587], logLKH = [-16.78711952], prob_sum = 0.1106, time = 0.04s
# epoch:40 ==>  KL = [1.02641547], logLKH = [-17.00887397], prob_sum = 0.1203, time = 0.04s
# epoch:41 ==>  KL = [1.04396704], logLKH = [-17.25459594], prob_sum = 0.1309, time = 0.05s
# epoch:42 ==>  KL = [1.06162441], logLKH = [-17.50179909], prob_sum = 0.1408, time = 0.05s
# epoch:43 ==>  KL = [1.07803942], logLKH = [-17.7316092], prob_sum = 0.1528, time = 0.05s
# epoch:44 ==>  KL = [1.09969052], logLKH = [-18.03472465], prob_sum = 0.1673, time = 0.05s
# epoch:45 ==>  KL = [1.11966835], logLKH = [-18.31441421], prob_sum = 0.1822, time = 0.05s
# epoch:46 ==>  KL = [1.1412237], logLKH = [-18.61618916], prob_sum = 0.1994, time = 0.05s
# epoch:47 ==>  KL = [1.15918391], logLKH = [-18.86763205], prob_sum = 0.2160, time = 0.05s
# epoch:48 ==>  KL = [1.17708177], logLKH = [-19.11820212], prob_sum = 0.2319, time = 0.04s
# epoch:49 ==>  KL = [1.19788558], logLKH = [-19.40945549], prob_sum = 0.2493, time = 0.05s
# epoch:50 ==>  KL = [1.21904401], logLKH = [-19.70567347], prob_sum = 0.2646, time = 0.05s
# epoch:51 ==>  KL = [1.23740765], logLKH = [-19.96276445], prob_sum = 0.2804, time = 0.05s
# epoch:52 ==>  KL = [1.25378819], logLKH = [-20.19209193], prob_sum = 0.2938, time = 0.05s
# epoch:53 ==>  KL = [1.26849553], logLKH = [-20.39799469], prob_sum = 0.3068, time = 0.05s
# epoch:54 ==>  KL = [1.28687267], logLKH = [-20.65527472], prob_sum = 0.3230, time = 0.05s
# epoch:55 ==>  KL = [1.30532641], logLKH = [-20.91362702], prob_sum = 0.3418, time = 0.05s
# epoch:56 ==>  KL = [1.32019252], logLKH = [-21.12175258], prob_sum = 0.3593, time = 0.05s
# epoch:57 ==>  KL = [1.33765852], logLKH = [-21.36627659], prob_sum = 0.3795, time = 0.05s
# epoch:58 ==>  KL = [1.35437317], logLKH = [-21.60028173], prob_sum = 0.3987, time = 0.05s
# epoch:59 ==>  KL = [1.37071045], logLKH = [-21.82900369], prob_sum = 0.4145, time = 0.05s
# epoch:60 ==>  KL = [1.38521715], logLKH = [-22.03209741], prob_sum = 0.4297, time = 0.05s
# epoch:61 ==>  KL = [1.39956702], logLKH = [-22.23299555], prob_sum = 0.4481, time = 0.05s
# epoch:62 ==>  KL = [1.41396966], logLKH = [-22.43463261], prob_sum = 0.4628, time = 0.05s
# epoch:63 ==>  KL = [1.42622484], logLKH = [-22.6062051], prob_sum = 0.4744, time = 0.05s
# epoch:64 ==>  KL = [1.4424505], logLKH = [-22.83336431], prob_sum = 0.4906, time = 0.05s
# epoch:65 ==>  KL = [1.45862339], logLKH = [-23.05978484], prob_sum = 0.5052, time = 0.05s
# epoch:66 ==>  KL = [1.47578635], logLKH = [-23.3000663], prob_sum = 0.5210, time = 0.05s
# epoch:67 ==>  KL = [1.49605923], logLKH = [-23.58388661], prob_sum = 0.5389, time = 0.05s
# epoch:68 ==>  KL = [1.51351109], logLKH = [-23.82821263], prob_sum = 0.5540, time = 0.05s
# epoch:69 ==>  KL = [1.53189739], logLKH = [-24.08562084], prob_sum = 0.5699, time = 0.05s
# epoch:70 ==>  KL = [1.5515855], logLKH = [-24.36125427], prob_sum = 0.5878, time = 0.05s
# epoch:71 ==>  KL = [1.57066957], logLKH = [-24.62843133], prob_sum = 0.6023, time = 0.05s
# epoch:72 ==>  KL = [1.58978193], logLKH = [-24.89600431], prob_sum = 0.6198, time = 0.05s
# epoch:73 ==>  KL = [1.6089989], logLKH = [-25.16504189], prob_sum = 0.6392, time = 0.05s
# epoch:74 ==>  KL = [1.6289678], logLKH = [-25.44460658], prob_sum = 0.6561, time = 0.05s
# epoch:75 ==>  KL = [1.64695675], logLKH = [-25.69645185], prob_sum = 0.6707, time = 0.05s
# epoch:76 ==>  KL = [1.66137961], logLKH = [-25.8983719], prob_sum = 0.6837, time = 0.05s
# epoch:77 ==>  KL = [1.67422034], logLKH = [-26.07814203], prob_sum = 0.6939, time = 0.05s
# epoch:78 ==>  KL = [1.69295911], logLKH = [-26.34048488], prob_sum = 0.7078, time = 0.05s
# epoch:79 ==>  KL = [1.70759602], logLKH = [-26.54540154], prob_sum = 0.7172, time = 0.05s
# epoch:80 ==>  KL = [1.72398528], logLKH = [-26.77485119], prob_sum = 0.7272, time = 0.05s
# epoch:81 ==>  KL = [1.74012741], logLKH = [-27.00084108], prob_sum = 0.7391, time = 0.05s
# epoch:82 ==>  KL = [1.75600364], logLKH = [-27.22310833], prob_sum = 0.7517, time = 0.05s
# epoch:83 ==>  KL = [1.77568564], logLKH = [-27.4986563], prob_sum = 0.7645, time = 0.05s
# epoch:84 ==>  KL = [1.79398759], logLKH = [-27.75488356], prob_sum = 0.7767, time = 0.05s
# epoch:85 ==>  KL = [1.8157581], logLKH = [-28.05967066], prob_sum = 0.7926, time = 0.05s
# epoch:86 ==>  KL = [1.83135065], logLKH = [-28.27796646], prob_sum = 0.8049, time = 0.05s
# epoch:87 ==>  KL = [1.84966578], logLKH = [-28.53437828], prob_sum = 0.8156, time = 0.05s
# epoch:88 ==>  KL = [1.8714442], logLKH = [-28.83927615], prob_sum = 0.8281, time = 0.05s
# epoch:89 ==>  KL = [1.89057966], logLKH = [-29.10717261], prob_sum = 0.8369, time = 0.05s
# epoch:90 ==>  KL = [1.9033056], logLKH = [-29.2853357], prob_sum = 0.8430, time = 0.05s
# epoch:91 ==>  KL = [1.92123304], logLKH = [-29.53631987], prob_sum = 0.8529, time = 0.06s
# epoch:92 ==>  KL = [1.9371176], logLKH = [-29.75870369], prob_sum = 0.8612, time = 0.05s
# epoch:93 ==>  KL = [1.95719365], logLKH = [-30.03976837], prob_sum = 0.8695, time = 0.05s
# epoch:94 ==>  KL = [1.97898537], logLKH = [-30.34485248], prob_sum = 0.8782, time = 0.05s
# epoch:95 ==>  KL = [1.99680132], logLKH = [-30.59427577], prob_sum = 0.8837, time = 0.05s
# epoch:96 ==>  KL = [2.00919927], logLKH = [-30.76784715], prob_sum = 0.8881, time = 0.05s
# epoch:97 ==>  KL = [2.02746144], logLKH = [-31.02351752], prob_sum = 0.8935, time = 0.05s
# epoch:98 ==>  KL = [2.0499516], logLKH = [-31.33837973], prob_sum = 0.9012, time = 0.05s
# epoch:99 ==>  KL = [2.07126544], logLKH = [-31.63677347], prob_sum = 0.9087, time = 0.05s
# epoch:100 ==>  KL = [2.09126016], logLKH = [-31.91669954], prob_sum = 0.9157, time = 0.05s
# epoch:101 ==>  KL = [2.1082745], logLKH = [-32.15490033], prob_sum = 0.9204, time = 0.05s
# epoch:102 ==>  KL = [2.12716714], logLKH = [-32.4193973], prob_sum = 0.9259, time = 0.05s
# epoch:103 ==>  KL = [2.14546597], logLKH = [-32.67558085], prob_sum = 0.9304, time = 0.05s
# epoch:104 ==>  KL = [2.15852142], logLKH = [-32.85835721], prob_sum = 0.9330, time = 0.05s
# epoch:105 ==>  KL = [2.17762607], logLKH = [-33.1258223], prob_sum = 0.9374, time = 0.05s
# epoch:106 ==>  KL = [2.19988329], logLKH = [-33.43742334], prob_sum = 0.9430, time = 0.05s
# epoch:107 ==>  KL = [2.22070433], logLKH = [-33.72891788], prob_sum = 0.9479, time = 0.05s
# epoch:108 ==>  KL = [2.24322875], logLKH = [-34.04425978], prob_sum = 0.9522, time = 0.05s
# epoch:109 ==>  KL = [2.26096483], logLKH = [-34.29256488], prob_sum = 0.9559, time = 0.05s
# epoch:110 ==>  KL = [2.27773459], logLKH = [-34.5273416], prob_sum = 0.9590, time = 0.05s
# epoch:111 ==>  KL = [2.30020867], logLKH = [-34.84197874], prob_sum = 0.9627, time = 0.05s
# epoch:112 ==>  KL = [2.31616842], logLKH = [-35.06541521], prob_sum = 0.9650, time = 0.05s
# epoch:113 ==>  KL = [2.33547615], logLKH = [-35.3357234], prob_sum = 0.9670, time = 0.05s
# epoch:114 ==>  KL = [2.35324238], logLKH = [-35.58445059], prob_sum = 0.9690, time = 0.05s
# epoch:115 ==>  KL = [2.36685008], logLKH = [-35.77495844], prob_sum = 0.9710, time = 0.05s
# epoch:116 ==>  KL = [2.38011058], logLKH = [-35.96060542], prob_sum = 0.9727, time = 0.05s
# epoch:117 ==>  KL = [2.39479873], logLKH = [-36.16623952], prob_sum = 0.9742, time = 0.05s
# epoch:118 ==>  KL = [2.40642216], logLKH = [-36.32896761], prob_sum = 0.9751, time = 0.05s
# epoch:119 ==>  KL = [2.42343588], logLKH = [-36.56715958], prob_sum = 0.9763, time = 0.05s
# epoch:120 ==>  KL = [2.44188093], logLKH = [-36.82539037], prob_sum = 0.9780, time = 0.05s
# epoch:121 ==>  KL = [2.45301342], logLKH = [-36.98124517], prob_sum = 0.9791, time = 0.05s
# epoch:122 ==>  KL = [2.46425978], logLKH = [-37.13869418], prob_sum = 0.9800, time = 0.05s
# epoch:123 ==>  KL = [2.47966434], logLKH = [-37.35435812], prob_sum = 0.9813, time = 0.05s
# epoch:124 ==>  KL = [2.49199864], logLKH = [-37.52703823], prob_sum = 0.9821, time = 0.05s
# epoch:125 ==>  KL = [2.51329836], logLKH = [-37.82523443], prob_sum = 0.9834, time = 0.05s
# epoch:126 ==>  KL = [2.5331274], logLKH = [-38.10284099], prob_sum = 0.9845, time = 0.05s
# epoch:127 ==>  KL = [2.55160943], logLKH = [-38.36158937], prob_sum = 0.9856, time = 0.05s
# epoch:128 ==>  KL = [2.57177419], logLKH = [-38.64389601], prob_sum = 0.9866, time = 0.05s
# epoch:129 ==>  KL = [2.59416787], logLKH = [-38.95740754], prob_sum = 0.9878, time = 0.05s
# epoch:130 ==>  KL = [2.61754211], logLKH = [-39.28464683], prob_sum = 0.9890, time = 0.05s
# epoch:131 ==>  KL = [2.63003205], logLKH = [-39.45950608], prob_sum = 0.9895, time = 0.05s
# epoch:132 ==>  KL = [2.6423015], logLKH = [-39.63127829], prob_sum = 0.9901, time = 0.05s
# epoch:133 ==>  KL = [2.66636921], logLKH = [-39.96822622], prob_sum = 0.9909, time = 0.05s
# epoch:134 ==>  KL = [2.68765748], logLKH = [-40.26626199], prob_sum = 0.9916, time = 0.05s
# epoch:135 ==>  KL = [2.70056826], logLKH = [-40.44701304], prob_sum = 0.9921, time = 0.05s
# epoch:136 ==>  KL = [2.71921607], logLKH = [-40.70808236], prob_sum = 0.9926, time = 0.05s
# epoch:137 ==>  KL = [2.73477392], logLKH = [-40.92589217], prob_sum = 0.9930, time = 0.05s
# epoch:138 ==>  KL = [2.74919015], logLKH = [-41.12771937], prob_sum = 0.9933, time = 0.05s
# epoch:139 ==>  KL = [2.76097085], logLKH = [-41.2926493], prob_sum = 0.9936, time = 0.05s
# epoch:140 ==>  KL = [2.7731478], logLKH = [-41.46312653], prob_sum = 0.9938, time = 0.05s
# epoch:141 ==>  KL = [2.78631361], logLKH = [-41.64744788], prob_sum = 0.9941, time = 0.05s
# epoch:142 ==>  KL = [2.80316214], logLKH = [-41.88332731], prob_sum = 0.9946, time = 0.05s
# epoch:143 ==>  KL = [2.81973445], logLKH = [-42.11533965], prob_sum = 0.9950, time = 0.05s
# epoch:144 ==>  KL = [2.84239489], logLKH = [-42.43258581], prob_sum = 0.9953, time = 0.05s
# epoch:145 ==>  KL = [2.85677951], logLKH = [-42.6339704], prob_sum = 0.9956, time = 0.05s
# epoch:146 ==>  KL = [2.86971501], logLKH = [-42.81506753], prob_sum = 0.9958, time = 0.05s
# epoch:147 ==>  KL = [2.88136445], logLKH = [-42.97815962], prob_sum = 0.9960, time = 0.05s
# epoch:148 ==>  KL = [2.89231649], logLKH = [-43.13148818], prob_sum = 0.9963, time = 0.05s
# epoch:149 ==>  KL = [2.90870086], logLKH = [-43.36086934], prob_sum = 0.9966, time = 0.05s
# epoch:150 ==>  KL = [2.92401187], logLKH = [-43.57522356], prob_sum = 0.9968, time = 0.05s
# epoch:151 ==>  KL = [2.94460046], logLKH = [-43.86346373], prob_sum = 0.9971, time = 0.05s
# epoch:152 ==>  KL = [2.96421286], logLKH = [-44.13803733], prob_sum = 0.9973, time = 0.05s
# epoch:153 ==>  KL = [2.98404546], logLKH = [-44.41569372], prob_sum = 0.9975, time = 0.05s
# epoch:154 ==>  KL = [3.00244007], logLKH = [-44.67321828], prob_sum = 0.9977, time = 0.05s
# epoch:155 ==>  KL = [3.01738851], logLKH = [-44.88249643], prob_sum = 0.9978, time = 0.05s
# epoch:156 ==>  KL = [3.03623785], logLKH = [-45.1463872], prob_sum = 0.9980, time = 0.05s
# epoch:157 ==>  KL = [3.04759007], logLKH = [-45.30531829], prob_sum = 0.9981, time = 0.05s
# epoch:158 ==>  KL = [3.05454459], logLKH = [-45.40268164], prob_sum = 0.9982, time = 0.05s
# epoch:159 ==>  KL = [3.06722296], logLKH = [-45.58017881], prob_sum = 0.9983, time = 0.05s
# epoch:160 ==>  KL = [3.07839684], logLKH = [-45.73661303], prob_sum = 0.9984, time = 0.05s
# epoch:161 ==>  KL = [3.08814761], logLKH = [-45.87312392], prob_sum = 0.9984, time = 0.05s
# epoch:162 ==>  KL = [3.10314355], logLKH = [-46.083067], prob_sum = 0.9985, time = 0.05s
# epoch:163 ==>  KL = [3.11903123], logLKH = [-46.3054946], prob_sum = 0.9986, time = 0.05s
# epoch:164 ==>  KL = [3.13296642], logLKH = [-46.50058725], prob_sum = 0.9987, time = 0.05s
# epoch:165 ==>  KL = [3.14649238], logLKH = [-46.68995064], prob_sum = 0.9988, time = 0.05s
# epoch:166 ==>  KL = [3.16524858], logLKH = [-46.95253739], prob_sum = 0.9988, time = 0.05s
# epoch:167 ==>  KL = [3.18303229], logLKH = [-47.20150944], prob_sum = 0.9989, time = 0.05s
# epoch:168 ==>  KL = [3.201355], logLKH = [-47.45802728], prob_sum = 0.9990, time = 0.05s
# epoch:169 ==>  KL = [3.22124442], logLKH = [-47.73647922], prob_sum = 0.9991, time = 0.05s
# epoch:170 ==>  KL = [3.24081285], logLKH = [-48.0104372], prob_sum = 0.9992, time = 0.05s
# epoch:171 ==>  KL = [3.25867611], logLKH = [-48.26052286], prob_sum = 0.9993, time = 0.05s
# epoch:172 ==>  KL = [3.26874799], logLKH = [-48.40152913], prob_sum = 0.9993, time = 0.05s
# epoch:173 ==>  KL = [3.28184535], logLKH = [-48.58489229], prob_sum = 0.9993, time = 0.05s
# epoch:174 ==>  KL = [3.29484193], logLKH = [-48.76684434], prob_sum = 0.9994, time = 0.05s
# epoch:175 ==>  KL = [3.30736576], logLKH = [-48.94217795], prob_sum = 0.9994, time = 0.05s
# epoch:176 ==>  KL = [3.32427235], logLKH = [-49.17887024], prob_sum = 0.9995, time = 0.05s
# epoch:177 ==>  KL = [3.33601358], logLKH = [-49.34324738], prob_sum = 0.9995, time = 0.05s
# epoch:178 ==>  KL = [3.34978798], logLKH = [-49.53608911], prob_sum = 0.9995, time = 0.05s
# epoch:179 ==>  KL = [3.36887323], logLKH = [-49.80328256], prob_sum = 0.9995, time = 0.05s
# epoch:180 ==>  KL = [3.38306155], logLKH = [-50.00191906], prob_sum = 0.9996, time = 0.05s
# epoch:181 ==>  KL = [3.39612216], logLKH = [-50.18476762], prob_sum = 0.9996, time = 0.05s
# epoch:182 ==>  KL = [3.40674172], logLKH = [-50.33344141], prob_sum = 0.9996, time = 0.05s
# epoch:183 ==>  KL = [3.42363976], logLKH = [-50.57001397], prob_sum = 0.9996, time = 0.05s
# epoch:184 ==>  KL = [3.44304568], logLKH = [-50.84169682], prob_sum = 0.9997, time = 0.05s
# epoch:185 ==>  KL = [3.45419156], logLKH = [-50.99773915], prob_sum = 0.9997, time = 0.05s
# epoch:186 ==>  KL = [3.46615857], logLKH = [-51.16527727], prob_sum = 0.9997, time = 0.05s
# epoch:187 ==>  KL = [3.48248056], logLKH = [-51.39378513], prob_sum = 0.9997, time = 0.05s
# epoch:188 ==>  KL = [3.50294103], logLKH = [-51.68023173], prob_sum = 0.9997, time = 0.05s
# epoch:189 ==>  KL = [3.52641845], logLKH = [-52.00891569], prob_sum = 0.9998, time = 0.05s
# epoch:190 ==>  KL = [3.54543403], logLKH = [-52.27513374], prob_sum = 0.9998, time = 0.05s
# epoch:191 ==>  KL = [3.56820439], logLKH = [-52.59391875], prob_sum = 0.9998, time = 0.05s
# epoch:192 ==>  KL = [3.58388036], logLKH = [-52.81338235], prob_sum = 0.9998, time = 0.05s
# epoch:193 ==>  KL = [3.6017424], logLKH = [-53.06345098], prob_sum = 0.9998, time = 0.05s
# epoch:194 ==>  KL = [3.62048731], logLKH = [-53.32587972], prob_sum = 0.9998, time = 0.05s
# epoch:195 ==>  KL = [3.63841446], logLKH = [-53.57685975], prob_sum = 0.9999, time = 0.05s
# epoch:196 ==>  KL = [3.65301839], logLKH = [-53.78131482], prob_sum = 0.9999, time = 0.05s
# epoch:197 ==>  KL = [3.67336023], logLKH = [-54.06610054], prob_sum = 0.9999, time = 0.05s
# epoch:198 ==>  KL = [3.68909345], logLKH = [-54.28636558], prob_sum = 0.9999, time = 0.05s
# epoch:199 ==>  KL = [3.70293253], logLKH = [-54.48011272], prob_sum = 0.9999, time = 0.05s
# epoch:200 ==>  KL = [3.71319518], logLKH = [-54.62378991], prob_sum = 0.9999, time = 0.05s
# epoch:201 ==>  KL = [3.72869096], logLKH = [-54.8407308], prob_sum = 0.9999, time = 0.05s
# epoch:202 ==>  KL = [3.74641647], logLKH = [-55.08888794], prob_sum = 0.9999, time = 0.05s
# epoch:203 ==>  KL = [3.76181851], logLKH = [-55.30451649], prob_sum = 0.9999, time = 0.05s
# epoch:204 ==>  KL = [3.78054251], logLKH = [-55.56665252], prob_sum = 0.9999, time = 0.05s
# epoch:205 ==>  KL = [3.79270158], logLKH = [-55.73687951], prob_sum = 0.9999, time = 0.05s
# epoch:206 ==>  KL = [3.80407337], logLKH = [-55.89608444], prob_sum = 0.9999, time = 0.05s
# epoch:207 ==>  KL = [3.81211421], logLKH = [-56.00865632], prob_sum = 0.9999, time = 0.05s
# epoch:208 ==>  KL = [3.82695717], logLKH = [-56.21645774], prob_sum = 0.9999, time = 0.05s
# epoch:209 ==>  KL = [3.84865904], logLKH = [-56.52028386], prob_sum = 0.9999, time = 0.05s
# epoch:210 ==>  KL = [3.86162572], logLKH = [-56.70181745], prob_sum = 0.9999, time = 0.05s
# epoch:211 ==>  KL = [3.87889164], logLKH = [-56.94354025], prob_sum = 0.9999, time = 0.05s
# epoch:212 ==>  KL = [3.89746104], logLKH = [-57.20351195], prob_sum = 0.9999, time = 0.05s
# epoch:213 ==>  KL = [3.91073378], logLKH = [-57.3893303], prob_sum = 1.0000, time = 0.05s
# epoch:214 ==>  KL = [3.93258313], logLKH = [-57.69522113], prob_sum = 1.0000, time = 0.05s
# epoch:215 ==>  KL = [3.94509164], logLKH = [-57.87034031], prob_sum = 1.0000, time = 0.05s
# epoch:216 ==>  KL = [3.95789417], logLKH = [-58.04957576], prob_sum = 1.0000, time = 0.05s
# epoch:217 ==>  KL = [3.96694923], logLKH = [-58.17634651], prob_sum = 1.0000, time = 0.05s
# epoch:218 ==>  KL = [3.9791613], logLKH = [-58.34731559], prob_sum = 1.0000, time = 0.05s
# epoch:219 ==>  KL = [3.98980973], logLKH = [-58.49639355], prob_sum = 1.0000, time = 0.05s
# epoch:220 ==>  KL = [4.00320238], logLKH = [-58.68389068], prob_sum = 1.0000, time = 0.05s
# epoch:221 ==>  KL = [4.0193507], logLKH = [-58.90996718], prob_sum = 1.0000, time = 0.05s
# epoch:222 ==>  KL = [4.03662521], logLKH = [-59.15181028], prob_sum = 1.0000, time = 0.05s
# epoch:223 ==>  KL = [4.05067276], logLKH = [-59.34847594], prob_sum = 1.0000, time = 0.05s
# epoch:224 ==>  KL = [4.07050804], logLKH = [-59.62616983], prob_sum = 1.0000, time = 0.05s
# epoch:225 ==>  KL = [4.08745363], logLKH = [-59.86340813], prob_sum = 1.0000, time = 0.05s
# epoch:226 ==>  KL = [4.09782067], logLKH = [-60.00854665], prob_sum = 1.0000, time = 0.05s
# epoch:227 ==>  KL = [4.11238327], logLKH = [-60.21242306], prob_sum = 1.0000, time = 0.05s
# epoch:228 ==>  KL = [4.11501514], logLKH = [-60.24926928], prob_sum = 1.0000, time = 0.05s
# epoch:229 ==>  KL = [4.12159056], logLKH = [-60.34132521], prob_sum = 1.0000, time = 0.05s
# epoch:230 ==>  KL = [4.12637173], logLKH = [-60.40826155], prob_sum = 1.0000, time = 0.05s
# epoch:231 ==>  KL = [4.13504074], logLKH = [-60.52962764], prob_sum = 1.0000, time = 0.05s
# epoch:232 ==>  KL = [4.15483018], logLKH = [-60.80667983], prob_sum = 1.0000, time = 0.05s
# epoch:233 ==>  KL = [4.17723336], logLKH = [-61.12032442], prob_sum = 1.0000, time = 0.05s
# epoch:234 ==>  KL = [4.19491994], logLKH = [-61.36793647], prob_sum = 1.0000, time = 0.05s
# epoch:235 ==>  KL = [4.20825507], logLKH = [-61.55462828], prob_sum = 1.0000, time = 0.05s
# epoch:236 ==>  KL = [4.22023067], logLKH = [-61.72228674], prob_sum = 1.0000, time = 0.05s
# epoch:237 ==>  KL = [4.22943066], logLKH = [-61.85108661], prob_sum = 1.0000, time = 0.05s
# epoch:238 ==>  KL = [4.23876513], logLKH = [-61.98176921], prob_sum = 1.0000, time = 0.05s
# epoch:239 ==>  KL = [4.25253446], logLKH = [-62.17453974], prob_sum = 1.0000, time = 0.05s
# epoch:240 ==>  KL = [4.27238108], logLKH = [-62.4523924], prob_sum = 1.0000, time = 0.05s
# epoch:241 ==>  KL = [4.29435421], logLKH = [-62.76001632], prob_sum = 1.0000, time = 0.05s
# epoch:242 ==>  KL = [4.30776952], logLKH = [-62.94783059], prob_sum = 1.0000, time = 0.05s
# epoch:243 ==>  KL = [4.32541116], logLKH = [-63.19481362], prob_sum = 1.0000, time = 0.05s
# epoch:244 ==>  KL = [4.34580504], logLKH = [-63.48032784], prob_sum = 1.0000, time = 0.05s
# epoch:245 ==>  KL = [4.3631797], logLKH = [-63.72357311], prob_sum = 1.0000, time = 0.05s
# epoch:246 ==>  KL = [4.38536529], logLKH = [-64.03417141], prob_sum = 1.0000, time = 0.05s
# epoch:247 ==>  KL = [4.41058888], logLKH = [-64.38730165], prob_sum = 1.0000, time = 0.05s
# epoch:248 ==>  KL = [4.43326037], logLKH = [-64.70470252], prob_sum = 1.0000, time = 0.05s
# epoch:249 ==>  KL = [4.45403215], logLKH = [-64.99550742], prob_sum = 1.0000, time = 0.05s
# epoch:250 ==>  KL = [4.47135997], logLKH = [-65.23809686], prob_sum = 1.0000, time = 0.05s
# epoch:251 ==>  KL = [4.48510291], logLKH = [-65.430498], prob_sum = 1.0000, time = 0.05s
# epoch:252 ==>  KL = [4.50110111], logLKH = [-65.65447287], prob_sum = 1.0000, time = 0.05s
# epoch:253 ==>  KL = [4.52276085], logLKH = [-65.95770918], prob_sum = 1.0000, time = 0.05s
# epoch:254 ==>  KL = [4.53884274], logLKH = [-66.18285568], prob_sum = 1.0000, time = 0.05s
# epoch:255 ==>  KL = [4.55470929], logLKH = [-66.40498742], prob_sum = 1.0000, time = 0.05s
# epoch:256 ==>  KL = [4.56459068], logLKH = [-66.54332682], prob_sum = 1.0000, time = 0.05s
# epoch:257 ==>  KL = [4.58142581], logLKH = [-66.77901863], prob_sum = 1.0000, time = 0.05s
# epoch:258 ==>  KL = [4.60006935], logLKH = [-67.04002819], prob_sum = 1.0000, time = 0.05s
# epoch:259 ==>  KL = [4.62700778], logLKH = [-67.4171662], prob_sum = 1.0000, time = 0.05s
# epoch:260 ==>  KL = [4.64736857], logLKH = [-67.70221736], prob_sum = 1.0000, time = 0.05s
# epoch:261 ==>  KL = [4.66684056], logLKH = [-67.97482512], prob_sum = 1.0000, time = 0.05s
# epoch:262 ==>  KL = [4.68447052], logLKH = [-68.22164458], prob_sum = 1.0000, time = 0.05s
# epoch:263 ==>  KL = [4.70058039], logLKH = [-68.44718273], prob_sum = 1.0000, time = 0.05s
# epoch:264 ==>  KL = [4.71482853], logLKH = [-68.64665674], prob_sum = 1.0000, time = 0.05s
# epoch:265 ==>  KL = [4.73199097], logLKH = [-68.88693089], prob_sum = 1.0000, time = 0.05s
# epoch:266 ==>  KL = [4.74766955], logLKH = [-69.10643099], prob_sum = 1.0000, time = 0.05s
# epoch:267 ==>  KL = [4.7619272], logLKH = [-69.30603814], prob_sum = 1.0000, time = 0.05s
# epoch:268 ==>  KL = [4.77605055], logLKH = [-69.503765], prob_sum = 1.0000, time = 0.05s
# epoch:269 ==>  KL = [4.79646415], logLKH = [-69.78955547], prob_sum = 1.0000, time = 0.05s
# epoch:270 ==>  KL = [4.80747208], logLKH = [-69.9436664], prob_sum = 1.0000, time = 0.05s
# epoch:271 ==>  KL = [4.82530665], logLKH = [-70.1933504], prob_sum = 1.0000, time = 0.05s
# epoch:272 ==>  KL = [4.84349535], logLKH = [-70.44799224], prob_sum = 1.0000, time = 0.05s
# epoch:273 ==>  KL = [4.85600282], logLKH = [-70.62309687], prob_sum = 1.0000, time = 0.05s
# epoch:274 ==>  KL = [4.87374459], logLKH = [-70.87148166], prob_sum = 1.0000, time = 0.05s
# epoch:275 ==>  KL = [4.89578299], logLKH = [-71.18001922], prob_sum = 1.0000, time = 0.05s
# epoch:276 ==>  KL = [4.9010578], logLKH = [-71.25386647], prob_sum = 1.0000, time = 0.05s
# epoch:277 ==>  KL = [4.91222186], logLKH = [-71.41016336], prob_sum = 1.0000, time = 0.05s
# epoch:278 ==>  KL = [4.93572512], logLKH = [-71.73920908], prob_sum = 1.0000, time = 0.05s
# epoch:279 ==>  KL = [4.95045408], logLKH = [-71.94541442], prob_sum = 1.0000, time = 0.05s
# epoch:280 ==>  KL = [4.96139182], logLKH = [-72.09854278], prob_sum = 1.0000, time = 0.05s
# epoch:281 ==>  KL = [4.97606584], logLKH = [-72.30397915], prob_sum = 1.0000, time = 0.05s
# epoch:282 ==>  KL = [4.99456739], logLKH = [-72.56300082], prob_sum = 1.0000, time = 0.05s
# epoch:283 ==>  KL = [5.01185918], logLKH = [-72.80508579], prob_sum = 1.0000, time = 0.05s
# epoch:284 ==>  KL = [5.01985631], logLKH = [-72.91704562], prob_sum = 1.0000, time = 0.05s
# epoch:285 ==>  KL = [5.02185968], logLKH = [-72.94509292], prob_sum = 1.0000, time = 0.05s
# epoch:286 ==>  KL = [5.0323872], logLKH = [-73.0924781], prob_sum = 1.0000, time = 0.05s
# epoch:287 ==>  KL = [5.03649737], logLKH = [-73.15002045], prob_sum = 1.0000, time = 0.05s
# epoch:288 ==>  KL = [5.04265401], logLKH = [-73.23621346], prob_sum = 1.0000, time = 0.05s
# epoch:289 ==>  KL = [5.05425498], logLKH = [-73.39862706], prob_sum = 1.0000, time = 0.05s
# epoch:290 ==>  KL = [5.06231353], logLKH = [-73.5114468], prob_sum = 1.0000, time = 0.05s
# epoch:291 ==>  KL = [5.07176798], logLKH = [-73.64380901], prob_sum = 1.0000, time = 0.05s
# epoch:292 ==>  KL = [5.08111397], logLKH = [-73.77465297], prob_sum = 1.0000, time = 0.05s
# epoch:293 ==>  KL = [5.09249044], logLKH = [-73.93392352], prob_sum = 1.0000, time = 0.05s
# epoch:294 ==>  KL = [5.09937898], logLKH = [-74.030363], prob_sum = 1.0000, time = 0.05s
# epoch:295 ==>  KL = [5.10627414], logLKH = [-74.12689533], prob_sum = 1.0000, time = 0.05s
# epoch:296 ==>  KL = [5.11816546], logLKH = [-74.29337372], prob_sum = 1.0000, time = 0.05s
# epoch:297 ==>  KL = [5.13412703], logLKH = [-74.5168357], prob_sum = 1.0000, time = 0.05s
# epoch:298 ==>  KL = [5.14907415], logLKH = [-74.72609537], prob_sum = 1.0000, time = 0.05s
# epoch:299 ==>  KL = [5.16530447], logLKH = [-74.95331985], prob_sum = 1.0000, time = 0.05s
# epoch:300 ==>  KL = [5.17541426], logLKH = [-75.09485699], prob_sum = 1.0000, time = 0.05s
# epoch:301 ==>  KL = [5.18625808], logLKH = [-75.24667039], prob_sum = 1.0000, time = 0.05s
# epoch:302 ==>  KL = [5.19459286], logLKH = [-75.36335742], prob_sum = 1.0000, time = 0.05s
# epoch:303 ==>  KL = [5.20835196], logLKH = [-75.55598474], prob_sum = 1.0000, time = 0.05s
# epoch:304 ==>  KL = [5.22930306], logLKH = [-75.84930013], prob_sum = 1.0000, time = 0.05s
# epoch:305 ==>  KL = [5.24940381], logLKH = [-76.13071066], prob_sum = 1.0000, time = 0.05s
# epoch:306 ==>  KL = [5.27006681], logLKH = [-76.41999263], prob_sum = 1.0000, time = 0.05s
# epoch:307 ==>  KL = [5.27525588], logLKH = [-76.49263961], prob_sum = 1.0000, time = 0.05s
# epoch:308 ==>  KL = [5.28615546], logLKH = [-76.64523382], prob_sum = 1.0000, time = 0.05s
# epoch:309 ==>  KL = [5.30360086], logLKH = [-76.88946934], prob_sum = 1.0000, time = 0.05s
# epoch:310 ==>  KL = [5.31931628], logLKH = [-77.10948531], prob_sum = 1.0000, time = 0.05s
# epoch:311 ==>  KL = [5.33489892], logLKH = [-77.32764225], prob_sum = 1.0000, time = 0.05s
# epoch:312 ==>  KL = [5.34781367], logLKH = [-77.50844876], prob_sum = 1.0000, time = 0.05s
# epoch:313 ==>  KL = [5.3578026], logLKH = [-77.64829379], prob_sum = 1.0000, time = 0.05s
# epoch:314 ==>  KL = [5.36586635], logLKH = [-77.76118621], prob_sum = 1.0000, time = 0.05s
# epoch:315 ==>  KL = [5.37626623], logLKH = [-77.90678449], prob_sum = 1.0000, time = 0.05s
# epoch:316 ==>  KL = [5.38552638], logLKH = [-78.03642661], prob_sum = 1.0000, time = 0.05s
# epoch:317 ==>  KL = [5.39519385], logLKH = [-78.17177125], prob_sum = 1.0000, time = 0.05s
# epoch:318 ==>  KL = [5.39981655], logLKH = [-78.23648901], prob_sum = 1.0000, time = 0.05s
# epoch:319 ==>  KL = [5.41151711], logLKH = [-78.40029682], prob_sum = 1.0000, time = 0.05s
# epoch:320 ==>  KL = [5.42974209], logLKH = [-78.6554466], prob_sum = 1.0000, time = 0.05s
# epoch:321 ==>  KL = [5.43373428], logLKH = [-78.71133729], prob_sum = 1.0000, time = 0.05s
# epoch:322 ==>  KL = [5.43527598], logLKH = [-78.73292108], prob_sum = 1.0000, time = 0.05s
# epoch:323 ==>  KL = [5.44695412], logLKH = [-78.89641501], prob_sum = 1.0000, time = 0.05s
# epoch:324 ==>  KL = [5.45668329], logLKH = [-79.03262344], prob_sum = 1.0000, time = 0.05s
# epoch:325 ==>  KL = [5.46456271], logLKH = [-79.14293533], prob_sum = 1.0000, time = 0.05s
# epoch:326 ==>  KL = [5.47401327], logLKH = [-79.27524313], prob_sum = 1.0000, time = 0.05s
# epoch:327 ==>  KL = [5.477295], logLKH = [-79.32118731], prob_sum = 1.0000, time = 0.05s
# epoch:328 ==>  KL = [5.48537878], logLKH = [-79.43436029], prob_sum = 1.0000, time = 0.05s
# epoch:329 ==>  KL = [5.50284459], logLKH = [-79.67888163], prob_sum = 1.0000, time = 0.05s
# epoch:330 ==>  KL = [5.51336041], logLKH = [-79.82610312], prob_sum = 1.0000, time = 0.05s
# epoch:331 ==>  KL = [5.52738651], logLKH = [-80.02246848], prob_sum = 1.0000, time = 0.05s
# epoch:332 ==>  KL = [5.54529382], logLKH = [-80.27317086], prob_sum = 1.0000, time = 0.05s
# epoch:333 ==>  KL = [5.56418275], logLKH = [-80.53761584], prob_sum = 1.0000, time = 0.05s
# epoch:334 ==>  KL = [5.57493973], logLKH = [-80.68821359], prob_sum = 1.0000, time = 0.05s
# epoch:335 ==>  KL = [5.58578083], logLKH = [-80.83998895], prob_sum = 1.0000, time = 0.05s
# epoch:336 ==>  KL = [5.59884361], logLKH = [-81.02286793], prob_sum = 1.0000, time = 0.05s
# epoch:337 ==>  KL = [5.61295255], logLKH = [-81.22039309], prob_sum = 1.0000, time = 0.05s
# epoch:338 ==>  KL = [5.61959268], logLKH = [-81.31335491], prob_sum = 1.0000, time = 0.05s
# epoch:339 ==>  KL = [5.63624311], logLKH = [-81.54646083], prob_sum = 1.0000, time = 0.05s
# epoch:340 ==>  KL = [5.65137656], logLKH = [-81.75832914], prob_sum = 1.0000, time = 0.05s
# epoch:341 ==>  KL = [5.66630975], logLKH = [-81.96739384], prob_sum = 1.0000, time = 0.05s
# epoch:342 ==>  KL = [5.67477535], logLKH = [-82.08591223], prob_sum = 1.0000, time = 0.05s
# epoch:343 ==>  KL = [5.68900596], logLKH = [-82.28514071], prob_sum = 1.0000, time = 0.05s
# epoch:344 ==>  KL = [5.69892202], logLKH = [-82.42396564], prob_sum = 1.0000, time = 0.05s
# epoch:345 ==>  KL = [5.70537129], logLKH = [-82.51425539], prob_sum = 1.0000, time = 0.05s
# epoch:346 ==>  KL = [5.71424982], logLKH = [-82.63855487], prob_sum = 1.0000, time = 0.05s
# epoch:347 ==>  KL = [5.73221914], logLKH = [-82.89012528], prob_sum = 1.0000, time = 0.05s
# epoch:348 ==>  KL = [5.74889076], logLKH = [-83.12352791], prob_sum = 1.0000, time = 0.05s
# epoch:349 ==>  KL = [5.76149246], logLKH = [-83.29995183], prob_sum = 1.0000, time = 0.05s
# epoch:350 ==>  KL = [5.76525325], logLKH = [-83.35260277], prob_sum = 1.0000, time = 0.05s
# epoch:351 ==>  KL = [5.77722274], logLKH = [-83.52017562], prob_sum = 1.0000, time = 0.05s
# epoch:352 ==>  KL = [5.78977037], logLKH = [-83.6958425], prob_sum = 1.0000, time = 0.05s
# epoch:353 ==>  KL = [5.8043155], logLKH = [-83.89947438], prob_sum = 1.0000, time = 0.05s
# epoch:354 ==>  KL = [5.79577329], logLKH = [-83.77988344], prob_sum = 1.0000, time = 0.05s
# epoch:355 ==>  KL = [5.79932767], logLKH = [-83.82964465], prob_sum = 1.0000, time = 0.05s
# epoch:356 ==>  KL = [5.79949358], logLKH = [-83.83196738], prob_sum = 1.0000, time = 0.05s
# epoch:357 ==>  KL = [5.80690028], logLKH = [-83.93566124], prob_sum = 1.0000, time = 0.05s
# epoch:358 ==>  KL = [5.81582018], logLKH = [-84.06053988], prob_sum = 1.0000, time = 0.05s
# epoch:359 ==>  KL = [5.82319513], logLKH = [-84.16378919], prob_sum = 1.0000, time = 0.05s
# epoch:360 ==>  KL = [5.82236076], logLKH = [-84.15210791], prob_sum = 1.0000, time = 0.05s
# epoch:361 ==>  KL = [5.82855705], logLKH = [-84.23885603], prob_sum = 1.0000, time = 0.05s
# epoch:362 ==>  KL = [5.83489589], logLKH = [-84.3275998], prob_sum = 1.0000, time = 0.05s
# epoch:363 ==>  KL = [5.84817271], logLKH = [-84.51347526], prob_sum = 1.0000, time = 0.05s
# epoch:364 ==>  KL = [5.85685084], logLKH = [-84.6349691], prob_sum = 1.0000, time = 0.05s
# epoch:365 ==>  KL = [5.86750081], logLKH = [-84.78406864], prob_sum = 1.0000, time = 0.05s
# epoch:366 ==>  KL = [5.87281016], logLKH = [-84.85839962], prob_sum = 1.0000, time = 0.05s
# epoch:367 ==>  KL = [5.88460348], logLKH = [-85.02350602], prob_sum = 1.0000, time = 0.05s
# epoch:368 ==>  KL = [5.89551798], logLKH = [-85.17630907], prob_sum = 1.0000, time = 0.05s
# epoch:369 ==>  KL = [5.91338546], logLKH = [-85.42645383], prob_sum = 1.0000, time = 0.05s
# epoch:370 ==>  KL = [5.9277069], logLKH = [-85.62695399], prob_sum = 1.0000, time = 0.05s
# epoch:371 ==>  KL = [5.93324794], logLKH = [-85.70452845], prob_sum = 1.0000, time = 0.05s
# epoch:372 ==>  KL = [5.93814149], logLKH = [-85.77303815], prob_sum = 1.0000, time = 0.05s
# epoch:373 ==>  KL = [5.93763572], logLKH = [-85.76595736], prob_sum = 1.0000, time = 0.05s
# epoch:374 ==>  KL = [5.94606219], logLKH = [-85.88392799], prob_sum = 1.0000, time = 0.05s
# epoch:375 ==>  KL = [5.96698981], logLKH = [-86.17691467], prob_sum = 1.0000, time = 0.05s
# epoch:376 ==>  KL = [5.98214177], logLKH = [-86.38904209], prob_sum = 1.0000, time = 0.05s
# epoch:377 ==>  KL = [5.98952572], logLKH = [-86.49241741], prob_sum = 1.0000, time = 0.05s
# epoch:378 ==>  KL = [5.99376202], logLKH = [-86.55172567], prob_sum = 1.0000, time = 0.05s
# epoch:379 ==>  KL = [5.99177379], logLKH = [-86.52389039], prob_sum = 1.0000, time = 0.05s
# epoch:380 ==>  KL = [5.99666417], logLKH = [-86.59235566], prob_sum = 1.0000, time = 0.05s
# epoch:381 ==>  KL = [6.00945812], logLKH = [-86.77147107], prob_sum = 1.0000, time = 0.05s
# epoch:382 ==>  KL = [6.01959222], logLKH = [-86.91334837], prob_sum = 1.0000, time = 0.05s
# epoch:383 ==>  KL = [6.03820898], logLKH = [-87.17398302], prob_sum = 1.0000, time = 0.05s
# epoch:384 ==>  KL = [6.05400911], logLKH = [-87.39518486], prob_sum = 1.0000, time = 0.05s
# epoch:385 ==>  KL = [6.06795131], logLKH = [-87.5903756], prob_sum = 1.0000, time = 0.05s
# epoch:386 ==>  KL = [6.08063913], logLKH = [-87.76800509], prob_sum = 1.0000, time = 0.05s
# epoch:387 ==>  KL = [6.09322494], logLKH = [-87.94420643], prob_sum = 1.0000, time = 0.05s
# epoch:388 ==>  KL = [6.10122623], logLKH = [-88.05622454], prob_sum = 1.0000, time = 0.05s
# epoch:389 ==>  KL = [6.10613113], logLKH = [-88.12489311], prob_sum = 1.0000, time = 0.05s
# epoch:390 ==>  KL = [6.11144471], logLKH = [-88.19928321], prob_sum = 1.0000, time = 0.05s
# epoch:391 ==>  KL = [6.12151949], logLKH = [-88.34033024], prob_sum = 1.0000, time = 0.05s
# epoch:392 ==>  KL = [6.12408203], logLKH = [-88.3762057], prob_sum = 1.0000, time = 0.05s
# epoch:393 ==>  KL = [6.13364104], logLKH = [-88.51003191], prob_sum = 1.0000, time = 0.05s
# epoch:394 ==>  KL = [6.15428125], logLKH = [-88.79899482], prob_sum = 1.0000, time = 0.05s
# epoch:395 ==>  KL = [6.16215765], logLKH = [-88.90926436], prob_sum = 1.0000, time = 0.05s
# epoch:396 ==>  KL = [6.16484361], logLKH = [-88.94686792], prob_sum = 1.0000, time = 0.05s
# epoch:397 ==>  KL = [6.17557793], logLKH = [-89.09714838], prob_sum = 1.0000, time = 0.05s
# epoch:398 ==>  KL = [6.18782262], logLKH = [-89.26857404], prob_sum = 1.0000, time = 0.05s
# epoch:399 ==>  KL = [6.19934015], logLKH = [-89.42981938], prob_sum = 1.0000, time = 0.05s
# epoch:400 ==>  KL = [6.21282642], logLKH = [-89.61862726], prob_sum = 1.0000, time = 0.05s
# epoch:401 ==>  KL = [6.22462518], logLKH = [-89.78380985], prob_sum = 1.0000, time = 0.05s
# epoch:402 ==>  KL = [6.24043493], logLKH = [-90.00514641], prob_sum = 1.0000, time = 0.05s
# epoch:403 ==>  KL = [6.25149008], logLKH = [-90.1599184], prob_sum = 1.0000, time = 0.05s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/92/zgzs76j97j3f_tf8rngzx_580000gn/T/ipykernel_12433/1439723799.py in <module>
#      12
#      13
# ---> 14     Z = compute_Z(train_data.shape[1], rbm.W, rbm.v_bias, rbm.h_bias)
#      15     probability_list = compute_px_with_Z(train_data, rbm.W, rbm.v_bias, rbm.h_bias)
#      16
#
# /var/folders/92/zgzs76j97j3f_tf8rngzx_580000gn/T/ipykernel_12433/3081522062.py in compute_Z(v_dim, W, v_bias, h_bias)
#      33         product = 1
#      34         for j in range(h_bias.shape[1]):
# ---> 35             product = product * (np.exp(np.dot(train_data_one.T, W.T[j]) + h_bias.T[j]) + 1)
#      36         total = exp_av * product
#      37
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

kl_time = [i for i in range(len(KL_list))]
plt.figure(figsize=(5,3))
plt.plot(kl_time, KL_list)
plt.savefig('KL_divergence')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot(kl_time, log_LKH_list)
plt.savefig('log_Likelihood')
plt.show()

# %%
acc = 0
train_data = [train_data[i].astype(int) for i in range(len(train_data))]
for i in range(len(train_data)):
    v0 = train_data[i]
    v0, vk, p_h0_v, p_hk_v = rbm.gibbs_sampling(v0)
    
    acc_i = np.sum(np.where(train_data[i]==vk, 1, 0)/len(train_data[i]))
    print('original_data: {}, sampling_data: {}, acc: {}'.format(train_data[i], vk, acc_i))
# Out:
# original_data: [1 1 1 0 0 0 0 0 0], sampling_data: [[1 1 1 0 0 0 0 0 0]], acc: 1.0
# original_data: [0 0 0 1 1 1 0 0 0], sampling_data: [[0 1 0 1 1 1 0 0 0]], acc: 0.8888888888888888
# original_data: [0 0 0 0 0 0 1 1 1], sampling_data: [[0 0 0 0 0 0 1 1 1]], acc: 1.0
# original_data: [1 1 1 1 1 1 0 0 0], sampling_data: [[0 1 1 0 1 0 0 0 0]], acc: 0.6666666666666667
# original_data: [1 1 1 0 0 0 1 1 1], sampling_data: [[0 1 1 0 0 0 1 1 1]], acc: 0.8888888888888888
# original_data: [0 0 0 1 1 1 1 1 1], sampling_data: [[0 0 0 0 1 1 1 0 1]], acc: 0.7777777777777777
# original_data: [1 0 0 1 0 0 1 0 0], sampling_data: [[1 0 0 1 0 0 1 0 0]], acc: 1.0
# original_data: [0 1 0 0 1 0 0 1 0], sampling_data: [[1 1 0 0 1 0 0 1 0]], acc: 0.8888888888888888
# original_data: [0 0 1 0 0 1 0 0 1], sampling_data: [[0 1 1 0 0 1 0 0 1]], acc: 0.8888888888888888
# original_data: [1 1 0 1 1 0 1 1 0], sampling_data: [[1 1 0 1 1 0 1 1 0]], acc: 1.0
# original_data: [1 0 1 1 0 1 1 0 1], sampling_data: [[1 0 1 1 0 1 1 0 1]], acc: 1.0
# original_data: [0 1 1 0 1 1 0 1 1], sampling_data: [[0 1 1 0 1 1 0 1 1]], acc: 1.0
# original_data: [0 0 0 0 0 0 0 0 0], sampling_data: [[0 0 0 0 0 0 0 0 0]], acc: 1.0
# original_data: [1 1 1 1 1 1 1 1 1], sampling_data: [[1 0 0 1 1 1 1 1 1]], acc: 0.7777777777777777

# %%
import seaborn as sns
sns.barplot(data = probability_list, color='Grey')
# Out:
# <AxesSubplot:>

# %%
with open("3x3.txt") as text01, open("pn3x3.txt", "w+") as text11:
    data = text01.readlines()
    for i in range(len(data)):
        raw_data = data[i][:-1].split(" ")
        for j in range(len(raw_data)):
            raw_data[j] = float(raw_data[j])
            if raw_data[j] == 0:
                raw_data[j] = -1.0
            text11.write(str(raw_data[j]))
            text11.write(str(" "))
        text11.write("\n")
