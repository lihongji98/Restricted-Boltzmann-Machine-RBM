# %%
import numpy as np
import itertools
import time

# %%
class RBM:
    def __init__(self, v_dim, h_dim, lr=5e-4, gibbs_num=1):
        self.v_dim = v_dim
        self.h_dim = h_dim
        self.lr = lr
        self.v_bias = np.random.normal(-0.1, 0.1, size = (1,self.v_dim))
        self.h_bias = np.random.normal(-0.1, 0.1, size =(1,self.h_dim))
        self.W = np.random.normal(size = (self.v_dim, self.h_dim))
        self.gibbs_num = gibbs_num
        self.v_w, self.v_v, self.v_h = 0, 0, 0
        self.momentum = 0.9

    
    # when a input vector V is recieved, p(h=1|v) can be computed
    # using the activition probability, the states of hidden layer could be sampled
    def sample_h(self, v_input):
        var = -(np.dot(v_input, self.W) + self.h_bias)
        p_h_v = 1/(1 + np.exp(2*var))
        #p_h_v = np.tanh(var)
        state_h = self.state_sample(p_h_v)

        return state_h, p_h_v
    
    # in constract, once the states of hidden layer are obtained, p(v=1|h) can be computed
    # with probability, the states of visible layer could be sampled 
    def sample_v(self, h):
        var = -(np.dot(h, self.W.T) + self.v_bias)
        p_v_h = 1/(1 + np.exp(2*var))
        #p_v_h = np.tanh(var)
        state_v = self.state_sample(p_v_h)
        
        return state_v, p_v_h

    def state_sample(self, p):
        state = []
        uni = np.random.uniform(0,1, size=p[0].shape[0])
        for i in range(len(p)):
            condition = np.less(p[i], uni)
            state_node = np.where(condition, -1, 1)
            state.append(state_node)
        return np.array(state).reshape(p.shape[0], p.shape[1])

    # taking use of the visible layer state V(i) and probability p(v|h), k'th V state could be computed 
    # and its corresponding p(h(k)|V).
    def gibbs_sampling(self, v):
        i = 0 
        k = self.gibbs_num
        v_0 = v

        _, p_h0_v = self.sample_h(v_0)

        while bool(i < k):
            state_h, _ = self.sample_h(v)
            state_v, _ = self.sample_v(state_h)
            i += 1

        else: 
            v_k = state_v

            _, p_hk_v = self.sample_h(v_k)
        
        return v_0, v_k, p_h0_v, p_hk_v
        

    # with the refered formulas, the gradient of each parameter(W, b-->h, a-->v) could be computed
    def gradient_compute(self, v_0, v_k, p_h0_v, p_hk_v):
        dw = np.dot(v_0.T, p_h0_v) - np.dot(v_k.T, p_hk_v)
        dh_bias = np.sum(p_h0_v - p_hk_v)
        dv_bias = np.sum(v_0 - v_k)
        
        
        self.v_w = self.momentum * self.v_w + (1 - self.momentum) * dw
        self.v_h = self.momentum * self.v_h + (1 - self.momentum) * dh_bias
        self.v_v = self.momentum * self.v_v + (1 - self.momentum) * dv_bias 

        self.W += self.lr * self.v_w
        self.v_bias += self.lr * self.v_v
        self.h_bias += self.lr * self.v_h 
    # set the number of iteration and go over all the training data (binary vectors) for one epoch.

# %%
def compute_px_with_Z(train_data, W, v_bias, h_bias): 
    probability = []
    for l in range(len(train_data)):
        train_data_one_piece = train_data[l]
        product_value = 1
        exp_av = np.exp(np.dot(v_bias, train_data_one_piece))
        for i in range(h_bias.shape[1]):
            product_value = product_value * (np.exp(np.dot(W.T[i], train_data_one_piece)+ h_bias.T[i]) +
                                             np.exp(-np.dot(W.T[i], train_data_one_piece)- h_bias.T[i]))
        px_with_Z = exp_av * product_value
        probability.append(px_with_Z[0])
    return probability


def compute_Z(v_dim, W, v_bias, h_bias):
    def dic_build(dic_candidate, dim):
        i= 0
        for item in itertools.product('01',repeat=dim):
        #for item in itertools.product(*((x, -x) for x in [1 for i in range(dim)])):
            if i not in dic_candidate:
                dic_candidate[i] = item
            i += 1
        return dic_candidate
        
    dic_v = {}  
    dic_v = dic_build(dic_v, v_dim)

    Z = 0
    for l in range(len(dic_v)):
        train_data_one = np.array(dic_v[l]).astype(int)
        for i in range(len(train_data_one)):
            if train_data_one[i] == 0:
                train_data_one[i] = -1
        exp_av = np.exp(np.dot(v_bias, train_data_one))
        product = 1
        for j in range(h_bias.shape[1]):
            product = product * (np.exp(np.dot(train_data_one.T, W.T[j]) + h_bias.T[j]) +
                                 np.exp(-np.dot(train_data_one.T, W.T[j]) - h_bias.T[j]))
        total = exp_av * product

        Z += total
    return Z

# %%
train_data = np.loadtxt(r'3x3pn.txt')

visible_node_num = train_data.shape[1]
hidden_node_num = 20
lr = 5e-4
gibbs_num = 1

epochs = 10000
batch_size = 1

# %%
rbm = RBM(visible_node_num, hidden_node_num, lr, gibbs_num)

# %%
KL_list = []
log_LKH_list = []

for epoch in range(epochs):
    epoch_start_time = time.time()
    for index in range(0, train_data.shape[0]-batch_size, batch_size):
        v0 = train_data[index: index + batch_size]
        vk = train_data[index: index + batch_size]
        _, p_h0_v = rbm.sample_h(v0)
        v0, vk, p_h0_v, p_hk_v = rbm.gibbs_sampling(v0)
        rbm.gradient_compute(v0, vk, p_h0_v, p_hk_v)
    

    Z = compute_Z(train_data.shape[1], rbm.W, rbm.v_bias, rbm.h_bias) 
    probability_list = compute_px_with_Z(train_data, rbm.W, rbm.v_bias, rbm.h_bias)

    logLKH = 0
    KL = 0
    
    
    for i in range(len(probability_list)):
        px_with_Z = probability_list[i]
        N = len(probability_list)
        log_lkh = np.log(px_with_Z) - np.log(Z) 
        logLKH += log_lkh

        kl = -np.log(N)/N - np.log(px_with_Z)/N + np.log(Z)/N
        KL += kl
    KL /= N
    logLKH /= N
    KL_list.append(KL)
    log_LKH_list.append(logLKH)

    probability_list = [probability_list[i]/Z for i in range(len(probability_list))]
    x = np.sum(probability_list)
    
    epoch_end_time = time.time()
    
    results = 'epoch:{} ==>  KL = {}, logLKH = {}, prob_sum = {:.4f}, time = {:.2f}s'.format(epoch+1, KL, logLKH, x, epoch_end_time-epoch_start_time)
    #f=open("log -1&1.txt","a")
    #f.write(results + '\n')
    #f.close()

    #if(epoch % 10 == 0):
    print(results)
# Out:
# epoch:1 ==>  KL = [1.8513722], logLKH = [-28.55826814], prob_sum = 0.0000, time = 0.10s
# epoch:2 ==>  KL = [1.84640628], logLKH = [-28.48874519], prob_sum = 0.0000, time = 0.07s
# epoch:3 ==>  KL = [1.84102164], logLKH = [-28.41336026], prob_sum = 0.0000, time = 0.07s
# epoch:4 ==>  KL = [1.83522694], logLKH = [-28.33223453], prob_sum = 0.0000, time = 0.07s
# epoch:5 ==>  KL = [1.82977497], logLKH = [-28.25590694], prob_sum = 0.0000, time = 0.07s
# epoch:6 ==>  KL = [1.82315577], logLKH = [-28.16323813], prob_sum = 0.0000, time = 0.07s
# epoch:7 ==>  KL = [1.81812127], logLKH = [-28.09275515], prob_sum = 0.0000, time = 0.07s
# epoch:8 ==>  KL = [1.8134531], logLKH = [-28.02740073], prob_sum = 0.0000, time = 0.09s
# epoch:9 ==>  KL = [1.80787364], logLKH = [-27.94928836], prob_sum = 0.0000, time = 0.07s
# epoch:10 ==>  KL = [1.80130073], logLKH = [-27.85726762], prob_sum = 0.0000, time = 0.07s
# epoch:11 ==>  KL = [1.79621025], logLKH = [-27.78600089], prob_sum = 0.0000, time = 0.08s
# epoch:12 ==>  KL = [1.79096586], logLKH = [-27.71257943], prob_sum = 0.0000, time = 0.07s
# epoch:13 ==>  KL = [1.7828657], logLKH = [-27.59917711], prob_sum = 0.0000, time = 0.07s
# epoch:14 ==>  KL = [1.77345329], logLKH = [-27.46740343], prob_sum = 0.0000, time = 0.08s
# epoch:15 ==>  KL = [1.76615513], logLKH = [-27.36522918], prob_sum = 0.0000, time = 0.09s
# epoch:16 ==>  KL = [1.75848307], logLKH = [-27.25782029], prob_sum = 0.0000, time = 0.07s
# epoch:17 ==>  KL = [1.75182497], logLKH = [-27.16460686], prob_sum = 0.0000, time = 0.07s
# epoch:18 ==>  KL = [1.74578782], logLKH = [-27.08008684], prob_sum = 0.0000, time = 0.08s
# epoch:19 ==>  KL = [1.7392006], logLKH = [-26.98786569], prob_sum = 0.0000, time = 0.07s
# epoch:20 ==>  KL = [1.73152107], logLKH = [-26.88035226], prob_sum = 0.0000, time = 0.07s
# epoch:21 ==>  KL = [1.72424893], logLKH = [-26.77854229], prob_sum = 0.0000, time = 0.08s
# epoch:22 ==>  KL = [1.71693156], logLKH = [-26.67609916], prob_sum = 0.0000, time = 0.07s
# epoch:23 ==>  KL = [1.70929365], logLKH = [-26.56916844], prob_sum = 0.0000, time = 0.07s
# epoch:24 ==>  KL = [1.7026463], logLKH = [-26.47610548], prob_sum = 0.0000, time = 0.08s
# epoch:25 ==>  KL = [1.69565937], logLKH = [-26.37828853], prob_sum = 0.0000, time = 0.08s
# epoch:26 ==>  KL = [1.69061774], logLKH = [-26.30770576], prob_sum = 0.0000, time = 0.07s
# epoch:27 ==>  KL = [1.6856002], logLKH = [-26.23746006], prob_sum = 0.0000, time = 0.08s
# epoch:28 ==>  KL = [1.68091804], logLKH = [-26.17190996], prob_sum = 0.0000, time = 0.07s
# epoch:29 ==>  KL = [1.67723282], logLKH = [-26.12031681], prob_sum = 0.0000, time = 0.07s
# epoch:30 ==>  KL = [1.67326889], logLKH = [-26.0648218], prob_sum = 0.0000, time = 0.07s
# epoch:31 ==>  KL = [1.66808531], logLKH = [-25.99225166], prob_sum = 0.0000, time = 0.09s
# epoch:32 ==>  KL = [1.66269739], logLKH = [-25.91682081], prob_sum = 0.0000, time = 0.07s
# epoch:33 ==>  KL = [1.65667327], logLKH = [-25.83248316], prob_sum = 0.0000, time = 0.07s
# epoch:34 ==>  KL = [1.65047479], logLKH = [-25.74570433], prob_sum = 0.0000, time = 0.09s
# epoch:35 ==>  KL = [1.64641494], logLKH = [-25.68886654], prob_sum = 0.0000, time = 0.08s
# epoch:36 ==>  KL = [1.64451535], logLKH = [-25.66227218], prob_sum = 0.0000, time = 0.08s
# epoch:37 ==>  KL = [1.64223957], logLKH = [-25.63041138], prob_sum = 0.0000, time = 0.08s
# epoch:38 ==>  KL = [1.63860951], logLKH = [-25.57959054], prob_sum = 0.0000, time = 0.07s
# epoch:39 ==>  KL = [1.63387354], logLKH = [-25.51328683], prob_sum = 0.0000, time = 0.07s
# epoch:40 ==>  KL = [1.62841984], logLKH = [-25.43693508], prob_sum = 0.0000, time = 0.08s
# epoch:41 ==>  KL = [1.62279706], logLKH = [-25.35821621], prob_sum = 0.0000, time = 0.07s
# epoch:42 ==>  KL = [1.61825281], logLKH = [-25.29459662], prob_sum = 0.0000, time = 0.07s
# epoch:43 ==>  KL = [1.61249435], logLKH = [-25.21397818], prob_sum = 0.0000, time = 0.07s
# epoch:44 ==>  KL = [1.60629471], logLKH = [-25.12718323], prob_sum = 0.0000, time = 0.07s
# epoch:45 ==>  KL = [1.60104095], logLKH = [-25.05363057], prob_sum = 0.0000, time = 0.07s
# epoch:46 ==>  KL = [1.59368579], logLKH = [-24.95065833], prob_sum = 0.0000, time = 0.08s
# epoch:47 ==>  KL = [1.58760934], logLKH = [-24.86558814], prob_sum = 0.0000, time = 0.07s
# epoch:48 ==>  KL = [1.58223896], logLKH = [-24.79040278], prob_sum = 0.0000, time = 0.07s
# epoch:49 ==>  KL = [1.57704539], logLKH = [-24.71769283], prob_sum = 0.0000, time = 0.08s
# epoch:50 ==>  KL = [1.57363298], logLKH = [-24.66991907], prob_sum = 0.0000, time = 0.07s
# epoch:51 ==>  KL = [1.57146366], logLKH = [-24.6395486], prob_sum = 0.0000, time = 0.07s
# epoch:52 ==>  KL = [1.56805477], logLKH = [-24.59182416], prob_sum = 0.0000, time = 0.08s
# epoch:53 ==>  KL = [1.56363454], logLKH = [-24.52994088], prob_sum = 0.0000, time = 0.07s
# epoch:54 ==>  KL = [1.55948817], logLKH = [-24.47189174], prob_sum = 0.0000, time = 0.07s
# epoch:55 ==>  KL = [1.55545454], logLKH = [-24.41542085], prob_sum = 0.0000, time = 0.07s
# epoch:56 ==>  KL = [1.55065717], logLKH = [-24.34825773], prob_sum = 0.0000, time = 0.10s
# epoch:57 ==>  KL = [1.54612816], logLKH = [-24.28485151], prob_sum = 0.0000, time = 0.08s
# epoch:58 ==>  KL = [1.54178176], logLKH = [-24.22400198], prob_sum = 0.0000, time = 0.07s
# epoch:59 ==>  KL = [1.53629419], logLKH = [-24.14717595], prob_sum = 0.0000, time = 0.07s
# epoch:60 ==>  KL = [1.5295698], logLKH = [-24.05303457], prob_sum = 0.0000, time = 0.10s
# epoch:61 ==>  KL = [1.52332874], logLKH = [-23.96565967], prob_sum = 0.0000, time = 0.07s
# epoch:62 ==>  KL = [1.51678909], logLKH = [-23.87410465], prob_sum = 0.0000, time = 0.07s
# epoch:63 ==>  KL = [1.51105848], logLKH = [-23.79387599], prob_sum = 0.0000, time = 0.07s
# epoch:64 ==>  KL = [1.50575803], logLKH = [-23.71966978], prob_sum = 0.0000, time = 0.10s
# epoch:65 ==>  KL = [1.50008667], logLKH = [-23.64027077], prob_sum = 0.0000, time = 0.07s
# epoch:66 ==>  KL = [1.49302716], logLKH = [-23.54143762], prob_sum = 0.0000, time = 0.07s
# epoch:67 ==>  KL = [1.48789811], logLKH = [-23.46963092], prob_sum = 0.0000, time = 0.08s
# epoch:68 ==>  KL = [1.48285334], logLKH = [-23.39900412], prob_sum = 0.0000, time = 0.08s
# epoch:69 ==>  KL = [1.47850411], logLKH = [-23.33811493], prob_sum = 0.0000, time = 0.07s
# epoch:70 ==>  KL = [1.47392604], logLKH = [-23.27402185], prob_sum = 0.0000, time = 0.07s
# epoch:71 ==>  KL = [1.46914574], logLKH = [-23.20709764], prob_sum = 0.0000, time = 0.07s
# epoch:72 ==>  KL = [1.46565282], logLKH = [-23.15819674], prob_sum = 0.0000, time = 0.07s
# epoch:73 ==>  KL = [1.46165486], logLKH = [-23.1022254], prob_sum = 0.0000, time = 0.08s
# epoch:74 ==>  KL = [1.45820635], logLKH = [-23.05394629], prob_sum = 0.0000, time = 0.08s
# epoch:75 ==>  KL = [1.4548244], logLKH = [-23.00659894], prob_sum = 0.0000, time = 0.07s
# epoch:76 ==>  KL = [1.45255061], logLKH = [-22.97476586], prob_sum = 0.0000, time = 0.07s
# epoch:77 ==>  KL = [1.448646], logLKH = [-22.92010136], prob_sum = 0.0000, time = 0.09s
# epoch:78 ==>  KL = [1.44447765], logLKH = [-22.86174441], prob_sum = 0.0000, time = 0.07s
# epoch:79 ==>  KL = [1.43967595], logLKH = [-22.79452064], prob_sum = 0.0000, time = 0.07s
# epoch:80 ==>  KL = [1.43387835], logLKH = [-22.71335423], prob_sum = 0.0000, time = 0.07s
# epoch:81 ==>  KL = [1.42948106], logLKH = [-22.65179216], prob_sum = 0.0000, time = 0.10s
# epoch:82 ==>  KL = [1.42458038], logLKH = [-22.58318262], prob_sum = 0.0000, time = 0.09s
# epoch:83 ==>  KL = [1.41867019], logLKH = [-22.50043996], prob_sum = 0.0000, time = 0.07s
# epoch:84 ==>  KL = [1.4128531], logLKH = [-22.4190007], prob_sum = 0.0000, time = 0.07s
# epoch:85 ==>  KL = [1.4080508], logLKH = [-22.35176857], prob_sum = 0.0000, time = 0.08s
# epoch:86 ==>  KL = [1.40347126], logLKH = [-22.28765498], prob_sum = 0.0000, time = 0.07s
# epoch:87 ==>  KL = [1.39967991], logLKH = [-22.23457614], prob_sum = 0.0000, time = 0.07s
# epoch:88 ==>  KL = [1.39612661], logLKH = [-22.18482984], prob_sum = 0.0000, time = 0.07s
# epoch:89 ==>  KL = [1.39196447], logLKH = [-22.12655994], prob_sum = 0.0000, time = 0.07s
# epoch:90 ==>  KL = [1.38918919], logLKH = [-22.08770605], prob_sum = 0.0000, time = 0.07s
# epoch:91 ==>  KL = [1.38716467], logLKH = [-22.05936273], prob_sum = 0.0000, time = 0.07s
# epoch:92 ==>  KL = [1.3847885], logLKH = [-22.02609634], prob_sum = 0.0000, time = 0.07s
# epoch:93 ==>  KL = [1.37994402], logLKH = [-21.95827363], prob_sum = 0.0000, time = 0.07s
# epoch:94 ==>  KL = [1.37491107], logLKH = [-21.88781233], prob_sum = 0.0000, time = 0.07s
# epoch:95 ==>  KL = [1.37054481], logLKH = [-21.8266847], prob_sum = 0.0000, time = 0.08s
# epoch:96 ==>  KL = [1.36617355], logLKH = [-21.76548705], prob_sum = 0.0000, time = 0.07s
# epoch:97 ==>  KL = [1.36297224], logLKH = [-21.72066871], prob_sum = 0.0000, time = 0.08s
# epoch:98 ==>  KL = [1.35868924], logLKH = [-21.66070663], prob_sum = 0.0000, time = 0.08s
# epoch:99 ==>  KL = [1.35308523], logLKH = [-21.58225059], prob_sum = 0.0000, time = 0.07s
# epoch:100 ==>  KL = [1.34779464], logLKH = [-21.50818228], prob_sum = 0.0000, time = 0.08s
# epoch:101 ==>  KL = [1.34500435], logLKH = [-21.46911828], prob_sum = 0.0000, time = 0.07s
# epoch:102 ==>  KL = [1.34177588], logLKH = [-21.42391963], prob_sum = 0.0000, time = 0.07s
# epoch:103 ==>  KL = [1.33807203], logLKH = [-21.37206575], prob_sum = 0.0000, time = 0.08s
# epoch:104 ==>  KL = [1.33472194], logLKH = [-21.32516446], prob_sum = 0.0000, time = 0.08s
# epoch:105 ==>  KL = [1.33078536], logLKH = [-21.27005235], prob_sum = 0.0000, time = 0.07s
# epoch:106 ==>  KL = [1.32646843], logLKH = [-21.20961536], prob_sum = 0.0000, time = 0.07s
# epoch:107 ==>  KL = [1.32371586], logLKH = [-21.17107931], prob_sum = 0.0000, time = 0.08s
# epoch:108 ==>  KL = [1.32130436], logLKH = [-21.13731834], prob_sum = 0.0000, time = 0.08s
# epoch:109 ==>  KL = [1.31843935], logLKH = [-21.09720823], prob_sum = 0.0000, time = 0.07s
# epoch:110 ==>  KL = [1.31425165], logLKH = [-21.03858039], prob_sum = 0.0000, time = 0.07s
# epoch:111 ==>  KL = [1.30887148], logLKH = [-20.96325807], prob_sum = 0.0000, time = 0.10s
# epoch:112 ==>  KL = [1.30470111], logLKH = [-20.90487292], prob_sum = 0.0000, time = 0.09s
# epoch:113 ==>  KL = [1.30158359], logLKH = [-20.86122759], prob_sum = 0.0000, time = 0.07s
# epoch:114 ==>  KL = [1.29728091], logLKH = [-20.80099011], prob_sum = 0.0000, time = 0.07s
# epoch:115 ==>  KL = [1.29257961], logLKH = [-20.73517187], prob_sum = 0.0000, time = 0.09s
# epoch:116 ==>  KL = [1.28757125], logLKH = [-20.66505481], prob_sum = 0.0000, time = 0.08s
# epoch:117 ==>  KL = [1.28306413], logLKH = [-20.60195518], prob_sum = 0.0000, time = 0.07s
# epoch:118 ==>  KL = [1.27874371], logLKH = [-20.54146926], prob_sum = 0.0000, time = 0.07s
# epoch:119 ==>  KL = [1.27504595], logLKH = [-20.48970061], prob_sum = 0.0000, time = 0.08s
# epoch:120 ==>  KL = [1.27095575], logLKH = [-20.43243788], prob_sum = 0.0000, time = 0.07s
# epoch:121 ==>  KL = [1.2659424], logLKH = [-20.362251], prob_sum = 0.0000, time = 0.07s
# epoch:122 ==>  KL = [1.26192712], logLKH = [-20.30603707], prob_sum = 0.0000, time = 0.07s
# epoch:123 ==>  KL = [1.25763935], logLKH = [-20.2460082], prob_sum = 0.0000, time = 0.08s
# epoch:124 ==>  KL = [1.25370087], logLKH = [-20.19086945], prob_sum = 0.0000, time = 0.07s
# epoch:125 ==>  KL = [1.249266], logLKH = [-20.12878137], prob_sum = 0.0000, time = 0.07s
# epoch:126 ==>  KL = [1.24570456], logLKH = [-20.07892115], prob_sum = 0.0000, time = 0.07s
# epoch:127 ==>  KL = [1.24362694], logLKH = [-20.04983442], prob_sum = 0.0000, time = 0.07s
# epoch:128 ==>  KL = [1.24117654], logLKH = [-20.01552893], prob_sum = 0.0000, time = 0.08s
# epoch:129 ==>  KL = [1.23726783], logLKH = [-19.96080698], prob_sum = 0.0000, time = 0.08s
# epoch:130 ==>  KL = [1.23336927], logLKH = [-19.90622711], prob_sum = 0.0000, time = 0.07s
# epoch:131 ==>  KL = [1.22995247], logLKH = [-19.85839196], prob_sum = 0.0000, time = 0.07s
# epoch:132 ==>  KL = [1.22804536], logLKH = [-19.83169234], prob_sum = 0.0000, time = 0.10s
# epoch:133 ==>  KL = [1.22624805], logLKH = [-19.80653005], prob_sum = 0.0000, time = 0.07s
# epoch:134 ==>  KL = [1.2239449], logLKH = [-19.77428591], prob_sum = 0.0000, time = 0.07s
# epoch:135 ==>  KL = [1.22075205], logLKH = [-19.72958606], prob_sum = 0.0000, time = 0.07s
# epoch:136 ==>  KL = [1.21784656], logLKH = [-19.68890918], prob_sum = 0.0000, time = 0.07s
# epoch:137 ==>  KL = [1.21326565], logLKH = [-19.62477645], prob_sum = 0.0000, time = 0.07s
# epoch:138 ==>  KL = [1.20961868], logLKH = [-19.57371889], prob_sum = 0.0000, time = 0.07s
# epoch:139 ==>  KL = [1.20713367], logLKH = [-19.53892872], prob_sum = 0.0000, time = 0.08s
# epoch:140 ==>  KL = [1.20394621], logLKH = [-19.49430424], prob_sum = 0.0000, time = 0.07s
# epoch:141 ==>  KL = [1.20005949], logLKH = [-19.43989015], prob_sum = 0.0000, time = 0.08s
# epoch:142 ==>  KL = [1.19762498], logLKH = [-19.40580709], prob_sum = 0.0000, time = 0.07s
# epoch:143 ==>  KL = [1.19524529], logLKH = [-19.37249134], prob_sum = 0.0000, time = 0.07s
# epoch:144 ==>  KL = [1.19231534], logLKH = [-19.33147209], prob_sum = 0.0000, time = 0.08s
# epoch:145 ==>  KL = [1.18875573], logLKH = [-19.28163748], prob_sum = 0.0000, time = 0.09s
# epoch:146 ==>  KL = [1.18504561], logLKH = [-19.22969587], prob_sum = 0.0000, time = 0.07s
# epoch:147 ==>  KL = [1.18194785], logLKH = [-19.18632723], prob_sum = 0.0000, time = 0.07s
# epoch:148 ==>  KL = [1.17916366], logLKH = [-19.14734864], prob_sum = 0.0000, time = 0.08s
# epoch:149 ==>  KL = [1.17630226], logLKH = [-19.10728903], prob_sum = 0.0000, time = 0.09s
# epoch:150 ==>  KL = [1.17305291], logLKH = [-19.06179808], prob_sum = 0.0000, time = 0.07s
# epoch:151 ==>  KL = [1.17036378], logLKH = [-19.0241502], prob_sum = 0.0000, time = 0.07s
# epoch:152 ==>  KL = [1.16648619], logLKH = [-18.969864], prob_sum = 0.0000, time = 0.10s
# epoch:153 ==>  KL = [1.16265782], logLKH = [-18.91626685], prob_sum = 0.0000, time = 0.09s
# epoch:154 ==>  KL = [1.15924496], logLKH = [-18.86848671], prob_sum = 0.0000, time = 0.07s
# epoch:155 ==>  KL = [1.15617862], logLKH = [-18.82555803], prob_sum = 0.0000, time = 0.07s
# epoch:156 ==>  KL = [1.15368915], logLKH = [-18.7907055], prob_sum = 0.0000, time = 0.09s
# epoch:157 ==>  KL = [1.15056944], logLKH = [-18.74702948], prob_sum = 0.0000, time = 0.08s
# epoch:158 ==>  KL = [1.14685259], logLKH = [-18.69499357], prob_sum = 0.0000, time = 0.07s
# epoch:159 ==>  KL = [1.14224448], logLKH = [-18.63047999], prob_sum = 0.0000, time = 0.07s
# epoch:160 ==>  KL = [1.13853013], logLKH = [-18.57847921], prob_sum = 0.0000, time = 0.10s
# epoch:161 ==>  KL = [1.13607601], logLKH = [-18.54412143], prob_sum = 0.0000, time = 0.07s
# epoch:162 ==>  KL = [1.133626], logLKH = [-18.50982127], prob_sum = 0.0000, time = 0.07s
# epoch:163 ==>  KL = [1.13150242], logLKH = [-18.48009115], prob_sum = 0.0000, time = 0.07s
# epoch:164 ==>  KL = [1.1285137], logLKH = [-18.43824909], prob_sum = 0.0000, time = 0.08s
# epoch:165 ==>  KL = [1.12582178], logLKH = [-18.4005622], prob_sum = 0.0000, time = 0.07s
# epoch:166 ==>  KL = [1.12362253], logLKH = [-18.36977279], prob_sum = 0.0000, time = 0.07s
# epoch:167 ==>  KL = [1.12137038], logLKH = [-18.33824259], prob_sum = 0.0000, time = 0.08s
# epoch:168 ==>  KL = [1.11825388], logLKH = [-18.29461159], prob_sum = 0.0000, time = 0.07s
# epoch:169 ==>  KL = [1.11626238], logLKH = [-18.26673061], prob_sum = 0.0000, time = 0.07s
# epoch:170 ==>  KL = [1.113099], logLKH = [-18.2224433], prob_sum = 0.0000, time = 0.08s
# epoch:171 ==>  KL = [1.1096208], logLKH = [-18.17374846], prob_sum = 0.0000, time = 0.07s
# epoch:172 ==>  KL = [1.10507558], logLKH = [-18.1101154], prob_sum = 0.0000, time = 0.07s
# epoch:173 ==>  KL = [1.10053475], logLKH = [-18.04654378], prob_sum = 0.0000, time = 0.08s
# epoch:174 ==>  KL = [1.0969031], logLKH = [-17.99570073], prob_sum = 0.0000, time = 0.08s
# epoch:175 ==>  KL = [1.09435449], logLKH = [-17.96002017], prob_sum = 0.0000, time = 0.07s
# epoch:176 ==>  KL = [1.09129746], logLKH = [-17.91722173], prob_sum = 0.0000, time = 0.07s
# epoch:177 ==>  KL = [1.08846435], logLKH = [-17.87755821], prob_sum = 0.0000, time = 0.10s
# epoch:178 ==>  KL = [1.0845592], logLKH = [-17.82288607], prob_sum = 0.0000, time = 0.07s
# epoch:179 ==>  KL = [1.08118369], logLKH = [-17.77562898], prob_sum = 0.0000, time = 0.07s
# epoch:180 ==>  KL = [1.07773504], logLKH = [-17.72734783], prob_sum = 0.0000, time = 0.07s
# epoch:181 ==>  KL = [1.07440277], logLKH = [-17.68069612], prob_sum = 0.0000, time = 0.07s
# epoch:182 ==>  KL = [1.07163333], logLKH = [-17.64192397], prob_sum = 0.0000, time = 0.07s
# epoch:183 ==>  KL = [1.06958063], logLKH = [-17.61318609], prob_sum = 0.0000, time = 0.08s
# epoch:184 ==>  KL = [1.06763224], logLKH = [-17.58590876], prob_sum = 0.0000, time = 0.08s
# epoch:185 ==>  KL = [1.0649598], logLKH = [-17.54849459], prob_sum = 0.0000, time = 0.07s
# epoch:186 ==>  KL = [1.06218707], logLKH = [-17.50967627], prob_sum = 0.0000, time = 0.08s
# epoch:187 ==>  KL = [1.06025807], logLKH = [-17.48267033], prob_sum = 0.0000, time = 0.08s
# epoch:188 ==>  KL = [1.05792188], logLKH = [-17.4499636], prob_sum = 0.0000, time = 0.07s
# epoch:189 ==>  KL = [1.05523716], logLKH = [-17.41237756], prob_sum = 0.0000, time = 0.07s
# epoch:190 ==>  KL = [1.05221185], logLKH = [-17.37002329], prob_sum = 0.0000, time = 0.10s
# epoch:191 ==>  KL = [1.04857726], logLKH = [-17.31913901], prob_sum = 0.0000, time = 0.08s
# epoch:192 ==>  KL = [1.04596994], logLKH = [-17.28263644], prob_sum = 0.0000, time = 0.07s
# epoch:193 ==>  KL = [1.04389003], logLKH = [-17.25351778], prob_sum = 0.0000, time = 0.08s
# epoch:194 ==>  KL = [1.04060743], logLKH = [-17.20756141], prob_sum = 0.0000, time = 0.07s
# epoch:195 ==>  KL = [1.0365215], logLKH = [-17.15035838], prob_sum = 0.0000, time = 0.07s
# epoch:196 ==>  KL = [1.0334378], logLKH = [-17.10718651], prob_sum = 0.0000, time = 0.07s
# epoch:197 ==>  KL = [1.02999038], logLKH = [-17.0589226], prob_sum = 0.0000, time = 0.08s
# epoch:198 ==>  KL = [1.02738705], logLKH = [-17.02247596], prob_sum = 0.0000, time = 0.07s
# epoch:199 ==>  KL = [1.02560135], logLKH = [-16.9974762], prob_sum = 0.0000, time = 0.07s
# epoch:200 ==>  KL = [1.0227663], logLKH = [-16.95778557], prob_sum = 0.0000, time = 0.08s
# epoch:201 ==>  KL = [1.01974714], logLKH = [-16.91551725], prob_sum = 0.0000, time = 0.07s
# epoch:202 ==>  KL = [1.01780668], logLKH = [-16.88835087], prob_sum = 0.0000, time = 0.07s
# epoch:203 ==>  KL = [1.01528388], logLKH = [-16.85303159], prob_sum = 0.0000, time = 0.08s
# epoch:204 ==>  KL = [1.01305184], logLKH = [-16.82178308], prob_sum = 0.0000, time = 0.07s
# epoch:205 ==>  KL = [1.01060536], logLKH = [-16.78753237], prob_sum = 0.0000, time = 0.07s
# epoch:206 ==>  KL = [1.00798376], logLKH = [-16.75082994], prob_sum = 0.0000, time = 0.07s
# epoch:207 ==>  KL = [1.00532349], logLKH = [-16.71358613], prob_sum = 0.0000, time = 0.07s
# epoch:208 ==>  KL = [1.00281849], logLKH = [-16.67851617], prob_sum = 0.0000, time = 0.07s
# epoch:209 ==>  KL = [1.00061126], logLKH = [-16.64761501], prob_sum = 0.0000, time = 0.07s
# epoch:210 ==>  KL = [0.99847024], logLKH = [-16.61764073], prob_sum = 0.0000, time = 0.08s
# epoch:211 ==>  KL = [0.99477465], logLKH = [-16.5659025], prob_sum = 0.0000, time = 0.07s
# epoch:212 ==>  KL = [0.9914325], logLKH = [-16.51911235], prob_sum = 0.0000, time = 0.07s
# epoch:213 ==>  KL = [0.98873916], logLKH = [-16.48140559], prob_sum = 0.0000, time = 0.07s
# epoch:214 ==>  KL = [0.98570138], logLKH = [-16.43887666], prob_sum = 0.0000, time = 0.10s
# epoch:215 ==>  KL = [0.98356938], logLKH = [-16.40902862], prob_sum = 0.0000, time = 0.07s
# epoch:216 ==>  KL = [0.97995723], logLKH = [-16.35845853], prob_sum = 0.0000, time = 0.07s
# epoch:217 ==>  KL = [0.97687336], logLKH = [-16.31528435], prob_sum = 0.0000, time = 0.08s
# epoch:218 ==>  KL = [0.97555277], logLKH = [-16.29679606], prob_sum = 0.0000, time = 0.07s
# epoch:219 ==>  KL = [0.97421275], logLKH = [-16.2780358], prob_sum = 0.0000, time = 0.07s
# epoch:220 ==>  KL = [0.97244565], logLKH = [-16.2532964], prob_sum = 0.0000, time = 0.08s
# epoch:221 ==>  KL = [0.96959947], logLKH = [-16.21344988], prob_sum = 0.0000, time = 0.08s
# epoch:222 ==>  KL = [0.9662923], logLKH = [-16.16714949], prob_sum = 0.0000, time = 0.07s
# epoch:223 ==>  KL = [0.96294277], logLKH = [-16.12025607], prob_sum = 0.0000, time = 0.08s
# epoch:224 ==>  KL = [0.95992033], logLKH = [-16.07794193], prob_sum = 0.0000, time = 0.07s
# epoch:225 ==>  KL = [0.95854132], logLKH = [-16.05863577], prob_sum = 0.0000, time = 0.07s
# epoch:226 ==>  KL = [0.95682234], logLKH = [-16.03457009], prob_sum = 0.0000, time = 0.07s
# epoch:227 ==>  KL = [0.95285937], logLKH = [-15.97908856], prob_sum = 0.0001, time = 0.07s
# epoch:228 ==>  KL = [0.95005081], logLKH = [-15.93976867], prob_sum = 0.0001, time = 0.07s
# epoch:229 ==>  KL = [0.9483691], logLKH = [-15.91622474], prob_sum = 0.0001, time = 0.08s
# epoch:230 ==>  KL = [0.94728267], logLKH = [-15.90101465], prob_sum = 0.0001, time = 0.07s
# epoch:231 ==>  KL = [0.94575578], logLKH = [-15.87963821], prob_sum = 0.0001, time = 0.07s
# epoch:232 ==>  KL = [0.94319082], logLKH = [-15.84372877], prob_sum = 0.0001, time = 0.08s
# epoch:233 ==>  KL = [0.9403462], logLKH = [-15.80390406], prob_sum = 0.0001, time = 0.08s
# epoch:234 ==>  KL = [0.93807827], logLKH = [-15.77215314], prob_sum = 0.0001, time = 0.07s
# epoch:235 ==>  KL = [0.93579234], logLKH = [-15.74015002], prob_sum = 0.0001, time = 0.07s
# epoch:236 ==>  KL = [0.93361188], logLKH = [-15.70962371], prob_sum = 0.0001, time = 0.08s
# epoch:237 ==>  KL = [0.93142586], logLKH = [-15.6790194], prob_sum = 0.0001, time = 0.07s
# epoch:238 ==>  KL = [0.92947537], logLKH = [-15.65171254], prob_sum = 0.0001, time = 0.07s
# epoch:239 ==>  KL = [0.92798425], logLKH = [-15.63083687], prob_sum = 0.0001, time = 0.07s
# epoch:240 ==>  KL = [0.92522043], logLKH = [-15.5921433], prob_sum = 0.0001, time = 0.08s
# epoch:241 ==>  KL = [0.92285431], logLKH = [-15.5590177], prob_sum = 0.0001, time = 0.07s
# epoch:242 ==>  KL = [0.9206734], logLKH = [-15.52848489], prob_sum = 0.0001, time = 0.07s
# epoch:243 ==>  KL = [0.91862272], logLKH = [-15.49977536], prob_sum = 0.0001, time = 0.08s
# epoch:244 ==>  KL = [0.91678563], logLKH = [-15.47405614], prob_sum = 0.0001, time = 0.08s
# epoch:245 ==>  KL = [0.91507387], logLKH = [-15.45009151], prob_sum = 0.0001, time = 0.07s
# epoch:246 ==>  KL = [0.91183955], logLKH = [-15.40481097], prob_sum = 0.0001, time = 0.07s
# epoch:247 ==>  KL = [0.90823282], logLKH = [-15.35431688], prob_sum = 0.0001, time = 0.08s
# epoch:248 ==>  KL = [0.90521418], logLKH = [-15.31205583], prob_sum = 0.0001, time = 0.07s
# epoch:249 ==>  KL = [0.90331871], logLKH = [-15.28551924], prob_sum = 0.0001, time = 0.07s
# epoch:250 ==>  KL = [0.90147504], logLKH = [-15.2597079], prob_sum = 0.0001, time = 0.08s
# epoch:251 ==>  KL = [0.90027478], logLKH = [-15.24290423], prob_sum = 0.0001, time = 0.07s
# epoch:252 ==>  KL = [0.89962177], logLKH = [-15.23376216], prob_sum = 0.0001, time = 0.07s
# epoch:253 ==>  KL = [0.89846338], logLKH = [-15.21754469], prob_sum = 0.0001, time = 0.08s
# epoch:254 ==>  KL = [0.89665841], logLKH = [-15.19227502], prob_sum = 0.0001, time = 0.10s
# epoch:255 ==>  KL = [0.89506529], logLKH = [-15.16997135], prob_sum = 0.0001, time = 0.07s
# epoch:256 ==>  KL = [0.89310915], logLKH = [-15.14258542], prob_sum = 0.0001, time = 0.07s
# epoch:257 ==>  KL = [0.89135912], logLKH = [-15.11808507], prob_sum = 0.0001, time = 0.07s
# epoch:258 ==>  KL = [0.88987985], logLKH = [-15.09737517], prob_sum = 0.0001, time = 0.09s
# epoch:259 ==>  KL = [0.88900698], logLKH = [-15.08515508], prob_sum = 0.0001, time = 0.08s
# epoch:260 ==>  KL = [0.88767392], logLKH = [-15.06649225], prob_sum = 0.0001, time = 0.07s
# epoch:261 ==>  KL = [0.88636704], logLKH = [-15.04819591], prob_sum = 0.0001, time = 0.09s
# epoch:262 ==>  KL = [0.88521259], logLKH = [-15.03203365], prob_sum = 0.0001, time = 0.07s
# epoch:263 ==>  KL = [0.88447137], logLKH = [-15.02165655], prob_sum = 0.0001, time = 0.07s
# epoch:264 ==>  KL = [0.88320037], logLKH = [-15.00386249], prob_sum = 0.0001, time = 0.07s
# epoch:265 ==>  KL = [0.88186023], logLKH = [-14.98510055], prob_sum = 0.0001, time = 0.07s
# epoch:266 ==>  KL = [0.87978605], logLKH = [-14.95606209], prob_sum = 0.0001, time = 0.07s
# epoch:267 ==>  KL = [0.87865676], logLKH = [-14.94025202], prob_sum = 0.0001, time = 0.07s
# epoch:268 ==>  KL = [0.87678723], logLKH = [-14.91407858], prob_sum = 0.0001, time = 0.08s
# epoch:269 ==>  KL = [0.87529978], logLKH = [-14.89325428], prob_sum = 0.0001, time = 0.07s
# epoch:270 ==>  KL = [0.87453385], logLKH = [-14.88253126], prob_sum = 0.0001, time = 0.07s
# epoch:271 ==>  KL = [0.87290285], logLKH = [-14.85969727], prob_sum = 0.0001, time = 0.08s
# epoch:272 ==>  KL = [0.87055968], logLKH = [-14.82689287], prob_sum = 0.0001, time = 0.09s
# epoch:273 ==>  KL = [0.86799617], logLKH = [-14.79100368], prob_sum = 0.0001, time = 0.08s
# epoch:274 ==>  KL = [0.86707048], logLKH = [-14.77804399], prob_sum = 0.0001, time = 0.07s
# epoch:275 ==>  KL = [0.86619958], logLKH = [-14.76585138], prob_sum = 0.0001, time = 0.10s
# epoch:276 ==>  KL = [0.86516472], logLKH = [-14.75136341], prob_sum = 0.0001, time = 0.09s
# epoch:277 ==>  KL = [0.86368895], logLKH = [-14.73070261], prob_sum = 0.0001, time = 0.07s
# epoch:278 ==>  KL = [0.86157771], logLKH = [-14.70114526], prob_sum = 0.0001, time = 0.07s
# epoch:279 ==>  KL = [0.86014695], logLKH = [-14.68111469], prob_sum = 0.0001, time = 0.08s
# epoch:280 ==>  KL = [0.85849624], logLKH = [-14.65800473], prob_sum = 0.0001, time = 0.07s
# epoch:281 ==>  KL = [0.85729139], logLKH = [-14.64113682], prob_sum = 0.0001, time = 0.07s
# epoch:282 ==>  KL = [0.85549371], logLKH = [-14.61596927], prob_sum = 0.0001, time = 0.07s
# epoch:283 ==>  KL = [0.85361468], logLKH = [-14.58966286], prob_sum = 0.0001, time = 0.07s
# epoch:284 ==>  KL = [0.85224493], logLKH = [-14.57048637], prob_sum = 0.0001, time = 0.07s
# epoch:285 ==>  KL = [0.85067492], logLKH = [-14.54850625], prob_sum = 0.0001, time = 0.08s
# epoch:286 ==>  KL = [0.84942902], logLKH = [-14.53106363], prob_sum = 0.0001, time = 0.07s
# epoch:287 ==>  KL = [0.84790015], logLKH = [-14.5096595], prob_sum = 0.0001, time = 0.07s
# epoch:288 ==>  KL = [0.84634587], logLKH = [-14.48789945], prob_sum = 0.0002, time = 0.07s
# epoch:289 ==>  KL = [0.84523682], logLKH = [-14.47237275], prob_sum = 0.0002, time = 0.09s
# epoch:290 ==>  KL = [0.84417445], logLKH = [-14.45749963], prob_sum = 0.0002, time = 0.07s
# epoch:291 ==>  KL = [0.84270015], logLKH = [-14.4368594], prob_sum = 0.0002, time = 0.07s
# epoch:292 ==>  KL = [0.84084655], logLKH = [-14.41090909], prob_sum = 0.0002, time = 0.09s
# epoch:293 ==>  KL = [0.83832275], logLKH = [-14.37557579], prob_sum = 0.0002, time = 0.07s
# epoch:294 ==>  KL = [0.83666434], logLKH = [-14.35235803], prob_sum = 0.0002, time = 0.07s
# epoch:295 ==>  KL = [0.83554651], logLKH = [-14.33670848], prob_sum = 0.0002, time = 0.07s
# epoch:296 ==>  KL = [0.8350265], logLKH = [-14.32942838], prob_sum = 0.0002, time = 0.07s
# epoch:297 ==>  KL = [0.83453952], logLKH = [-14.32261063], prob_sum = 0.0002, time = 0.07s
# epoch:298 ==>  KL = [0.83360769], logLKH = [-14.30956501], prob_sum = 0.0002, time = 0.07s
# epoch:299 ==>  KL = [0.8316852], logLKH = [-14.28265011], prob_sum = 0.0002, time = 0.10s
# epoch:300 ==>  KL = [0.82983045], logLKH = [-14.25668359], prob_sum = 0.0002, time = 0.10s
# epoch:301 ==>  KL = [0.82782071], logLKH = [-14.22854732], prob_sum = 0.0002, time = 0.07s
# epoch:302 ==>  KL = [0.82585234], logLKH = [-14.20099013], prob_sum = 0.0002, time = 0.07s
# epoch:303 ==>  KL = [0.8242439], logLKH = [-14.17847193], prob_sum = 0.0002, time = 0.08s
# epoch:304 ==>  KL = [0.82253504], logLKH = [-14.15454782], prob_sum = 0.0002, time = 0.08s
# epoch:305 ==>  KL = [0.82139499], logLKH = [-14.13858714], prob_sum = 0.0002, time = 0.07s
# epoch:306 ==>  KL = [0.82013383], logLKH = [-14.12093091], prob_sum = 0.0002, time = 0.07s
# epoch:307 ==>  KL = [0.81781313], logLKH = [-14.08844113], prob_sum = 0.0002, time = 0.09s
# epoch:308 ==>  KL = [0.81515844], logLKH = [-14.05127554], prob_sum = 0.0002, time = 0.07s
# epoch:309 ==>  KL = [0.81361381], logLKH = [-14.02965064], prob_sum = 0.0002, time = 0.07s
# epoch:310 ==>  KL = [0.81211828], logLKH = [-14.00871324], prob_sum = 0.0002, time = 0.07s
# epoch:311 ==>  KL = [0.81117866], logLKH = [-13.99555859], prob_sum = 0.0002, time = 0.09s
# epoch:312 ==>  KL = [0.80995174], logLKH = [-13.9783817], prob_sum = 0.0002, time = 0.08s
# epoch:313 ==>  KL = [0.80918427], logLKH = [-13.96763714], prob_sum = 0.0002, time = 0.08s
# epoch:314 ==>  KL = [0.80795009], logLKH = [-13.95035852], prob_sum = 0.0002, time = 0.09s
# epoch:315 ==>  KL = [0.80663601], logLKH = [-13.93196142], prob_sum = 0.0002, time = 0.07s
# epoch:316 ==>  KL = [0.80576589], logLKH = [-13.91977978], prob_sum = 0.0002, time = 0.07s
# epoch:317 ==>  KL = [0.80435815], logLKH = [-13.9000714], prob_sum = 0.0002, time = 0.07s
# epoch:318 ==>  KL = [0.80340839], logLKH = [-13.88677478], prob_sum = 0.0002, time = 0.08s
# epoch:319 ==>  KL = [0.80181116], logLKH = [-13.86441363], prob_sum = 0.0002, time = 0.07s
# epoch:320 ==>  KL = [0.80012443], logLKH = [-13.84079935], prob_sum = 0.0002, time = 0.07s
# epoch:321 ==>  KL = [0.79922012], logLKH = [-13.82813901], prob_sum = 0.0002, time = 0.07s
# epoch:322 ==>  KL = [0.7983775], logLKH = [-13.81634232], prob_sum = 0.0002, time = 0.09s
# epoch:323 ==>  KL = [0.79715034], logLKH = [-13.79916203], prob_sum = 0.0002, time = 0.07s
# epoch:324 ==>  KL = [0.79546826], logLKH = [-13.775613], prob_sum = 0.0002, time = 0.07s
# epoch:325 ==>  KL = [0.79351467], logLKH = [-13.74826269], prob_sum = 0.0003, time = 0.08s
# epoch:326 ==>  KL = [0.79076453], logLKH = [-13.70976073], prob_sum = 0.0003, time = 0.07s
# epoch:327 ==>  KL = [0.78906178], logLKH = [-13.68592227], prob_sum = 0.0003, time = 0.07s
# epoch:328 ==>  KL = [0.78832663], logLKH = [-13.67563019], prob_sum = 0.0003, time = 0.07s
# epoch:329 ==>  KL = [0.78723197], logLKH = [-13.66030489], prob_sum = 0.0003, time = 0.10s
# epoch:330 ==>  KL = [0.78500306], logLKH = [-13.62910022], prob_sum = 0.0003, time = 0.07s
# epoch:331 ==>  KL = [0.78299487], logLKH = [-13.60098553], prob_sum = 0.0003, time = 0.07s
# epoch:332 ==>  KL = [0.78191756], logLKH = [-13.58590319], prob_sum = 0.0003, time = 0.08s
# epoch:333 ==>  KL = [0.78156661], logLKH = [-13.58098982], prob_sum = 0.0003, time = 0.09s
# epoch:334 ==>  KL = [0.78116656], logLKH = [-13.57538919], prob_sum = 0.0003, time = 0.07s
# epoch:335 ==>  KL = [0.77945722], logLKH = [-13.55145847], prob_sum = 0.0003, time = 0.07s
# epoch:336 ==>  KL = [0.77774842], logLKH = [-13.52753527], prob_sum = 0.0003, time = 0.09s
# epoch:337 ==>  KL = [0.77617724], logLKH = [-13.50553863], prob_sum = 0.0003, time = 0.07s
# epoch:338 ==>  KL = [0.77523802], logLKH = [-13.49238964], prob_sum = 0.0003, time = 0.07s
# epoch:339 ==>  KL = [0.77298141], logLKH = [-13.46079707], prob_sum = 0.0003, time = 0.08s
# epoch:340 ==>  KL = [0.77097452], logLKH = [-13.43270064], prob_sum = 0.0003, time = 0.07s
# epoch:341 ==>  KL = [0.76883657], logLKH = [-13.40276929], prob_sum = 0.0003, time = 0.07s
# epoch:342 ==>  KL = [0.76676792], logLKH = [-13.37380824], prob_sum = 0.0003, time = 0.08s
# epoch:343 ==>  KL = [0.76564272], logLKH = [-13.35805539], prob_sum = 0.0003, time = 0.07s
# epoch:344 ==>  KL = [0.76459175], logLKH = [-13.34334176], prob_sum = 0.0003, time = 0.07s
# epoch:345 ==>  KL = [0.76353408], logLKH = [-13.3285345], prob_sum = 0.0003, time = 0.07s
# epoch:346 ==>  KL = [0.76209901], logLKH = [-13.30844345], prob_sum = 0.0003, time = 0.08s
# epoch:347 ==>  KL = [0.7589603], logLKH = [-13.26450158], prob_sum = 0.0003, time = 0.07s
# epoch:348 ==>  KL = [0.75633147], logLKH = [-13.22769791], prob_sum = 0.0003, time = 0.07s
# epoch:349 ==>  KL = [0.75521827], logLKH = [-13.21211312], prob_sum = 0.0003, time = 0.07s
# epoch:350 ==>  KL = [0.75415079], logLKH = [-13.19716833], prob_sum = 0.0003, time = 0.08s
# epoch:351 ==>  KL = [0.7529564], logLKH = [-13.18044693], prob_sum = 0.0004, time = 0.07s
# epoch:352 ==>  KL = [0.75176574], logLKH = [-13.16377774], prob_sum = 0.0004, time = 0.07s
# epoch:353 ==>  KL = [0.7504622], logLKH = [-13.14552817], prob_sum = 0.0004, time = 0.10s
# epoch:354 ==>  KL = [0.74916666], logLKH = [-13.12739053], prob_sum = 0.0004, time = 0.08s
# epoch:355 ==>  KL = [0.74860083], logLKH = [-13.11946889], prob_sum = 0.0004, time = 0.07s
# epoch:356 ==>  KL = [0.7475647], logLKH = [-13.10496318], prob_sum = 0.0004, time = 0.07s
# epoch:357 ==>  KL = [0.74628403], logLKH = [-13.08703373], prob_sum = 0.0004, time = 0.08s
# epoch:358 ==>  KL = [0.74580708], logLKH = [-13.08035642], prob_sum = 0.0004, time = 0.07s
# epoch:359 ==>  KL = [0.74483087], logLKH = [-13.06668956], prob_sum = 0.0004, time = 0.07s
# epoch:360 ==>  KL = [0.74384506], logLKH = [-13.05288816], prob_sum = 0.0004, time = 0.07s
# epoch:361 ==>  KL = [0.74198776], logLKH = [-13.02688592], prob_sum = 0.0004, time = 0.07s
# epoch:362 ==>  KL = [0.74092926], logLKH = [-13.01206695], prob_sum = 0.0004, time = 0.07s
# epoch:363 ==>  KL = [0.7405151], logLKH = [-13.0062688], prob_sum = 0.0004, time = 0.07s
# epoch:364 ==>  KL = [0.74024416], logLKH = [-13.00247552], prob_sum = 0.0004, time = 0.07s
# epoch:365 ==>  KL = [0.7399267], logLKH = [-12.9980312], prob_sum = 0.0004, time = 0.07s
# epoch:366 ==>  KL = [0.73927595], logLKH = [-12.9889206], prob_sum = 0.0004, time = 0.08s
# epoch:367 ==>  KL = [0.7383446], logLKH = [-12.97588172], prob_sum = 0.0004, time = 0.07s
# epoch:368 ==>  KL = [0.73755991], logLKH = [-12.96489601], prob_sum = 0.0004, time = 0.07s
# epoch:369 ==>  KL = [0.73530361], logLKH = [-12.93330787], prob_sum = 0.0004, time = 0.07s
# epoch:370 ==>  KL = [0.73247508], logLKH = [-12.89370843], prob_sum = 0.0004, time = 0.07s
# epoch:371 ==>  KL = [0.73091879], logLKH = [-12.87192043], prob_sum = 0.0004, time = 0.07s
# epoch:372 ==>  KL = [0.73027882], logLKH = [-12.86296086], prob_sum = 0.0005, time = 0.07s
# epoch:373 ==>  KL = [0.72896071], logLKH = [-12.84450733], prob_sum = 0.0005, time = 0.07s
# epoch:374 ==>  KL = [0.7278214], logLKH = [-12.82855693], prob_sum = 0.0005, time = 0.10s
# epoch:375 ==>  KL = [0.727212], logLKH = [-12.82002534], prob_sum = 0.0005, time = 0.08s
# epoch:376 ==>  KL = [0.72645071], logLKH = [-12.80936724], prob_sum = 0.0005, time = 0.07s
# epoch:377 ==>  KL = [0.72462378], logLKH = [-12.78379032], prob_sum = 0.0005, time = 0.07s
# epoch:378 ==>  KL = [0.72330339], logLKH = [-12.76530479], prob_sum = 0.0005, time = 0.10s
# epoch:379 ==>  KL = [0.72267916], logLKH = [-12.75656561], prob_sum = 0.0005, time = 0.08s
# epoch:380 ==>  KL = [0.72188395], logLKH = [-12.74543261], prob_sum = 0.0005, time = 0.07s
# epoch:381 ==>  KL = [0.72084099], logLKH = [-12.7308312], prob_sum = 0.0005, time = 0.08s
# epoch:382 ==>  KL = [0.72004796], logLKH = [-12.71972878], prob_sum = 0.0005, time = 0.08s
# epoch:383 ==>  KL = [0.71971872], logLKH = [-12.71511943], prob_sum = 0.0005, time = 0.08s
# epoch:384 ==>  KL = [0.7188134], logLKH = [-12.70244495], prob_sum = 0.0005, time = 0.08s
# epoch:385 ==>  KL = [0.71766847], logLKH = [-12.68641592], prob_sum = 0.0005, time = 0.07s
# epoch:386 ==>  KL = [0.71675058], logLKH = [-12.67356539], prob_sum = 0.0005, time = 0.07s
# epoch:387 ==>  KL = [0.71630444], logLKH = [-12.66731945], prob_sum = 0.0006, time = 0.08s
# epoch:388 ==>  KL = [0.71568061], logLKH = [-12.65858586], prob_sum = 0.0006, time = 0.07s
# epoch:389 ==>  KL = [0.71469302], logLKH = [-12.64475956], prob_sum = 0.0006, time = 0.07s
# epoch:390 ==>  KL = [0.71318158], logLKH = [-12.62359949], prob_sum = 0.0006, time = 0.07s
# epoch:391 ==>  KL = [0.71121384], logLKH = [-12.59605112], prob_sum = 0.0006, time = 0.07s
# epoch:392 ==>  KL = [0.710287], logLKH = [-12.58307531], prob_sum = 0.0006, time = 0.07s
# epoch:393 ==>  KL = [0.70979593], logLKH = [-12.57620033], prob_sum = 0.0006, time = 0.08s
# epoch:394 ==>  KL = [0.70956223], logLKH = [-12.57292854], prob_sum = 0.0006, time = 0.07s
# epoch:395 ==>  KL = [0.70904669], logLKH = [-12.56571102], prob_sum = 0.0006, time = 0.07s
# epoch:396 ==>  KL = [0.70799651], logLKH = [-12.55100849], prob_sum = 0.0006, time = 0.07s
# epoch:397 ==>  KL = [0.707103], logLKH = [-12.53849927], prob_sum = 0.0006, time = 0.09s
# epoch:398 ==>  KL = [0.70627663], logLKH = [-12.52693015], prob_sum = 0.0006, time = 0.07s
# epoch:399 ==>  KL = [0.705383], logLKH = [-12.5144194], prob_sum = 0.0006, time = 0.07s
# epoch:400 ==>  KL = [0.70413586], logLKH = [-12.49695936], prob_sum = 0.0007, time = 0.09s
# epoch:401 ==>  KL = [0.70276828], logLKH = [-12.47781328], prob_sum = 0.0007, time = 0.07s
# epoch:402 ==>  KL = [0.70191138], logLKH = [-12.46581659], prob_sum = 0.0007, time = 0.07s
# epoch:403 ==>  KL = [0.70103256], logLKH = [-12.45351321], prob_sum = 0.0007, time = 0.07s
# epoch:404 ==>  KL = [0.69921634], logLKH = [-12.42808607], prob_sum = 0.0007, time = 0.07s
# epoch:405 ==>  KL = [0.69802613], logLKH = [-12.41142311], prob_sum = 0.0007, time = 0.07s
# epoch:406 ==>  KL = [0.69760427], logLKH = [-12.40551715], prob_sum = 0.0007, time = 0.07s
# epoch:407 ==>  KL = [0.69673175], logLKH = [-12.39330178], prob_sum = 0.0007, time = 0.07s
# epoch:408 ==>  KL = [0.69406587], logLKH = [-12.35597946], prob_sum = 0.0007, time = 0.07s
# epoch:409 ==>  KL = [0.69199969], logLKH = [-12.32705294], prob_sum = 0.0007, time = 0.07s
# epoch:410 ==>  KL = [0.69089037], logLKH = [-12.31152251], prob_sum = 0.0007, time = 0.10s
# epoch:411 ==>  KL = [0.6891686], logLKH = [-12.28741776], prob_sum = 0.0008, time = 0.07s
# epoch:412 ==>  KL = [0.68708763], logLKH = [-12.25828415], prob_sum = 0.0008, time = 0.07s
# epoch:413 ==>  KL = [0.6864277], logLKH = [-12.24904517], prob_sum = 0.0008, time = 0.08s
# epoch:414 ==>  KL = [0.68568821], logLKH = [-12.23869224], prob_sum = 0.0008, time = 0.07s
# epoch:415 ==>  KL = [0.68508341], logLKH = [-12.23022502], prob_sum = 0.0008, time = 0.07s
# epoch:416 ==>  KL = [0.68458883], logLKH = [-12.22330097], prob_sum = 0.0008, time = 0.07s
# epoch:417 ==>  KL = [0.68391815], logLKH = [-12.21391149], prob_sum = 0.0008, time = 0.07s
# epoch:418 ==>  KL = [0.68284434], logLKH = [-12.19887806], prob_sum = 0.0008, time = 0.07s
# epoch:419 ==>  KL = [0.68203791], logLKH = [-12.18758808], prob_sum = 0.0008, time = 0.08s
# epoch:420 ==>  KL = [0.68140865], logLKH = [-12.17877845], prob_sum = 0.0008, time = 0.10s
# epoch:421 ==>  KL = [0.679389], logLKH = [-12.15050338], prob_sum = 0.0008, time = 0.07s
# epoch:422 ==>  KL = [0.67795049], logLKH = [-12.13036426], prob_sum = 0.0009, time = 0.07s
# epoch:423 ==>  KL = [0.67703143], logLKH = [-12.11749736], prob_sum = 0.0009, time = 0.07s
# epoch:424 ==>  KL = [0.67632906], logLKH = [-12.10766415], prob_sum = 0.0009, time = 0.10s
# epoch:425 ==>  KL = [0.67606716], logLKH = [-12.10399756], prob_sum = 0.0009, time = 0.08s
# epoch:426 ==>  KL = [0.67529352], logLKH = [-12.09316668], prob_sum = 0.0009, time = 0.07s
# epoch:427 ==>  KL = [0.6743528], logLKH = [-12.07999647], prob_sum = 0.0009, time = 0.07s
# epoch:428 ==>  KL = [0.67377337], logLKH = [-12.07188452], prob_sum = 0.0009, time = 0.10s
# epoch:429 ==>  KL = [0.67337433], logLKH = [-12.06629792], prob_sum = 0.0009, time = 0.07s
# epoch:430 ==>  KL = [0.67315954], logLKH = [-12.06329082], prob_sum = 0.0009, time = 0.07s
# epoch:431 ==>  KL = [0.67278803], logLKH = [-12.0580897], prob_sum = 0.0009, time = 0.07s
# epoch:432 ==>  KL = [0.67138363], logLKH = [-12.0384281], prob_sum = 0.0009, time = 0.10s
# epoch:433 ==>  KL = [0.67091635], logLKH = [-12.03188628], prob_sum = 0.0009, time = 0.07s
# epoch:434 ==>  KL = [0.67052391], logLKH = [-12.0263921], prob_sum = 0.0009, time = 0.07s
# epoch:435 ==>  KL = [0.67004481], logLKH = [-12.01968466], prob_sum = 0.0009, time = 0.07s
# epoch:436 ==>  KL = [0.66928799], logLKH = [-12.00908914], prob_sum = 0.0009, time = 0.07s
# epoch:437 ==>  KL = [0.6689211], logLKH = [-12.00395267], prob_sum = 0.0009, time = 0.07s
# epoch:438 ==>  KL = [0.66890967], logLKH = [-12.00379271], prob_sum = 0.0009, time = 0.08s
# epoch:439 ==>  KL = [0.66853899], logLKH = [-11.9986032], prob_sum = 0.0009, time = 0.08s
# epoch:440 ==>  KL = [0.6676201], logLKH = [-11.98573877], prob_sum = 0.0009, time = 0.07s
# epoch:441 ==>  KL = [0.66648687], logLKH = [-11.96987354], prob_sum = 0.0009, time = 0.07s
# epoch:442 ==>  KL = [0.66546857], logLKH = [-11.95561733], prob_sum = 0.0009, time = 0.08s
# epoch:443 ==>  KL = [0.66357777], logLKH = [-11.92914615], prob_sum = 0.0010, time = 0.08s
# epoch:444 ==>  KL = [0.66165024], logLKH = [-11.90216063], prob_sum = 0.0010, time = 0.07s
# epoch:445 ==>  KL = [0.66096079], logLKH = [-11.89250836], prob_sum = 0.0010, time = 0.07s
# epoch:446 ==>  KL = [0.66001701], logLKH = [-11.87929552], prob_sum = 0.0010, time = 0.09s
# epoch:447 ==>  KL = [0.65889063], logLKH = [-11.86352621], prob_sum = 0.0010, time = 0.08s
# epoch:448 ==>  KL = [0.65830059], logLKH = [-11.85526556], prob_sum = 0.0010, time = 0.07s
# epoch:449 ==>  KL = [0.65822859], logLKH = [-11.85425764], prob_sum = 0.0010, time = 0.07s
# epoch:450 ==>  KL = [0.65810293], logLKH = [-11.85249833], prob_sum = 0.0010, time = 0.09s
# epoch:451 ==>  KL = [0.65792531], logLKH = [-11.85001163], prob_sum = 0.0010, time = 0.07s
# epoch:452 ==>  KL = [0.65748037], logLKH = [-11.84378252], prob_sum = 0.0010, time = 0.07s
# epoch:453 ==>  KL = [0.65716823], logLKH = [-11.83941262], prob_sum = 0.0010, time = 0.07s
# epoch:454 ==>  KL = [0.65671639], logLKH = [-11.83308674], prob_sum = 0.0010, time = 0.07s
# epoch:455 ==>  KL = [0.65590086], logLKH = [-11.82166931], prob_sum = 0.0010, time = 0.07s
# epoch:456 ==>  KL = [0.65405184], logLKH = [-11.79578307], prob_sum = 0.0011, time = 0.07s
# epoch:457 ==>  KL = [0.65247242], logLKH = [-11.7736712], prob_sum = 0.0011, time = 0.07s
# epoch:458 ==>  KL = [0.65168239], logLKH = [-11.76261082], prob_sum = 0.0011, time = 0.07s
# epoch:459 ==>  KL = [0.65128788], logLKH = [-11.75708771], prob_sum = 0.0011, time = 0.07s
# epoch:460 ==>  KL = [0.65113731], logLKH = [-11.7549797], prob_sum = 0.0011, time = 0.07s
# epoch:461 ==>  KL = [0.65043784], logLKH = [-11.74518715], prob_sum = 0.0011, time = 0.07s
# epoch:462 ==>  KL = [0.64891778], logLKH = [-11.72390629], prob_sum = 0.0011, time = 0.07s
# epoch:463 ==>  KL = [0.64811794], logLKH = [-11.71270843], prob_sum = 0.0011, time = 0.10s
# epoch:464 ==>  KL = [0.64736519], logLKH = [-11.70217002], prob_sum = 0.0011, time = 0.07s
# epoch:465 ==>  KL = [0.64694937], logLKH = [-11.69634847], prob_sum = 0.0012, time = 0.07s
# epoch:466 ==>  KL = [0.64601591], logLKH = [-11.68328012], prob_sum = 0.0012, time = 0.08s
# epoch:467 ==>  KL = [0.64471448], logLKH = [-11.66506001], prob_sum = 0.0012, time = 0.07s
# epoch:468 ==>  KL = [0.6435852], logLKH = [-11.64925018], prob_sum = 0.0012, time = 0.07s
# epoch:469 ==>  KL = [0.64276021], logLKH = [-11.63770033], prob_sum = 0.0012, time = 0.07s
# epoch:470 ==>  KL = [0.64254164], logLKH = [-11.63464031], prob_sum = 0.0012, time = 0.07s
# epoch:471 ==>  KL = [0.64189546], logLKH = [-11.62559382], prob_sum = 0.0012, time = 0.07s
# epoch:472 ==>  KL = [0.64047487], logLKH = [-11.60570555], prob_sum = 0.0013, time = 0.07s
# epoch:473 ==>  KL = [0.63919517], logLKH = [-11.58778976], prob_sum = 0.0013, time = 0.10s
# epoch:474 ==>  KL = [0.63845043], logLKH = [-11.57736336], prob_sum = 0.0013, time = 0.07s
# epoch:475 ==>  KL = [0.63788858], logLKH = [-11.56949743], prob_sum = 0.0013, time = 0.07s
# epoch:476 ==>  KL = [0.63668593], logLKH = [-11.55266042], prob_sum = 0.0013, time = 0.07s
# epoch:477 ==>  KL = [0.63587755], logLKH = [-11.54134299], prob_sum = 0.0013, time = 0.08s
# epoch:478 ==>  KL = [0.63524896], logLKH = [-11.53254282], prob_sum = 0.0013, time = 0.07s
# epoch:479 ==>  KL = [0.63450898], logLKH = [-11.52218299], prob_sum = 0.0014, time = 0.07s
# epoch:480 ==>  KL = [0.63383779], logLKH = [-11.51278637], prob_sum = 0.0014, time = 0.10s
# epoch:481 ==>  KL = [0.63342026], logLKH = [-11.50694101], prob_sum = 0.0014, time = 0.07s
# epoch:482 ==>  KL = [0.63283901], logLKH = [-11.49880343], prob_sum = 0.0014, time = 0.07s
# epoch:483 ==>  KL = [0.6321392], logLKH = [-11.48900619], prob_sum = 0.0014, time = 0.07s
# epoch:484 ==>  KL = [0.63177148], logLKH = [-11.48385804], prob_sum = 0.0014, time = 0.08s
# epoch:485 ==>  KL = [0.63098881], logLKH = [-11.47290066], prob_sum = 0.0015, time = 0.07s
# epoch:486 ==>  KL = [0.62971929], logLKH = [-11.45512743], prob_sum = 0.0015, time = 0.07s
# epoch:487 ==>  KL = [0.62828275], logLKH = [-11.43501585], prob_sum = 0.0015, time = 0.07s
# epoch:488 ==>  KL = [0.62722039], logLKH = [-11.42014284], prob_sum = 0.0015, time = 0.07s
# epoch:489 ==>  KL = [0.62662786], logLKH = [-11.41184731], prob_sum = 0.0015, time = 0.07s
# epoch:490 ==>  KL = [0.62565642], logLKH = [-11.39824725], prob_sum = 0.0016, time = 0.07s
# epoch:491 ==>  KL = [0.6249681], logLKH = [-11.38861071], prob_sum = 0.0015, time = 0.07s
# epoch:492 ==>  KL = [0.62423279], logLKH = [-11.37831645], prob_sum = 0.0016, time = 0.07s
# epoch:493 ==>  KL = [0.62393292], logLKH = [-11.37411826], prob_sum = 0.0016, time = 0.07s
# epoch:494 ==>  KL = [0.62386785], logLKH = [-11.3732072], prob_sum = 0.0016, time = 0.09s
# epoch:495 ==>  KL = [0.62263025], logLKH = [-11.35588082], prob_sum = 0.0016, time = 0.07s
# epoch:496 ==>  KL = [0.62170664], logLKH = [-11.34295024], prob_sum = 0.0016, time = 0.07s
# epoch:497 ==>  KL = [0.62112451], logLKH = [-11.33480042], prob_sum = 0.0016, time = 0.09s
# epoch:498 ==>  KL = [0.62043032], logLKH = [-11.32508178], prob_sum = 0.0016, time = 0.07s
# epoch:499 ==>  KL = [0.62008464], logLKH = [-11.32024226], prob_sum = 0.0016, time = 0.07s
# epoch:500 ==>  KL = [0.61956395], logLKH = [-11.31295269], prob_sum = 0.0017, time = 0.07s
# epoch:501 ==>  KL = [0.61855879], logLKH = [-11.29888039], prob_sum = 0.0017, time = 0.10s
# epoch:502 ==>  KL = [0.61776048], logLKH = [-11.28770405], prob_sum = 0.0017, time = 0.07s
# epoch:503 ==>  KL = [0.61721608], logLKH = [-11.28008247], prob_sum = 0.0017, time = 0.07s
# epoch:504 ==>  KL = [0.61686423], logLKH = [-11.27515657], prob_sum = 0.0018, time = 0.07s
# epoch:505 ==>  KL = [0.61630839], logLKH = [-11.2673748], prob_sum = 0.0017, time = 0.09s
# epoch:506 ==>  KL = [0.61580151], logLKH = [-11.26027847], prob_sum = 0.0017, time = 0.08s
# epoch:507 ==>  KL = [0.61567843], logLKH = [-11.25855537], prob_sum = 0.0017, time = 0.07s
# epoch:508 ==>  KL = [0.61506127], logLKH = [-11.2499151], prob_sum = 0.0018, time = 0.07s
# epoch:509 ==>  KL = [0.61428069], logLKH = [-11.23898697], prob_sum = 0.0018, time = 0.10s
# epoch:510 ==>  KL = [0.61291226], logLKH = [-11.219829], prob_sum = 0.0018, time = 0.07s
# epoch:511 ==>  KL = [0.61232062], logLKH = [-11.21154599], prob_sum = 0.0018, time = 0.07s
# epoch:512 ==>  KL = [0.61195196], logLKH = [-11.20638473], prob_sum = 0.0018, time = 0.07s
# epoch:513 ==>  KL = [0.61167205], logLKH = [-11.20246602], prob_sum = 0.0018, time = 0.09s
# epoch:514 ==>  KL = [0.61150152], logLKH = [-11.20007856], prob_sum = 0.0018, time = 0.07s
# epoch:515 ==>  KL = [0.6108742], logLKH = [-11.1912961], prob_sum = 0.0018, time = 0.07s
# epoch:516 ==>  KL = [0.6097319], logLKH = [-11.17530394], prob_sum = 0.0018, time = 0.08s
# epoch:517 ==>  KL = [0.60924664], logLKH = [-11.16851032], prob_sum = 0.0018, time = 0.07s
# epoch:518 ==>  KL = [0.60857957], logLKH = [-11.15917128], prob_sum = 0.0019, time = 0.07s
# epoch:519 ==>  KL = [0.60729859], logLKH = [-11.14123758], prob_sum = 0.0019, time = 0.07s
# epoch:520 ==>  KL = [0.60599813], logLKH = [-11.12303118], prob_sum = 0.0019, time = 0.07s
# epoch:521 ==>  KL = [0.60483027], logLKH = [-11.10668105], prob_sum = 0.0020, time = 0.07s
# epoch:522 ==>  KL = [0.60429719], logLKH = [-11.09921803], prob_sum = 0.0020, time = 0.07s
# epoch:523 ==>  KL = [0.60387614], logLKH = [-11.09332326], prob_sum = 0.0020, time = 0.07s
# epoch:524 ==>  KL = [0.60302046], logLKH = [-11.08134372], prob_sum = 0.0020, time = 0.08s
# epoch:525 ==>  KL = [0.60248772], logLKH = [-11.07388546], prob_sum = 0.0020, time = 0.07s
# epoch:526 ==>  KL = [0.60204107], logLKH = [-11.06763227], prob_sum = 0.0020, time = 0.07s
# epoch:527 ==>  KL = [0.60134858], logLKH = [-11.05793745], prob_sum = 0.0020, time = 0.08s
# epoch:528 ==>  KL = [0.60100812], logLKH = [-11.05317107], prob_sum = 0.0020, time = 0.07s
# epoch:529 ==>  KL = [0.59999749], logLKH = [-11.03902215], prob_sum = 0.0020, time = 0.07s
# ...
# epoch:9825 ==>  KL = [0.05924364], logLKH = [-3.46846833], prob_sum = 0.8943, time = 0.09s
# epoch:9826 ==>  KL = [0.05923467], logLKH = [-3.4683427], prob_sum = 0.8944, time = 0.07s
# epoch:9827 ==>  KL = [0.0592324], logLKH = [-3.46831096], prob_sum = 0.8944, time = 0.07s
# epoch:9828 ==>  KL = [0.05923183], logLKH = [-3.4683029], prob_sum = 0.8944, time = 0.07s
# epoch:9829 ==>  KL = [0.05923168], logLKH = [-3.46830085], prob_sum = 0.8944, time = 0.07s
# epoch:9830 ==>  KL = [0.05923164], logLKH = [-3.46830033], prob_sum = 0.8944, time = 0.07s
# epoch:9831 ==>  KL = [0.05920043], logLKH = [-3.46786339], prob_sum = 0.8944, time = 0.07s
# epoch:9832 ==>  KL = [0.05899275], logLKH = [-3.46495588], prob_sum = 0.8942, time = 0.07s
# epoch:9833 ==>  KL = [0.05894045], logLKH = [-3.46422366], prob_sum = 0.8942, time = 0.07s
# epoch:9834 ==>  KL = [0.05892719], logLKH = [-3.46403799], prob_sum = 0.8942, time = 0.07s
# epoch:9835 ==>  KL = [0.05892382], logLKH = [-3.46399082], prob_sum = 0.8942, time = 0.07s
# epoch:9836 ==>  KL = [0.05877746], logLKH = [-3.4619417], prob_sum = 0.8944, time = 0.07s
# epoch:9837 ==>  KL = [0.05874076], logLKH = [-3.46142791], prob_sum = 0.8945, time = 0.07s
# epoch:9838 ==>  KL = [0.05873146], logLKH = [-3.46129776], prob_sum = 0.8945, time = 0.07s
# epoch:9839 ==>  KL = [0.05877264], logLKH = [-3.46187426], prob_sum = 0.8948, time = 0.07s
# epoch:9840 ==>  KL = [0.05878749], logLKH = [-3.46208223], prob_sum = 0.8950, time = 0.07s
# epoch:9841 ==>  KL = [0.05879132], logLKH = [-3.46213578], prob_sum = 0.8950, time = 0.07s
# epoch:9842 ==>  KL = [0.05879229], logLKH = [-3.46214943], prob_sum = 0.8950, time = 0.07s
# epoch:9843 ==>  KL = [0.0588155], logLKH = [-3.4624744], prob_sum = 0.8951, time = 0.07s
# epoch:9844 ==>  KL = [0.05886251], logLKH = [-3.46313252], prob_sum = 0.8952, time = 0.07s
# epoch:9845 ==>  KL = [0.05887465], logLKH = [-3.46330241], prob_sum = 0.8952, time = 0.07s
# epoch:9846 ==>  KL = [0.05887775], logLKH = [-3.46334576], prob_sum = 0.8953, time = 0.07s
# epoch:9847 ==>  KL = [0.05887746], logLKH = [-3.46334173], prob_sum = 0.8953, time = 0.07s
# epoch:9848 ==>  KL = [0.05887505], logLKH = [-3.46330806], prob_sum = 0.8954, time = 0.07s
# epoch:9849 ==>  KL = [0.05887464], logLKH = [-3.46330227], prob_sum = 0.8955, time = 0.07s
# epoch:9850 ==>  KL = [0.0588836], logLKH = [-3.46342768], prob_sum = 0.8956, time = 0.08s
# epoch:9851 ==>  KL = [0.05891582], logLKH = [-3.4638788], prob_sum = 0.8958, time = 0.07s
# epoch:9852 ==>  KL = [0.0589242], logLKH = [-3.46399607], prob_sum = 0.8959, time = 0.07s
# epoch:9853 ==>  KL = [0.05892634], logLKH = [-3.46402605], prob_sum = 0.8959, time = 0.07s
# epoch:9854 ==>  KL = [0.05899289], logLKH = [-3.46495776], prob_sum = 0.8961, time = 0.07s
# epoch:9855 ==>  KL = [0.05886922], logLKH = [-3.46322647], prob_sum = 0.8963, time = 0.07s
# epoch:9856 ==>  KL = [0.05883812], logLKH = [-3.46279098], prob_sum = 0.8963, time = 0.07s
# epoch:9857 ==>  KL = [0.05883023], logLKH = [-3.46268058], prob_sum = 0.8963, time = 0.07s
# epoch:9858 ==>  KL = [0.05882823], logLKH = [-3.46265254], prob_sum = 0.8963, time = 0.08s
# epoch:9859 ==>  KL = [0.05873187], logLKH = [-3.46130351], prob_sum = 0.8964, time = 0.07s
# epoch:9860 ==>  KL = [0.05866711], logLKH = [-3.46039692], prob_sum = 0.8965, time = 0.07s
# epoch:9861 ==>  KL = [0.05865077], logLKH = [-3.46016813], prob_sum = 0.8965, time = 0.07s
# epoch:9862 ==>  KL = [0.05864662], logLKH = [-3.46011008], prob_sum = 0.8965, time = 0.07s
# epoch:9863 ==>  KL = [0.05864557], logLKH = [-3.46009533], prob_sum = 0.8965, time = 0.08s
# epoch:9864 ==>  KL = [0.0586453], logLKH = [-3.46009158], prob_sum = 0.8965, time = 0.07s
# epoch:9865 ==>  KL = [0.05864524], logLKH = [-3.46009063], prob_sum = 0.8965, time = 0.08s
# epoch:9866 ==>  KL = [0.05864522], logLKH = [-3.46009039], prob_sum = 0.8965, time = 0.08s
# epoch:9867 ==>  KL = [0.05862604], logLKH = [-3.45982189], prob_sum = 0.8965, time = 0.07s
# epoch:9868 ==>  KL = [0.0585996], logLKH = [-3.45945179], prob_sum = 0.8965, time = 0.07s
# epoch:9869 ==>  KL = [0.05859304], logLKH = [-3.45935994], prob_sum = 0.8965, time = 0.07s
# epoch:9870 ==>  KL = [0.05859139], logLKH = [-3.45933674], prob_sum = 0.8965, time = 0.07s
# epoch:9871 ==>  KL = [0.05859097], logLKH = [-3.45933085], prob_sum = 0.8965, time = 0.07s
# epoch:9872 ==>  KL = [0.05859086], logLKH = [-3.45932935], prob_sum = 0.8965, time = 0.08s
# epoch:9873 ==>  KL = [0.05859083], logLKH = [-3.45932897], prob_sum = 0.8965, time = 0.07s
# epoch:9874 ==>  KL = [0.05859082], logLKH = [-3.45932888], prob_sum = 0.8965, time = 0.07s
# epoch:9875 ==>  KL = [0.05859082], logLKH = [-3.45932885], prob_sum = 0.8965, time = 0.07s
# epoch:9876 ==>  KL = [0.05859082], logLKH = [-3.45932885], prob_sum = 0.8965, time = 0.08s
# epoch:9877 ==>  KL = [0.05859082], logLKH = [-3.45932884], prob_sum = 0.8965, time = 0.07s
# epoch:9878 ==>  KL = [0.05854025], logLKH = [-3.45862086], prob_sum = 0.8966, time = 0.07s
# epoch:9879 ==>  KL = [0.0584469], logLKH = [-3.45731391], prob_sum = 0.8967, time = 0.07s
# epoch:9880 ==>  KL = [0.05842349], logLKH = [-3.45698623], prob_sum = 0.8968, time = 0.07s
# epoch:9881 ==>  KL = [0.05841756], logLKH = [-3.45690322], prob_sum = 0.8968, time = 0.07s
# epoch:9882 ==>  KL = [0.05841606], logLKH = [-3.45688215], prob_sum = 0.8968, time = 0.07s
# epoch:9883 ==>  KL = [0.05841568], logLKH = [-3.45687679], prob_sum = 0.8968, time = 0.08s
# epoch:9884 ==>  KL = [0.05841558], logLKH = [-3.45687543], prob_sum = 0.8968, time = 0.07s
# epoch:9885 ==>  KL = [0.05841555], logLKH = [-3.45687508], prob_sum = 0.8968, time = 0.07s
# epoch:9886 ==>  KL = [0.05841555], logLKH = [-3.45687499], prob_sum = 0.8968, time = 0.08s
# epoch:9887 ==>  KL = [0.05841555], logLKH = [-3.45687497], prob_sum = 0.8968, time = 0.07s
# epoch:9888 ==>  KL = [0.05841555], logLKH = [-3.45687496], prob_sum = 0.8968, time = 0.07s
# epoch:9889 ==>  KL = [0.05841555], logLKH = [-3.45687496], prob_sum = 0.8968, time = 0.07s
# epoch:9890 ==>  KL = [0.05841555], logLKH = [-3.45687496], prob_sum = 0.8968, time = 0.07s
# epoch:9891 ==>  KL = [0.05846249], logLKH = [-3.45753221], prob_sum = 0.8968, time = 0.07s
# epoch:9892 ==>  KL = [0.05849515], logLKH = [-3.45798941], prob_sum = 0.8968, time = 0.07s
# epoch:9893 ==>  KL = [0.05850352], logLKH = [-3.45810663], prob_sum = 0.8968, time = 0.07s
# epoch:9894 ==>  KL = [0.05850565], logLKH = [-3.45813649], prob_sum = 0.8968, time = 0.07s
# epoch:9895 ==>  KL = [0.0585062], logLKH = [-3.45814409], prob_sum = 0.8968, time = 0.07s
# epoch:9896 ==>  KL = [0.05850633], logLKH = [-3.45814602], prob_sum = 0.8968, time = 0.07s
# epoch:9897 ==>  KL = [0.05850637], logLKH = [-3.45814651], prob_sum = 0.8968, time = 0.07s
# epoch:9898 ==>  KL = [0.05850638], logLKH = [-3.45814663], prob_sum = 0.8968, time = 0.07s
# epoch:9899 ==>  KL = [0.05850638], logLKH = [-3.45814667], prob_sum = 0.8968, time = 0.07s
# epoch:9900 ==>  KL = [0.05850638], logLKH = [-3.45814667], prob_sum = 0.8968, time = 0.07s
# epoch:9901 ==>  KL = [0.05850638], logLKH = [-3.45814668], prob_sum = 0.8968, time = 0.08s
# epoch:9902 ==>  KL = [0.05848253], logLKH = [-3.45781269], prob_sum = 0.8968, time = 0.09s
# epoch:9903 ==>  KL = [0.05847665], logLKH = [-3.45773038], prob_sum = 0.8968, time = 0.07s
# epoch:9904 ==>  KL = [0.05847516], logLKH = [-3.45770962], prob_sum = 0.8968, time = 0.08s
# epoch:9905 ==>  KL = [0.05847479], logLKH = [-3.45770435], prob_sum = 0.8968, time = 0.07s
# epoch:9906 ==>  KL = [0.05847469], logLKH = [-3.45770302], prob_sum = 0.8968, time = 0.07s
# epoch:9907 ==>  KL = [0.05847467], logLKH = [-3.45770268], prob_sum = 0.8968, time = 0.07s
# epoch:9908 ==>  KL = [0.05847466], logLKH = [-3.45770259], prob_sum = 0.8968, time = 0.09s
# epoch:9909 ==>  KL = [0.05847466], logLKH = [-3.45770257], prob_sum = 0.8968, time = 0.07s
# epoch:9910 ==>  KL = [0.0584951], logLKH = [-3.45798878], prob_sum = 0.8969, time = 0.07s
# epoch:9911 ==>  KL = [0.05851298], logLKH = [-3.4582391], prob_sum = 0.8970, time = 0.08s
# epoch:9912 ==>  KL = [0.05851761], logLKH = [-3.45830393], prob_sum = 0.8970, time = 0.07s
# epoch:9913 ==>  KL = [0.0585188], logLKH = [-3.45832049], prob_sum = 0.8970, time = 0.07s
# epoch:9914 ==>  KL = [0.0585191], logLKH = [-3.4583247], prob_sum = 0.8970, time = 0.07s
# epoch:9915 ==>  KL = [0.05851917], logLKH = [-3.45832578], prob_sum = 0.8970, time = 0.07s
# epoch:9916 ==>  KL = [0.05851919], logLKH = [-3.45832605], prob_sum = 0.8970, time = 0.07s
# epoch:9917 ==>  KL = [0.0585192], logLKH = [-3.45832612], prob_sum = 0.8970, time = 0.08s
# epoch:9918 ==>  KL = [0.0585192], logLKH = [-3.45832613], prob_sum = 0.8970, time = 0.07s
# epoch:9919 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9920 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9921 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9922 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9923 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9924 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9925 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9926 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9927 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9928 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9929 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9930 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9931 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9932 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9933 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9934 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.10s
# epoch:9935 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9936 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9937 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9938 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9939 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9940 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9941 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9942 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9943 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9944 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9945 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9946 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9947 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9948 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9949 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9950 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.08s
# epoch:9951 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9952 ==>  KL = [0.0585192], logLKH = [-3.45832614], prob_sum = 0.8970, time = 0.07s
# epoch:9953 ==>  KL = [0.05860476], logLKH = [-3.45952392], prob_sum = 0.8972, time = 0.07s
# epoch:9954 ==>  KL = [0.0586303], logLKH = [-3.45988155], prob_sum = 0.8973, time = 0.07s
# epoch:9955 ==>  KL = [0.05863683], logLKH = [-3.4599729], prob_sum = 0.8973, time = 0.07s
# epoch:9956 ==>  KL = [0.05863849], logLKH = [-3.45999614], prob_sum = 0.8973, time = 0.07s
# epoch:9957 ==>  KL = [0.05863891], logLKH = [-3.46000205], prob_sum = 0.8973, time = 0.07s
# epoch:9958 ==>  KL = [0.05868861], logLKH = [-3.46069783], prob_sum = 0.8975, time = 0.07s
# epoch:9959 ==>  KL = [0.05870346], logLKH = [-3.4609058], prob_sum = 0.8976, time = 0.07s
# epoch:9960 ==>  KL = [0.05870726], logLKH = [-3.46095894], prob_sum = 0.8976, time = 0.07s
# epoch:9961 ==>  KL = [0.05870822], logLKH = [-3.46097246], prob_sum = 0.8976, time = 0.07s
# epoch:9962 ==>  KL = [0.05870847], logLKH = [-3.4609759], prob_sum = 0.8976, time = 0.07s
# epoch:9963 ==>  KL = [0.05870853], logLKH = [-3.46097678], prob_sum = 0.8976, time = 0.07s
# epoch:9964 ==>  KL = [0.05870855], logLKH = [-3.460977], prob_sum = 0.8976, time = 0.07s
# epoch:9965 ==>  KL = [0.05870855], logLKH = [-3.46097706], prob_sum = 0.8976, time = 0.07s
# epoch:9966 ==>  KL = [0.05870855], logLKH = [-3.46097707], prob_sum = 0.8976, time = 0.08s
# epoch:9967 ==>  KL = [0.05870855], logLKH = [-3.46097707], prob_sum = 0.8976, time = 0.07s
# epoch:9968 ==>  KL = [0.05870855], logLKH = [-3.46097707], prob_sum = 0.8976, time = 0.07s
# epoch:9969 ==>  KL = [0.05870855], logLKH = [-3.46097707], prob_sum = 0.8976, time = 0.07s
# epoch:9970 ==>  KL = [0.05870855], logLKH = [-3.46097708], prob_sum = 0.8976, time = 0.07s
# epoch:9971 ==>  KL = [0.05870855], logLKH = [-3.46097708], prob_sum = 0.8976, time = 0.07s
# epoch:9972 ==>  KL = [0.05870855], logLKH = [-3.46097708], prob_sum = 0.8976, time = 0.07s
# epoch:9973 ==>  KL = [0.05872262], logLKH = [-3.46117406], prob_sum = 0.8977, time = 0.08s
# epoch:9974 ==>  KL = [0.05873829], logLKH = [-3.46139333], prob_sum = 0.8977, time = 0.07s
# epoch:9975 ==>  KL = [0.05874235], logLKH = [-3.4614503], prob_sum = 0.8978, time = 0.07s
# epoch:9976 ==>  KL = [0.05874339], logLKH = [-3.46146486], prob_sum = 0.8978, time = 0.07s
# epoch:9977 ==>  KL = [0.05874366], logLKH = [-3.46146856], prob_sum = 0.8978, time = 0.07s
# epoch:9978 ==>  KL = [0.05874373], logLKH = [-3.4614695], prob_sum = 0.8978, time = 0.07s
# epoch:9979 ==>  KL = [0.05874374], logLKH = [-3.46146974], prob_sum = 0.8978, time = 0.07s
# epoch:9980 ==>  KL = [0.05874375], logLKH = [-3.4614698], prob_sum = 0.8978, time = 0.08s
# epoch:9981 ==>  KL = [0.05874375], logLKH = [-3.46146982], prob_sum = 0.8978, time = 0.07s
# epoch:9982 ==>  KL = [0.05874375], logLKH = [-3.46146982], prob_sum = 0.8978, time = 0.07s
# epoch:9983 ==>  KL = [0.05874375], logLKH = [-3.46146982], prob_sum = 0.8978, time = 0.08s
# epoch:9984 ==>  KL = [0.05874375], logLKH = [-3.46146983], prob_sum = 0.8978, time = 0.07s
# epoch:9985 ==>  KL = [0.05874375], logLKH = [-3.46146983], prob_sum = 0.8978, time = 0.07s
# epoch:9986 ==>  KL = [0.0587315], logLKH = [-3.46129831], prob_sum = 0.8978, time = 0.07s
# epoch:9987 ==>  KL = [0.05872198], logLKH = [-3.46116506], prob_sum = 0.8978, time = 0.09s
# epoch:9988 ==>  KL = [0.05871969], logLKH = [-3.46113292], prob_sum = 0.8978, time = 0.07s
# epoch:9989 ==>  KL = [0.05871911], logLKH = [-3.46112486], prob_sum = 0.8978, time = 0.07s
# epoch:9990 ==>  KL = [0.05871896], logLKH = [-3.46112282], prob_sum = 0.8978, time = 0.07s
# epoch:9991 ==>  KL = [0.05871893], logLKH = [-3.4611223], prob_sum = 0.8978, time = 0.07s
# epoch:9992 ==>  KL = [0.05861516], logLKH = [-3.45966956], prob_sum = 0.8975, time = 0.07s
# epoch:9993 ==>  KL = [0.05858055], logLKH = [-3.45918498], prob_sum = 0.8975, time = 0.07s
# epoch:9994 ==>  KL = [0.05850247], logLKH = [-3.45809197], prob_sum = 0.8974, time = 0.08s
# epoch:9995 ==>  KL = [0.05846143], logLKH = [-3.45751729], prob_sum = 0.8973, time = 0.07s
# epoch:9996 ==>  KL = [0.05845102], logLKH = [-3.45737163], prob_sum = 0.8973, time = 0.07s
# epoch:9997 ==>  KL = [0.05844838], logLKH = [-3.45733464], prob_sum = 0.8973, time = 0.07s
# epoch:9998 ==>  KL = [0.05844771], logLKH = [-3.45732523], prob_sum = 0.8973, time = 0.07s
# epoch:9999 ==>  KL = [0.05844754], logLKH = [-3.45732284], prob_sum = 0.8973, time = 0.07s
# epoch:10000 ==>  KL = [0.05844749], logLKH = [-3.45732224], prob_sum = 0.8973, time = 0.07s

# %%
import matplotlib.pyplot as plt

kl_time = [i for i in range(len(KL_list))]
plt.figure(figsize=(5,3))
plt.plot(kl_time, KL_list)
plt.savefig('KL_divergence -1&1')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot(kl_time, log_LKH_list)
plt.savefig('log_Likelihood -1&1')
plt.show()

# %%
acc = 0
train_data = [train_data[i].astype(int) for i in range(len(train_data))]
for i in range(len(train_data)):
    v0 = train_data[i]
    v0, vk, p_h0_v, p_hk_v = rbm.gibbs_sampling(v0)
    
    acc_i = np.sum(np.where(train_data[i]==vk, 1, 0)/len(train_data[i]))
    print('original_data: {}, sampling_data: {}, acc: {}'.format(train_data[i], vk, acc_i))
# Out:
# original_data: [ 1  1  1 -1 -1 -1 -1 -1 -1], sampling_data: [[ 1  1  1 -1 -1 -1 -1 -1 -1]], acc: 1.0
# original_data: [-1 -1 -1  1  1  1 -1 -1 -1], sampling_data: [[-1 -1 -1  1  1  1 -1 -1 -1]], acc: 1.0
# original_data: [-1 -1 -1 -1 -1 -1  1  1  1], sampling_data: [[-1 -1 -1 -1 -1 -1  1  1  1]], acc: 1.0
# original_data: [ 1  1  1  1  1  1 -1 -1 -1], sampling_data: [[ 1  1  1  1  1  1 -1 -1 -1]], acc: 1.0
# original_data: [ 1  1  1 -1 -1 -1  1  1  1], sampling_data: [[ 1  1  1 -1 -1 -1  1  1  1]], acc: 1.0
# original_data: [-1 -1 -1  1  1  1  1  1  1], sampling_data: [[-1 -1 -1  1  1  1  1  1  1]], acc: 1.0
# original_data: [ 1 -1 -1  1 -1 -1  1 -1 -1], sampling_data: [[ 1 -1 -1  1 -1 -1  1 -1 -1]], acc: 1.0
# original_data: [-1  1 -1 -1  1 -1 -1  1 -1], sampling_data: [[-1  1 -1 -1  1 -1 -1  1 -1]], acc: 1.0
# original_data: [-1 -1  1 -1 -1  1 -1 -1  1], sampling_data: [[-1 -1  1 -1 -1  1 -1 -1  1]], acc: 1.0
# original_data: [ 1  1 -1  1  1 -1  1  1 -1], sampling_data: [[ 1  1 -1  1  1 -1  1  1 -1]], acc: 1.0
# original_data: [ 1 -1  1  1 -1  1  1 -1  1], sampling_data: [[ 1 -1  1  1 -1  1  1 -1  1]], acc: 1.0
# original_data: [-1  1  1 -1  1  1 -1  1  1], sampling_data: [[-1  1  1 -1  1  1 -1  1  1]], acc: 1.0
# original_data: [-1 -1 -1 -1 -1 -1 -1 -1 -1], sampling_data: [[-1 -1 -1 -1 -1 -1 -1 -1 -1]], acc: 1.0
# original_data: [1 1 1 1 1 1 1 1 1], sampling_data: [[1 1 1 1 1 1 1 1 1]], acc: 1.0

# %%
import seaborn as sns
sns.barplot(data = probability_list, color='Grey')
# Out:
# <AxesSubplot:>
