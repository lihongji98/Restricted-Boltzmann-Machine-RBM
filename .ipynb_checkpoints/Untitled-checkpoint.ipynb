# %%
import numpy as np
import time
from tqdm import tqdm

# %%
class RBM:
    def __init__(self,
                 v_dim, h_dim,
                 lr=5e-4,
                 gibbs_num = 1,
                 epochs = 50000,
                 batch_size = 1,
                 compute_detail = True,
                 binary_kind = "withoutzero"):
        self.v_dim = v_dim
        self.h_dim = h_dim
        self.lr = lr
        #self.v_bias = np.random.normal(-0.1, 0.1, size = (1,self.v_dim))
        #self.h_bias = np.random.normal(-0.1, 0.1, size =(1,self.h_dim))
        self.v_bias = np.zeros((1,self.v_dim))
        self.h_bias = np.zeros((1,self.h_dim))
        self.W = np.random.normal(size = (self.v_dim, self.h_dim))
        self.gibbs_num = gibbs_num
        self.v_w, self.v_v, self.v_h = 0, 0, 0
        self.momentum = 0.9
        self.epochs = epochs
        self.compute_detail = compute_detail
        self.batch_size = batch_size
        self.binary_kind = binary_kind
        self.allcases = self.get_all_cases(self.binary_kind, self.v_dim)

    def sample_h(self, v_input):
        if self.binary_kind == "withoutzero":
            var = -(np.dot(v_input, self.W) + self.h_bias)
            p_h_v = 1 / (1 + np.exp(2 * var))
            state_h = self.state_sample(p_h_v)
        elif self.binary_kind == "withzero":
            p_h_v = 1 / (1 + np.exp(-(np.dot(v_input, self.W) + self.h_bias)))
            state_h = self.state_sample(p_h_v)
        else:
            print("enter 'withzero' or 'withoutzero'!")

        return state_h, p_h_v

    def sample_v(self, h):
        if self.binary_kind == "withoutzero":
            var = -(np.dot(h, self.W.T) + self.v_bias)
            p_v_h = 1 / (1 + np.exp(2 * var))
            state_v = self.state_sample(p_v_h)
        elif self.binary_kind == "withzero":
            p_v_h = 1 / (1 + np.exp(-(np.dot(h, self.W.T) + self.v_bias)))
            state_v = self.state_sample(p_v_h)
        else:
            print("enter 'withzero' or 'withoutzero'!")

        return state_v, p_v_h

    def state_sample(self, p):
        state = []
        uni = np.random.uniform(0,1, size=p[0].shape[0])
        for i in range(len(p)):
            condition = np.less(p[i], uni)
            if self.binary_kind == "withoutzero":
                state_node = np.where(condition, -1, 1)
            elif self.binary_kind == "withzero":
                state_node = np.where(condition, 0, 1)
            else:
                print("enter 'withzero' or 'withoutzero'!")
            state.append(state_node)

        return np.array(state).reshape(p.shape[0], p.shape[1])


    def gibbs_sampling(self, v, k):
        i = 0
        #k = self.gibbs_num
        v_0, v_init = v.copy(), v.copy()
        _, p_h0_v = self.sample_h(v_0)

        while i < k:
            state_h, _ = self.sample_h(v_init)
            state_v, _ = self.sample_v(state_h)
            v_init = state_v
            i += 1
        else:
            v_k = state_v
            _, p_hk_v = self.sample_h(v_k)

        return v_0, v_k, p_h0_v, p_hk_v


    def gradient_compute(self, v_0, v_k, p_h0_v, p_hk_v):
        dw = (np.dot(v_0.T, p_h0_v) - np.dot(v_k.T, p_hk_v))
        dh_bias = (np.sum(p_h0_v - p_hk_v))
        dv_bias = (np.sum(v_0 - v_k))

        self.v_w = self.momentum * self.v_w + (1 - self.momentum) * dw
        self.v_h = self.momentum * self.v_h + (1 - self.momentum) * dh_bias
        self.v_v = self.momentum * self.v_v + (1 - self.momentum) * dv_bias

        self.W += self.lr * self.v_w / self.batch_size
        self.v_bias += self.lr * self.v_v / self.batch_size
        self.h_bias += self.lr * self.v_h  / self.batch_size

    def get_all_cases(self, binary_kind, v_dim):
        def all_cases(nums, v_dim):
            res = []
            backtracking(nums, v_dim, [], 0, res)
            return res

        def backtracking(nums, v_dim, path, pos, res):
            if len(path) > v_dim:
                return
            if len(path) == v_dim:
                res.append(list(path))
            for i in range(len(nums)):
                path.append(nums[i])
                backtracking(nums, v_dim, path, i + 1, res)
                path.pop()
        if binary_kind == "withzero":
            return np.array(all_cases([0, 1], self.v_dim))

        elif binary_kind == "withoutzero":
            return np.array(all_cases([-1, 1], self.v_dim))
        else:
            print("enter 'withzero' or 'withoutzero'!")


    def compute_px_with_Z(self, train_data, W, v_bias, h_bias):
        probability = []
        if self.binary_kind == "withoutzero":
            for l in range(len(train_data)):
                train_data_one_piece = train_data[l]
                product_value = 1
                exp_av = np.exp(np.dot(v_bias, train_data_one_piece))
                for i in range(h_bias.shape[1]):
                    product_value = product_value * (np.exp(np.dot(W.T[i], train_data_one_piece)+ h_bias.T[i]) +
                                                     np.exp(-np.dot(W.T[i], train_data_one_piece)- h_bias.T[i]))
                px_with_Z = exp_av * product_value
                probability.append(px_with_Z[0])

        elif self.binary_kind == "withzero":
            for l in range(len(train_data)):
                train_data_one_piece = train_data[l]
                product_value = 1
                exp_av = np.exp(np.dot(v_bias, train_data_one_piece))
                for i in range(h_bias.shape[1]):
                    product_value = product_value * (np.exp(np.dot(W.T[i], train_data_one_piece) + h_bias.T[i]) + 1)
                px_with_Z = exp_av * product_value
                probability.append(px_with_Z[0])

        else:
            print("enter 'withzero' or 'withoutzero'!")

        return probability

    def compute_Z(self, W, v_bias, h_bias):
        Z = 0
        if self.binary_kind == "withoutzero":
            for l in range(len(self.allcases)):
                train_data_one = self.allcases[l]
                exp_av = np.exp(np.dot(v_bias, train_data_one))
                product = 1
                for j in range(h_bias.shape[1]):
                    product = product * (np.exp(np.dot(train_data_one.T, W.T[j]) + h_bias.T[j]) +
                                         np.exp(-np.dot(train_data_one.T, W.T[j]) - h_bias.T[j]))
                total = exp_av * product

                Z += total

        elif self.binary_kind == "withzero":
            for l in range(len(self.allcases)):
                train_data_one = self.allcases[l]
                exp_av = np.exp(np.dot(v_bias, train_data_one))
                product = 1
                for j in range(h_bias.shape[1]):
                    product = product * (np.exp(np.dot(train_data_one.T, W.T[j]) + h_bias.T[j]) + 1)
                total = exp_av * product

                Z += total
        else:
            print("enter 'withzero' or 'withoutzero'!")

        return Z

    def train(self, train_data):
        idx = [i for i in range(train_data.shape[0])]
        start = [i for i in idx if i%self.batch_size == 0]
        end = []
        for start_idx in start:
            end_idx = start_idx + self.batch_size
            if end_idx < len(idx):
                end.append(end_idx)
            else:
                end.append(len(idx))
        batch_idx = len(start)

        persistant_chain = None
        #for epoch in tqdm(range(self.epochs)):
        for epoch in range(self.epochs):
            epoch_start_time = time.time()
            for index in range(batch_idx):
                v0 = train_data[start[index]: end[index]]
                _, p_h0_v = self.sample_h(v0)

                if persistant_chain is None:
                    _, persistant_chain, _, _ = self.gibbs_sampling(v0, 1)
                    # return v_0, v_k, p_h0_v, p_hk_v
                _, vk, _, p_hk_v = self.gibbs_sampling(persistant_chain, k = self.gibbs_num)
                self.gradient_compute(v0, vk, p_h0_v, p_hk_v)
                persistant_chain = vk

            lowest_KL = float("inf")
            lowest_KL_epoch = 0

            if self.compute_detail:
                KL_list, log_LKH_list = [], []
                logLKH, KL = 0, 0
                Z = self.compute_Z(self.W, self.v_bias, self.h_bias)
                probability_list = self.compute_px_with_Z(train_data, self.W, self.v_bias, self.h_bias)

                for i in range(len(probability_list)):
                    px_with_Z = probability_list[i]
                    N = len(probability_list)
                    log_lkh = np.log(px_with_Z) - np.log(Z)
                    logLKH += log_lkh

                    kl = -np.log(N)/N - np.log(px_with_Z)/N + np.log(Z)/N
                    KL += kl
                KL /= N
                logLKH /= N

                KL_list.append(KL)
                log_LKH_list.append(logLKH)

                probability_list = [probability_list[i]/Z for i in range(len(probability_list))]
                x = np.sum(probability_list)

                epoch_end_time = time.time()

                if KL[0] < lowest_KL:
                    lowest_KL = KL[0]
                    lowest_KL_epoch = epoch
                else:
                    print(epoch)


                results = 'epoch:{} ==>  KL = {}, logLKH = {}, prob_sum = {:.4f}, time = {:.2f}s' \
                		  .format(epoch+1, KL, logLKH, x, epoch_end_time-epoch_start_time)
                #f=open("pcd10w.txt","a")
                #f.write(results + '\n')
                #f.close()
                if((epoch + 1) % 200 == 0) or epoch == 0:
                    print(results)

            else:
                if epoch + 1 == self.epochs:
                    logLKH, KL = 0, 0
                    Z = self.compute_Z(self.W, self.v_bias, self.h_bias)
                    probability_list = self.compute_px_with_Z(train_data, self.W, self.v_bias, self.h_bias)

                    for i in range(len(probability_list)):
                        px_with_Z = probability_list[i]
                        N = len(probability_list)
                        log_lkh = np.log(px_with_Z) - np.log(Z)
                        logLKH += log_lkh

                        kl = -np.log(N)/N - np.log(px_with_Z)/N + np.log(Z)/N
                        KL += kl
                    KL /= N
                    logLKH /= N
                    probability_list = [probability_list[i]/Z for i in range(len(probability_list))]
                    x = np.sum(probability_list)
                    results = 'KL = {}, logLKH = {}, prob_distribution = {}'.format(KL, logLKH, x)
                    print(results)
        record = "The lowest KL is {} in epoch {}".format(lowest_KL, lowest_KL_epoch)
        #f.write(record + '\n')
        #f.write('\n')
        print(record)
        #f.close()

# %%
if __name__ == "__main__":
	train_data = np.loadtxt(r'3x3.txt')

	visible_node_num = train_data.shape[1]
	hidden_node_num = 20
	lr = 0.0003

	rbm = RBM(visible_node_num, hidden_node_num, lr, binary_kind="withzero",
	           epochs=1000, batch_size = 2, gibbs_num = 1, compute_detail=True)

	rbm.train(train_data)
# Out:
# lowest_KL [0.60698237]
# epoch:1 ==>  KL = [0.60698237], logLKH = [-11.13681051], prob_sum = 0.0035, time = 0.04s
# lowest_KL [0.60568431]
# lowest_KL [0.60383215]
# lowest_KL [0.60169425]
# lowest_KL [0.59951296]
# lowest_KL [0.59749787]
# lowest_KL [0.59552119]
# lowest_KL [0.59361959]
# lowest_KL [0.59156984]
# lowest_KL [0.58938318]
# lowest_KL [0.58712228]
# lowest_KL [0.58479319]
# lowest_KL [0.58249427]
# lowest_KL [0.5805714]
# lowest_KL [0.57882857]
# lowest_KL [0.57698504]
# lowest_KL [0.57494299]
# lowest_KL [0.57272476]
# lowest_KL [0.57043126]
# lowest_KL [0.56842139]
# lowest_KL [0.56648083]
# lowest_KL [0.5645885]
# lowest_KL [0.56264527]
# lowest_KL [0.56102538]
# lowest_KL [0.55929818]
# lowest_KL [0.55723456]
# lowest_KL [0.55523398]
# lowest_KL [0.55344889]
# lowest_KL [0.55149329]
# lowest_KL [0.54941365]
# lowest_KL [0.54769678]
# lowest_KL [0.54595281]
# lowest_KL [0.54428993]
# lowest_KL [0.54265404]
# lowest_KL [0.54128213]
# lowest_KL [0.54015964]
# lowest_KL [0.53867414]
# lowest_KL [0.53713426]
# lowest_KL [0.53546964]
# lowest_KL [0.5337404]
# lowest_KL [0.53217887]
# lowest_KL [0.53093822]
# lowest_KL [0.52965151]
# lowest_KL [0.52857514]
# lowest_KL [0.52738126]
# lowest_KL [0.52612369]
# lowest_KL [0.52470471]
# lowest_KL [0.5231111]
# lowest_KL [0.52157465]
# lowest_KL [0.52009746]
# lowest_KL [0.51861138]
# lowest_KL [0.5170595]
# lowest_KL [0.51570475]
# lowest_KL [0.51431323]
# lowest_KL [0.51295208]
# lowest_KL [0.5117609]
# lowest_KL [0.51037359]
# lowest_KL [0.5092234]
# lowest_KL [0.50815074]
# lowest_KL [0.50699239]
# lowest_KL [0.50589967]
# lowest_KL [0.50480362]
# lowest_KL [0.50355463]
# lowest_KL [0.50244097]
# lowest_KL [0.50114932]
# lowest_KL [0.49992438]
# lowest_KL [0.49851225]
# lowest_KL [0.49752757]
# lowest_KL [0.49620313]
# lowest_KL [0.49466277]
# lowest_KL [0.49337567]
# lowest_KL [0.49207181]
# lowest_KL [0.49064551]
# lowest_KL [0.48925725]
# lowest_KL [0.4877707]
# lowest_KL [0.48643096]
# lowest_KL [0.48502024]
# lowest_KL [0.48372787]
# lowest_KL [0.48258921]
# lowest_KL [0.48134858]
# lowest_KL [0.48006986]
# lowest_KL [0.47923584]
# lowest_KL [0.47810235]
# lowest_KL [0.47707594]
# lowest_KL [0.47617747]
# lowest_KL [0.47537397]
# lowest_KL [0.47433696]
# lowest_KL [0.47320276]
# lowest_KL [0.47193891]
# lowest_KL [0.47107618]
# lowest_KL [0.47010485]
# lowest_KL [0.46895086]
# lowest_KL [0.46784618]
# lowest_KL [0.46680213]
# lowest_KL [0.46579183]
# lowest_KL [0.4649561]
# lowest_KL [0.46412301]
# lowest_KL [0.46323811]
# lowest_KL [0.46215747]
# lowest_KL [0.46105009]
# lowest_KL [0.45995238]
# lowest_KL [0.45891175]
# lowest_KL [0.45785765]
# lowest_KL [0.45693965]
# lowest_KL [0.45582655]
# lowest_KL [0.45470474]
# lowest_KL [0.45354044]
# lowest_KL [0.45246251]
# lowest_KL [0.45141428]
# lowest_KL [0.45033466]
# lowest_KL [0.44931129]
# lowest_KL [0.44842338]
# lowest_KL [0.44766278]
# lowest_KL [0.44678168]
# lowest_KL [0.44591761]
# lowest_KL [0.44507734]
# lowest_KL [0.44440579]
# lowest_KL [0.44350511]
# lowest_KL [0.44245648]
# lowest_KL [0.44157484]
# lowest_KL [0.44067788]
# lowest_KL [0.43986982]
# lowest_KL [0.43906887]
# lowest_KL [0.43823629]
# lowest_KL [0.43735815]
# lowest_KL [0.43644786]
# lowest_KL [0.43552669]
# lowest_KL [0.43462511]
# lowest_KL [0.43369905]
# lowest_KL [0.4330231]
# lowest_KL [0.43212859]
# lowest_KL [0.43125356]
# lowest_KL [0.43034537]
# lowest_KL [0.42971096]
# lowest_KL [0.42904897]
# lowest_KL [0.42827983]
# lowest_KL [0.42733078]
# lowest_KL [0.4263691]
# lowest_KL [0.42571561]
# lowest_KL [0.42500398]
# lowest_KL [0.42427362]
# lowest_KL [0.42364741]
# lowest_KL [0.42323779]
# lowest_KL [0.42267705]
# lowest_KL [0.4219724]
# lowest_KL [0.42135857]
# lowest_KL [0.42064357]
# lowest_KL [0.41976173]
# lowest_KL [0.41894842]
# lowest_KL [0.41830438]
# lowest_KL [0.41758156]
# lowest_KL [0.41687994]
# lowest_KL [0.41610156]
# lowest_KL [0.41540706]
# lowest_KL [0.41475411]
# lowest_KL [0.4139556]
# lowest_KL [0.41318036]
# lowest_KL [0.41271994]
# lowest_KL [0.41245241]
# lowest_KL [0.41215732]
# lowest_KL [0.41181429]
# lowest_KL [0.41141931]
# lowest_KL [0.41091089]
# lowest_KL [0.41034336]
# lowest_KL [0.40970192]
# lowest_KL [0.40893628]
# lowest_KL [0.40816378]
# lowest_KL [0.40744346]
# lowest_KL [0.40676373]
# lowest_KL [0.40624185]
# lowest_KL [0.40568482]
# lowest_KL [0.40518272]
# lowest_KL [0.40460344]
# lowest_KL [0.40404788]
# lowest_KL [0.40344866]
# lowest_KL [0.40293055]
# lowest_KL [0.40251075]
# lowest_KL [0.40214376]
# lowest_KL [0.40173659]
# lowest_KL [0.40127168]
# lowest_KL [0.4008424]
# lowest_KL [0.40036137]
# lowest_KL [0.39991605]
# lowest_KL [0.39939394]
# lowest_KL [0.39902264]
# lowest_KL [0.39851347]
# lowest_KL [0.39789609]
# lowest_KL [0.39736509]
# lowest_KL [0.3969088]
# lowest_KL [0.39645817]
# lowest_KL [0.39583544]
# lowest_KL [0.39513245]
# lowest_KL [0.3944954]
# lowest_KL [0.39401166]
# lowest_KL [0.39353323]
# lowest_KL [0.39294278]
# lowest_KL [0.3923352]
# lowest_KL [0.39185121]
# lowest_KL [0.39119309]
# lowest_KL [0.39050035]
# epoch:200 ==>  KL = [0.39050035], logLKH = [-8.10606219], prob_sum = 0.0207, time = 0.04s
# lowest_KL [0.38996078]
# lowest_KL [0.38948008]
# lowest_KL [0.38923305]
# lowest_KL [0.38913377]
# lowest_KL [0.3889616]
# lowest_KL [0.38866124]
# lowest_KL [0.3882641]
# lowest_KL [0.38781395]
# lowest_KL [0.3872794]
# lowest_KL [0.38669776]
# lowest_KL [0.38610747]
# lowest_KL [0.38563156]
# lowest_KL [0.38510642]
# lowest_KL [0.38461944]
# lowest_KL [0.38419728]
# lowest_KL [0.38379678]
# lowest_KL [0.38346323]
# lowest_KL [0.38316575]
# lowest_KL [0.38275007]
# lowest_KL [0.38230046]
# lowest_KL [0.38183743]
# lowest_KL [0.38146806]
# lowest_KL [0.38093827]
# lowest_KL [0.38049321]
# lowest_KL [0.38010795]
# lowest_KL [0.37963735]
# lowest_KL [0.37914592]
# lowest_KL [0.3786403]
# lowest_KL [0.37826356]
# lowest_KL [0.3779546]
# lowest_KL [0.37767768]
# lowest_KL [0.37736098]
# lowest_KL [0.37701542]
# lowest_KL [0.37677974]
# lowest_KL [0.37643529]
# lowest_KL [0.37599459]
# lowest_KL [0.37551816]
# lowest_KL [0.37508137]
# lowest_KL [0.37465162]
# lowest_KL [0.37427823]
# lowest_KL [0.37390689]
# lowest_KL [0.37367029]
# lowest_KL [0.3734168]
# lowest_KL [0.37303193]
# lowest_KL [0.37260826]
# lowest_KL [0.37226865]
# lowest_KL [0.37201446]
# lowest_KL [0.37167579]
# lowest_KL [0.37126313]
# lowest_KL [0.37088331]
# lowest_KL [0.37052206]
# lowest_KL [0.37006998]
# lowest_KL [0.36952655]
# lowest_KL [0.36909839]
# lowest_KL [0.3688223]
# lowest_KL [0.36857056]
# lowest_KL [0.36821111]
# lowest_KL [0.36790665]
# lowest_KL [0.36769115]
# lowest_KL [0.36746811]
# lowest_KL [0.36736697]
# lowest_KL [0.36735535]
# lowest_KL [0.36721406]
# lowest_KL [0.36695998]
# lowest_KL [0.36677767]
# lowest_KL [0.36643459]
# lowest_KL [0.36601671]
# lowest_KL [0.36562042]
# lowest_KL [0.36536472]
# lowest_KL [0.36508239]
# lowest_KL [0.3647131]
# lowest_KL [0.36429634]
# lowest_KL [0.36392444]
# lowest_KL [0.36354482]
# lowest_KL [0.36318564]
# lowest_KL [0.36283886]
# lowest_KL [0.36248416]
# lowest_KL [0.36209872]
# lowest_KL [0.3617309]
# lowest_KL [0.36141641]
# lowest_KL [0.36115347]
# lowest_KL [0.36095133]
# lowest_KL [0.36071876]
# lowest_KL [0.36052082]
# lowest_KL [0.36029054]
# lowest_KL [0.35999867]
# lowest_KL [0.3597479]
# lowest_KL [0.35954046]
# lowest_KL [0.35930478]
# lowest_KL [0.35911912]
# lowest_KL [0.358898]
# lowest_KL [0.35866428]
# lowest_KL [0.35839181]
# lowest_KL [0.35814549]
# lowest_KL [0.35792397]
# lowest_KL [0.35770549]
# lowest_KL [0.35753509]
# lowest_KL [0.35730314]
# lowest_KL [0.35703122]
# lowest_KL [0.35674607]
# lowest_KL [0.35643448]
# lowest_KL [0.35612091]
# lowest_KL [0.35584449]
# lowest_KL [0.3556031]
# lowest_KL [0.35535928]
# lowest_KL [0.35511139]
# lowest_KL [0.35482976]
# lowest_KL [0.35451968]
# lowest_KL [0.35434486]
# lowest_KL [0.35415043]
# lowest_KL [0.35401482]
# lowest_KL [0.35384491]
# lowest_KL [0.35373611]
# lowest_KL [0.35369831]
# lowest_KL [0.35359606]
# lowest_KL [0.35355641]
# lowest_KL [0.35361398]
# lowest_KL [0.35359425]
# lowest_KL [0.35361781]
# lowest_KL [0.35356652]
# lowest_KL [0.35346155]
# lowest_KL [0.35339741]
# lowest_KL [0.35321344]
# lowest_KL [0.35306579]
# lowest_KL [0.35288034]
# lowest_KL [0.35262913]
# lowest_KL [0.35249347]
# lowest_KL [0.35240949]
# lowest_KL [0.35228699]
# lowest_KL [0.35205256]
# lowest_KL [0.35174808]
# lowest_KL [0.35144801]
# lowest_KL [0.35133525]
# lowest_KL [0.35125271]
# lowest_KL [0.35114825]
# lowest_KL [0.35097006]
# lowest_KL [0.35076748]
# lowest_KL [0.35060007]
# lowest_KL [0.35045301]
# lowest_KL [0.35030511]
# lowest_KL [0.35013479]
# lowest_KL [0.34993275]
# lowest_KL [0.34965408]
# lowest_KL [0.34934924]
# lowest_KL [0.34913155]
# lowest_KL [0.34894927]
# lowest_KL [0.34885411]
# lowest_KL [0.34881218]
# lowest_KL [0.34865779]
# lowest_KL [0.3484144]
# lowest_KL [0.34814984]
# lowest_KL [0.34800061]
# lowest_KL [0.34783199]
# lowest_KL [0.34762]
# lowest_KL [0.34737279]
# lowest_KL [0.34708531]
# lowest_KL [0.34681976]
# lowest_KL [0.34655219]
# lowest_KL [0.34628124]
# lowest_KL [0.34602533]
# lowest_KL [0.3457954]
# lowest_KL [0.34564824]
# lowest_KL [0.3455367]
# lowest_KL [0.34544293]
# lowest_KL [0.3453316]
# lowest_KL [0.34519614]
# lowest_KL [0.34501576]
# lowest_KL [0.34478133]
# lowest_KL [0.34456367]
# lowest_KL [0.34429295]
# lowest_KL [0.34410149]
# lowest_KL [0.34397832]
# lowest_KL [0.34379761]
# lowest_KL [0.34362253]
# lowest_KL [0.34345675]
# lowest_KL [0.3433282]
# lowest_KL [0.34324552]
# lowest_KL [0.34315374]
# lowest_KL [0.34301675]
# lowest_KL [0.34283514]
# lowest_KL [0.34274633]
# lowest_KL [0.34266575]
# lowest_KL [0.3425177]
# lowest_KL [0.34236176]
# lowest_KL [0.34217393]
# lowest_KL [0.34194212]
# lowest_KL [0.34173051]
# lowest_KL [0.34150361]
# lowest_KL [0.34130343]
# lowest_KL [0.34113862]
# lowest_KL [0.34096202]
# lowest_KL [0.34077365]
# lowest_KL [0.34060774]
# lowest_KL [0.34051778]
# lowest_KL [0.3404286]
# lowest_KL [0.34031309]
# lowest_KL [0.34010611]
# lowest_KL [0.33991928]
# lowest_KL [0.33969239]
# lowest_KL [0.33943614]
# epoch:400 ==>  KL = [0.33943614], logLKH = [-7.39116328], prob_sum = 0.0294, time = 0.04s
# lowest_KL [0.33922469]
# lowest_KL [0.33899856]
# lowest_KL [0.33871628]
# lowest_KL [0.33847466]
# lowest_KL [0.33828977]
# lowest_KL [0.33810465]
# lowest_KL [0.33792074]
# lowest_KL [0.33771805]
# lowest_KL [0.33762641]
# lowest_KL [0.33756451]
# lowest_KL [0.33744111]
# lowest_KL [0.33734061]
# lowest_KL [0.33724481]
# lowest_KL [0.33718468]
# lowest_KL [0.33708089]
# lowest_KL [0.33697873]
# lowest_KL [0.33682054]
# lowest_KL [0.33655734]
# lowest_KL [0.3362592]
# lowest_KL [0.33603908]
# lowest_KL [0.33583176]
# lowest_KL [0.33553176]
# lowest_KL [0.33528742]
# lowest_KL [0.33511633]
# lowest_KL [0.33499707]
# lowest_KL [0.33487197]
# lowest_KL [0.33471771]
# lowest_KL [0.33450875]
# lowest_KL [0.33433172]
# lowest_KL [0.33420828]
# lowest_KL [0.33409916]
# lowest_KL [0.33397387]
# lowest_KL [0.33384755]
# lowest_KL [0.33372266]
# lowest_KL [0.33361977]
# lowest_KL [0.3334439]
# lowest_KL [0.33324874]
# lowest_KL [0.33305838]
# lowest_KL [0.3328661]
# lowest_KL [0.3326562]
# lowest_KL [0.33241662]
# lowest_KL [0.33219976]
# lowest_KL [0.33202843]
# lowest_KL [0.33181514]
# lowest_KL [0.33161946]
# lowest_KL [0.3314745]
# lowest_KL [0.33135431]
# lowest_KL [0.33126977]
# lowest_KL [0.33121482]
# lowest_KL [0.33106852]
# lowest_KL [0.33085446]
# lowest_KL [0.33061611]
# lowest_KL [0.33040908]
# lowest_KL [0.3302235]
# lowest_KL [0.3301468]
# lowest_KL [0.33005087]
# lowest_KL [0.32994]
# lowest_KL [0.32978622]
# lowest_KL [0.32962086]
# lowest_KL [0.32942959]
# lowest_KL [0.32927597]
# lowest_KL [0.32910751]
# lowest_KL [0.32890858]
# lowest_KL [0.32878006]
# lowest_KL [0.32865181]
# lowest_KL [0.32851748]
# lowest_KL [0.32839915]
# lowest_KL [0.32821823]
# lowest_KL [0.32809807]
# lowest_KL [0.32801456]
# lowest_KL [0.32790848]
# lowest_KL [0.32777438]
# lowest_KL [0.32765439]
# lowest_KL [0.32750532]
# lowest_KL [0.32736863]
# lowest_KL [0.32726142]
# lowest_KL [0.32714438]
# lowest_KL [0.32701463]
# lowest_KL [0.32687509]
# lowest_KL [0.32674368]
# lowest_KL [0.32666309]
# lowest_KL [0.32664019]
# lowest_KL [0.3265486]
# lowest_KL [0.32639879]
# lowest_KL [0.32628663]
# lowest_KL [0.32619516]
# lowest_KL [0.32609612]
# lowest_KL [0.32596824]
# lowest_KL [0.32585399]
# lowest_KL [0.32579802]
# lowest_KL [0.32571295]
# lowest_KL [0.32560265]
# lowest_KL [0.32548505]
# lowest_KL [0.32536836]
# lowest_KL [0.32524435]
# lowest_KL [0.32514054]
# lowest_KL [0.32504889]
# lowest_KL [0.32500612]
# lowest_KL [0.32492426]
# lowest_KL [0.32476085]
# lowest_KL [0.32462447]
# lowest_KL [0.32448573]
# lowest_KL [0.32432516]
# lowest_KL [0.32418459]
# lowest_KL [0.3240103]
# lowest_KL [0.32385801]
# lowest_KL [0.32368402]
# lowest_KL [0.32349613]
# lowest_KL [0.32330433]
# lowest_KL [0.32311353]
# lowest_KL [0.32301167]
# lowest_KL [0.32289662]
# lowest_KL [0.32276088]
# lowest_KL [0.32266693]
# lowest_KL [0.32263172]
# lowest_KL [0.32258119]
# lowest_KL [0.32246957]
# lowest_KL [0.32238984]
# lowest_KL [0.32231324]
# lowest_KL [0.32224379]
# lowest_KL [0.32214535]
# lowest_KL [0.32206469]
# lowest_KL [0.32199089]
# lowest_KL [0.32187927]
# lowest_KL [0.32177042]
# lowest_KL [0.32170819]
# lowest_KL [0.32164839]
# lowest_KL [0.32159771]
# lowest_KL [0.32149052]
# lowest_KL [0.3213635]
# lowest_KL [0.3212546]
# lowest_KL [0.32119216]
# lowest_KL [0.32115459]
# lowest_KL [0.32106176]
# lowest_KL [0.32090793]
# lowest_KL [0.32073783]
# lowest_KL [0.32060337]
# lowest_KL [0.32049587]
# lowest_KL [0.32043029]
# lowest_KL [0.32040496]
# lowest_KL [0.32040108]
# lowest_KL [0.32041827]
# lowest_KL [0.3203826]
# lowest_KL [0.32031487]
# lowest_KL [0.3202459]
# lowest_KL [0.32014934]
# lowest_KL [0.3200382]
# lowest_KL [0.31991463]
# lowest_KL [0.31981437]
# lowest_KL [0.31974199]
# lowest_KL [0.31964087]
# lowest_KL [0.3195807]
# lowest_KL [0.31952363]
# lowest_KL [0.31941259]
# lowest_KL [0.31931629]
# lowest_KL [0.31920185]
# lowest_KL [0.31908259]
# lowest_KL [0.31898516]
# lowest_KL [0.31886397]
# lowest_KL [0.31871664]
# lowest_KL [0.31856719]
# lowest_KL [0.31844761]
# lowest_KL [0.31832918]
# lowest_KL [0.31826037]
# lowest_KL [0.31815297]
# lowest_KL [0.3180487]
# lowest_KL [0.31791386]
# lowest_KL [0.31779169]
# lowest_KL [0.31771237]
# lowest_KL [0.31767145]
# lowest_KL [0.31759139]
# lowest_KL [0.31745765]
# lowest_KL [0.31737296]
# lowest_KL [0.31732289]
# lowest_KL [0.31722613]
# lowest_KL [0.3171171]
# lowest_KL [0.31702493]
# lowest_KL [0.31695066]
# lowest_KL [0.31684679]
# lowest_KL [0.31675137]
# lowest_KL [0.31669534]
# lowest_KL [0.31668193]
# lowest_KL [0.31672656]
# lowest_KL [0.31675559]
# lowest_KL [0.31679348]
# lowest_KL [0.31679407]
# lowest_KL [0.31677218]
# lowest_KL [0.3166508]
# lowest_KL [0.31648053]
# lowest_KL [0.31632725]
# lowest_KL [0.31618573]
# lowest_KL [0.31609802]
# lowest_KL [0.3160539]
# lowest_KL [0.31604971]
# lowest_KL [0.31602615]
# lowest_KL [0.31594223]
# lowest_KL [0.31588758]
# lowest_KL [0.31576518]
# lowest_KL [0.31565322]
# lowest_KL [0.31560407]
# epoch:600 ==>  KL = [0.31560407], logLKH = [-7.05751428], prob_sum = 0.0323, time = 0.04s
# lowest_KL [0.31557218]
# lowest_KL [0.3155392]
# lowest_KL [0.31553731]
# lowest_KL [0.31546325]
# lowest_KL [0.31533384]
# lowest_KL [0.31518112]
# lowest_KL [0.31502619]
# lowest_KL [0.31488763]
# lowest_KL [0.31476748]
# lowest_KL [0.31462911]
# lowest_KL [0.31452891]
# lowest_KL [0.31446966]
# lowest_KL [0.31446422]
# lowest_KL [0.31441735]
# lowest_KL [0.31429981]
# lowest_KL [0.31416421]
# lowest_KL [0.31398118]
# lowest_KL [0.31378385]
# lowest_KL [0.31363695]
# lowest_KL [0.31356413]
# lowest_KL [0.31352185]
# lowest_KL [0.31340506]
# lowest_KL [0.31328202]
# lowest_KL [0.31314425]
# lowest_KL [0.31300026]
# lowest_KL [0.31285333]
# lowest_KL [0.31272225]
# lowest_KL [0.31263248]
# lowest_KL [0.31250684]
# lowest_KL [0.31236855]
# lowest_KL [0.31227236]
# lowest_KL [0.31215845]
# lowest_KL [0.31202175]
# lowest_KL [0.31187363]
# lowest_KL [0.31172533]
# lowest_KL [0.31158138]
# lowest_KL [0.31143729]
# lowest_KL [0.31129398]
# lowest_KL [0.31111873]
# lowest_KL [0.31098259]
# lowest_KL [0.31087686]
# lowest_KL [0.31077134]
# lowest_KL [0.31062746]
# lowest_KL [0.31052602]
# lowest_KL [0.31041249]
# lowest_KL [0.31029489]
# lowest_KL [0.31020432]
# lowest_KL [0.31010299]
# lowest_KL [0.31001118]
# lowest_KL [0.30992947]
# lowest_KL [0.30988368]
# lowest_KL [0.30986988]
# lowest_KL [0.30984502]
# lowest_KL [0.30980648]
# lowest_KL [0.30978213]
# lowest_KL [0.30975006]
# lowest_KL [0.30968022]
# lowest_KL [0.30964016]
# lowest_KL [0.30957424]
# lowest_KL [0.30949889]
# lowest_KL [0.30941824]
# lowest_KL [0.30934994]
# lowest_KL [0.30930265]
# lowest_KL [0.30928781]
# lowest_KL [0.30926138]
# lowest_KL [0.3092106]
# lowest_KL [0.30914592]
# lowest_KL [0.3090886]
# lowest_KL [0.3090378]
# lowest_KL [0.30898422]
# lowest_KL [0.30892943]
# lowest_KL [0.30886465]
# lowest_KL [0.30883532]
# lowest_KL [0.30875976]
# lowest_KL [0.30866786]
# lowest_KL [0.3085824]
# lowest_KL [0.3085181]
# lowest_KL [0.30849881]
# lowest_KL [0.30848803]
# lowest_KL [0.30843976]
# lowest_KL [0.30840063]
# lowest_KL [0.30832566]
# lowest_KL [0.30825733]
# lowest_KL [0.30818797]
# lowest_KL [0.30810272]
# lowest_KL [0.30804137]
# lowest_KL [0.30799689]
# lowest_KL [0.30793235]
# lowest_KL [0.30789177]
# lowest_KL [0.30782953]
# lowest_KL [0.30778599]
# lowest_KL [0.30772131]
# lowest_KL [0.30763387]
# lowest_KL [0.30753984]
# lowest_KL [0.30745188]
# lowest_KL [0.30738298]
# lowest_KL [0.30730838]
# lowest_KL [0.3072319]
# lowest_KL [0.30718239]
# lowest_KL [0.30713699]
# lowest_KL [0.30708701]
# lowest_KL [0.30702948]
# lowest_KL [0.30695622]
# lowest_KL [0.30687023]
# lowest_KL [0.30676552]
# lowest_KL [0.30664628]
# lowest_KL [0.30652712]
# lowest_KL [0.30642398]
# lowest_KL [0.30633757]
# lowest_KL [0.3062678]
# lowest_KL [0.30620238]
# lowest_KL [0.30616259]
# lowest_KL [0.30612582]
# lowest_KL [0.30605756]
# lowest_KL [0.30598753]
# lowest_KL [0.30592989]
# lowest_KL [0.30587958]
# lowest_KL [0.30583515]
# lowest_KL [0.30578137]
# lowest_KL [0.30573653]
# lowest_KL [0.30571923]
# lowest_KL [0.30569981]
# lowest_KL [0.30566095]
# lowest_KL [0.30558166]
# lowest_KL [0.30548481]
# lowest_KL [0.30539586]
# lowest_KL [0.30533063]
# lowest_KL [0.30526841]
# lowest_KL [0.30521019]
# lowest_KL [0.305149]
# lowest_KL [0.30509668]
# lowest_KL [0.30504516]
# lowest_KL [0.30499205]
# lowest_KL [0.30494302]
# lowest_KL [0.30488107]
# lowest_KL [0.30483059]
# lowest_KL [0.30476922]
# lowest_KL [0.3047111]
# lowest_KL [0.30463152]
# lowest_KL [0.30456906]
# lowest_KL [0.304501]
# lowest_KL [0.30443344]
# lowest_KL [0.30434798]
# lowest_KL [0.30425896]
# lowest_KL [0.30415693]
# lowest_KL [0.30407627]
# lowest_KL [0.30403843]
# lowest_KL [0.30398474]
# lowest_KL [0.30393263]
# lowest_KL [0.30388402]
# lowest_KL [0.3038461]
# lowest_KL [0.30379212]
# lowest_KL [0.30375435]
# lowest_KL [0.30373277]
# lowest_KL [0.30369722]
# lowest_KL [0.30361941]
# lowest_KL [0.30352042]
# lowest_KL [0.30340867]
# lowest_KL [0.30331355]
# lowest_KL [0.30324393]
# lowest_KL [0.30318535]
# lowest_KL [0.30313035]
# lowest_KL [0.30307892]
# lowest_KL [0.30304672]
# lowest_KL [0.30302382]
# lowest_KL [0.30298579]
# lowest_KL [0.30291665]
# lowest_KL [0.30283018]
# lowest_KL [0.30274549]
# lowest_KL [0.30264359]
# lowest_KL [0.30258078]
# lowest_KL [0.30253422]
# lowest_KL [0.30247857]
# lowest_KL [0.30241447]
# lowest_KL [0.30236192]
# lowest_KL [0.30229674]
# lowest_KL [0.30222852]
# lowest_KL [0.30215488]
# lowest_KL [0.30207366]
# lowest_KL [0.30201799]
# lowest_KL [0.30195601]
# lowest_KL [0.30190609]
# lowest_KL [0.30186352]
# lowest_KL [0.30182223]
# lowest_KL [0.30175967]
# lowest_KL [0.30169384]
# lowest_KL [0.30165479]
# lowest_KL [0.3016108]
# lowest_KL [0.30154697]
# lowest_KL [0.30148075]
# lowest_KL [0.30140584]
# lowest_KL [0.30135032]
# lowest_KL [0.30129264]
# lowest_KL [0.30127432]
# lowest_KL [0.30125766]
# lowest_KL [0.30121862]
# lowest_KL [0.3011628]
# lowest_KL [0.30110453]
# lowest_KL [0.30104306]
# lowest_KL [0.30097361]
# epoch:800 ==>  KL = [0.30097361], logLKH = [-6.85268789], prob_sum = 0.0370, time = 0.04s
# lowest_KL [0.30091107]
# lowest_KL [0.30084259]
# lowest_KL [0.30078691]
# lowest_KL [0.30072537]
# lowest_KL [0.30065819]
# lowest_KL [0.30061103]
# lowest_KL [0.300562]
# lowest_KL [0.30053268]
# lowest_KL [0.30051907]
# lowest_KL [0.30050826]
# lowest_KL [0.30048731]
# lowest_KL [0.3004897]
# lowest_KL [0.3005144]
# lowest_KL [0.30051771]
# lowest_KL [0.30048999]
# lowest_KL [0.3004303]
# lowest_KL [0.30034148]
# lowest_KL [0.30023645]
# lowest_KL [0.30013671]
# lowest_KL [0.30002248]
# lowest_KL [0.29990731]
# lowest_KL [0.29983835]
# lowest_KL [0.29979336]
# lowest_KL [0.29977899]
# lowest_KL [0.2997781]
# lowest_KL [0.29978909]
# lowest_KL [0.29977591]
# lowest_KL [0.2997515]
# lowest_KL [0.29970124]
# lowest_KL [0.29963152]
# lowest_KL [0.29954214]
# lowest_KL [0.2994679]
# lowest_KL [0.29943883]
# lowest_KL [0.29939805]
# lowest_KL [0.29938631]
# lowest_KL [0.29936123]
# lowest_KL [0.29930921]
# lowest_KL [0.29923399]
# lowest_KL [0.29913443]
# lowest_KL [0.29905758]
# lowest_KL [0.29898418]
# lowest_KL [0.29889343]
# lowest_KL [0.29878316]
# lowest_KL [0.29872276]
# lowest_KL [0.29868287]
# lowest_KL [0.29866653]
# lowest_KL [0.29862082]
# lowest_KL [0.29855457]
# lowest_KL [0.2984535]
# lowest_KL [0.29835594]
# lowest_KL [0.29828508]
# lowest_KL [0.29823676]
# lowest_KL [0.298191]
# lowest_KL [0.29813186]
# lowest_KL [0.29807628]
# lowest_KL [0.29802301]
# lowest_KL [0.29794504]
# lowest_KL [0.29786725]
# lowest_KL [0.29780307]
# lowest_KL [0.29774612]
# lowest_KL [0.29772151]
# lowest_KL [0.29771135]
# lowest_KL [0.29768853]
# lowest_KL [0.29763459]
# lowest_KL [0.29757279]
# lowest_KL [0.29751448]
# lowest_KL [0.29746117]
# lowest_KL [0.2974162]
# lowest_KL [0.29737565]
# lowest_KL [0.29733963]
# lowest_KL [0.29728507]
# lowest_KL [0.29722566]
# lowest_KL [0.29716598]
# lowest_KL [0.29711082]
# lowest_KL [0.2970602]
# lowest_KL [0.29701734]
# lowest_KL [0.29698205]
# lowest_KL [0.29693804]
# lowest_KL [0.29687825]
# lowest_KL [0.2968228]
# lowest_KL [0.29674354]
# lowest_KL [0.29667933]
# lowest_KL [0.29662478]
# lowest_KL [0.29657412]
# lowest_KL [0.29652361]
# lowest_KL [0.29647547]
# lowest_KL [0.29641369]
# lowest_KL [0.29636882]
# lowest_KL [0.2963347]
# lowest_KL [0.29631016]
# lowest_KL [0.29629488]
# lowest_KL [0.29627285]
# lowest_KL [0.29625274]
# lowest_KL [0.29621454]
# lowest_KL [0.29620185]
# lowest_KL [0.29618783]
# lowest_KL [0.29614571]
# lowest_KL [0.29607586]
# lowest_KL [0.29598707]
# lowest_KL [0.29591729]
# lowest_KL [0.29586943]
# lowest_KL [0.295864]
# lowest_KL [0.2958467]
# lowest_KL [0.29584218]
# lowest_KL [0.29586062]
# lowest_KL [0.29586902]
# lowest_KL [0.29585839]
# lowest_KL [0.29580684]
# lowest_KL [0.29574579]
# lowest_KL [0.29565145]
# lowest_KL [0.29554668]
# lowest_KL [0.29545428]
# lowest_KL [0.29536148]
# lowest_KL [0.29526624]
# lowest_KL [0.29519652]
# lowest_KL [0.29514535]
# lowest_KL [0.29509313]
# lowest_KL [0.29501714]
# lowest_KL [0.29492504]
# lowest_KL [0.29485261]
# lowest_KL [0.29481859]
# lowest_KL [0.29477649]
# lowest_KL [0.29470758]
# lowest_KL [0.29462293]
# lowest_KL [0.29454216]
# lowest_KL [0.29447363]
# lowest_KL [0.29443624]
# lowest_KL [0.29441235]
# lowest_KL [0.29436791]
# lowest_KL [0.29429838]
# lowest_KL [0.29425725]
# lowest_KL [0.29422107]
# lowest_KL [0.2941848]
# lowest_KL [0.29413463]
# lowest_KL [0.29407488]
# lowest_KL [0.29403665]
# lowest_KL [0.29397517]
# lowest_KL [0.29392147]
# lowest_KL [0.29387492]
# lowest_KL [0.29381352]
# lowest_KL [0.29375458]
# lowest_KL [0.29369858]
# lowest_KL [0.29363583]
# lowest_KL [0.29357965]
# lowest_KL [0.29353087]
# lowest_KL [0.29349939]
# lowest_KL [0.29348662]
# lowest_KL [0.29346223]
# lowest_KL [0.29342861]
# lowest_KL [0.29340957]
# lowest_KL [0.293372]
# lowest_KL [0.2933554]
# lowest_KL [0.29336397]
# lowest_KL [0.29336048]
# lowest_KL [0.29335649]
# lowest_KL [0.29333516]
# lowest_KL [0.29329087]
# lowest_KL [0.29325618]
# lowest_KL [0.29319713]
# lowest_KL [0.29312633]
# lowest_KL [0.29304093]
# lowest_KL [0.29294414]
# lowest_KL [0.29288341]
# lowest_KL [0.29280007]
# lowest_KL [0.29272137]
# lowest_KL [0.29270138]
# lowest_KL [0.29270233]
# lowest_KL [0.2926745]
# lowest_KL [0.29262253]
# lowest_KL [0.29259423]
# lowest_KL [0.29254822]
# lowest_KL [0.29248084]
# lowest_KL [0.29242383]
# lowest_KL [0.29237682]
# lowest_KL [0.29232532]
# lowest_KL [0.29229819]
# lowest_KL [0.29228616]
# lowest_KL [0.29225356]
# lowest_KL [0.29219236]
# lowest_KL [0.29212777]
# lowest_KL [0.29206227]
# lowest_KL [0.29200533]
# lowest_KL [0.29196122]
# lowest_KL [0.29190365]
# lowest_KL [0.29184712]
# lowest_KL [0.29181139]
# lowest_KL [0.29175694]
# lowest_KL [0.29174146]
# lowest_KL [0.291721]
# lowest_KL [0.29169765]
# lowest_KL [0.29164829]
# lowest_KL [0.29160194]
# lowest_KL [0.29154722]
# lowest_KL [0.29148175]
# lowest_KL [0.29143741]
# lowest_KL [0.29137579]
# lowest_KL [0.29130488]
# lowest_KL [0.29123306]
# lowest_KL [0.29116567]
# lowest_KL [0.2911174]
# epoch:1000 ==>  KL = [0.2911174], logLKH = [-6.7147009], prob_sum = 0.0399, time = 0.04s
# The lowest KL is 0.29111739772747136 in epoch 999

# %%
v0 = np.loadtxt(r'3x3.txt')
v0[0].shape
# Out:
# (9,)
